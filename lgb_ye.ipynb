# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
import logging

# %%
log_fmt = "[%(asctime)s] %(levelname)s in %(module)s: %(message)s"
logging.basicConfig(format=log_fmt, level=logging.INFO)

# %%
base_path = './data'
feature_path = './feature'
print(os.getcwd())
# Out:
# /extend/yezhizi/ZhiHuComp/zhcup

# %%
# 加载邀请回答数据
train = pd.read_csv(f'{base_path}/invite_info_0926.txt', sep='\t', header=None)
train.columns = ['qid', 'uid', 'dt', 'label']
del train['dt']
logging.info("invite %s", train.shape)

test = pd.read_csv(f'{base_path}/invite_info_evaluate_0926.txt', sep='\t', header=None)
test.columns = ['qid', 'uid', 'dt']
sub = test.copy()
sub_size = len(sub)
del test['dt']
logging.info("test %s", test.shape)
# Out:
# [2019-12-10 17:28:42,298] INFO in <ipython-input-4-f5fcce844f4e>: invite (9489162, 3)
# [2019-12-10 17:28:44,494] INFO in <ipython-input-4-f5fcce844f4e>: test (1141683, 2)

# %%
# 加载 kfold feature
t1 = pd.read_csv(f'{feature_path}/train_kfold_feature.txt', sep='\t')
train = pd.concat([train, t1], axis=1)

t1 = pd.read_csv(f'{feature_path}/test_kfold_feature.txt', sep='\t')
test = pd.concat([test, t1], axis=1)

# %%
# 加载 user 过去两个月的回答统计特征（除当条记录）
# t1 = pd.read_csv(f'{feature_path}/train_ua_feature.txt', sep='\t')
# train = pd.concat([train, t1], axis=1)

# t1 = pd.read_csv(f'{feature_path}/test_ua_feature.txt', sep='\t')
# test = pd.concat([test, t1], axis=1)

# %%
# 加载 invete feature 1
t1 = pd.read_csv(f'{feature_path}/train_invite_feature.txt', sep='\t')
train = pd.concat([train, t1], axis=1)

t1 = pd.read_csv(f'{feature_path}/test_invite_feature.txt', sep='\t')
test = pd.concat([test, t1], axis=1)

# %%
# 加载 invete feature 2
t1 = pd.read_csv(f'{feature_path}/train_invite_feature_2.txt', sep='\t')
train = pd.concat([train, t1], axis=1)

t1 = pd.read_csv(f'{feature_path}/test_invite_feature_2.txt', sep='\t')
test = pd.concat([test, t1], axis=1)

# %%
# # # 加载 member feature
# cate_feats = ['gender', 'freq',
#               'uf_b1', 'uf_b2','uf_b3', 'uf_b4', 'uf_b5',
#               'uf_c5',
#               'cate_clustered']
# use_cols = []
# for i1 in range(len(cate_feats)):
#     for i2 in range(i1+1, len(cate_feats)):
#         use_cols.append('{}_{}_count'.format(cate_feats[i1], cate_feats[i2]))

# t1 = pd.read_csv(f'{feature_path}/train_member_feature.txt', sep='\t', usecols=use_cols)
# train = pd.concat([train, t1], axis=1)

# t1 = pd.read_csv(f'{feature_path}/test_member_feature.txt', sep='\t', usecols=use_cols)
# test = pd.concat([test, t1], axis=1)

# %%
# # 特征计数伪接受率
# # for feat in use_cols:
# for feat in train.keys():
#     if feat[-6:] != '_count':
#         continue

#     tmp = train[[feat, 'label']]
#     tmp.columns = [feat, feat+'_psd_lb']
#     t1 = tmp.groupby([feat]).mean().reset_index()
#     train = pd.merge(train, t1, on=[feat], how='left')
#     test = pd.merge(test, t1, on=[feat], how='left')

print(test.head())
# Out:
# qid          uid   day  hour  q_inv_kfold_mean  q_inv_kfold_sum  \
# 0  Q1493039281    M64135255  3870     9               0.0              0.0
# 1  Q2023398782  M2536956560  3872    22               NaN              NaN
# 2  Q4151338694  M3294926344  3874    15               NaN              NaN
# 3  Q3271436624  M3744310794  3873     4               0.5              3.0
# 4  Q3314287018  M1349051752  3872    19               NaN              NaN
#
#    q_inv_kfold_std  q_inv_kfold_count  u_inv_kfold_mean  u_inv_kfold_sum  ...  \
# 0         0.000000                2.0             0.125              1.0  ...
# 1              NaN                NaN             0.000              0.0  ...
# 2              NaN                NaN             0.100              1.0  ...
# 3         0.547723                6.0             0.000              0.0  ...
# 4              NaN                NaN             0.000              0.0  ...
#
#    qid_gender_count  qid_uf_b1_count  qid_uf_b2_count  qid_uf_b3_count  \
# 0                 4                2                2                7
# 1                17                7                7               28
# 2                 2                2                2                3
# 3                 2                2                6                7
# 4                 1                1                1                1
#
#    qid_uf_b4_count  qid_uf_b5_count  qid_uf_c5_count  intersection_ft_count  \
# 0                7                7                7                      0
# 1                7               27               27                      0
# 2                3                3                3                      0
# 3                6                6                2                      0
# 4                1                1                1                      0
#
#    intersection_it_count  intersection_it_score
# 0                      1               0.626967
# 1                      0               0.000000
# 2                      0               0.000000
# 3                      0               0.000000
# 4                      0               0.000000
#
# [5 rows x 150 columns]

# %%
# 加载用户
user = pd.read_csv(f'{base_path}/member_info_0926.txt', header=None, sep='\t', usecols=[i for i in np.arange(21).tolist() if i not in [2,3,4,5,6]])
user.columns = ['uid', 'gender', 'freq',
                'uf_b1', 'uf_b2','uf_b3', 'uf_b4', 'uf_b5', 
                'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 
                'score', 'follow_topic', 'inter_topic']

del user['follow_topic'], user['inter_topic']
logging.info("user %s", user.shape)

unq = user.nunique()
logging.info("user unq %s", unq)

for x in unq[unq == 1].index:
    del user[x]
    logging.info('del unq==1 %s', x)

t = user.dtypes
cats = [x for x in t[t == 'object'].index if x not in ['follow_topic', 'inter_topic', 'uid']]
logging.info("user cat %s", cats)

for d in cats:
    lb = LabelEncoder()
    user[d] = lb.fit_transform(user[d])
    logging.info('encode %s', d)
    
q_lb = LabelEncoder()
q_lb.fit(list(train['qid'].astype(str).values) + list(test['qid'].astype(str).values))
train['qid_enc'] = q_lb.transform(train['qid'])
test['qid_enc'] = q_lb.transform(test['qid'])

u_lb = LabelEncoder()
u_lb.fit(user['uid'])
train['uid_enc'] = u_lb.transform(train['uid'])
test['uid_enc'] = u_lb.transform(test['uid'])

# merge user
train = pd.merge(train, user, on='uid', how='left')
test = pd.merge(test, user, on='uid', how='left')
logging.info("train shape %s, test shape %s", train.shape, test.shape)
# Out:
# [2019-12-10 17:33:56,656] INFO in <ipython-input-11-ddd3e7aab310>: user (1931654, 14)
# [2019-12-10 17:34:00,162] INFO in <ipython-input-11-ddd3e7aab310>: user unq uid       1931654
# gender          3
# freq            5
# uf_b1           2
# uf_b2           2
# uf_b3           2
# uf_b4           2
# uf_b5           2
# uf_c1        2561
# uf_c2         291
# uf_c3         428
# uf_c4        1556
# uf_c5           2
# score         732
# dtype: int64
# [2019-12-10 17:34:00,168] INFO in <ipython-input-11-ddd3e7aab310>: user cat ['gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# [2019-12-10 17:34:00,913] INFO in <ipython-input-11-ddd3e7aab310>: encode gender
# [2019-12-10 17:34:01,795] INFO in <ipython-input-11-ddd3e7aab310>: encode freq
# [2019-12-10 17:34:02,326] INFO in <ipython-input-11-ddd3e7aab310>: encode uf_c1
# [2019-12-10 17:34:02,833] INFO in <ipython-input-11-ddd3e7aab310>: encode uf_c2
# [2019-12-10 17:34:03,300] INFO in <ipython-input-11-ddd3e7aab310>: encode uf_c3
# [2019-12-10 17:34:03,950] INFO in <ipython-input-11-ddd3e7aab310>: encode uf_c4
# [2019-12-10 17:34:04,511] INFO in <ipython-input-11-ddd3e7aab310>: encode uf_c5
# [2019-12-10 17:35:14,303] INFO in <ipython-input-11-ddd3e7aab310>: train shape (9489162, 166), test shape (1141683, 165)

# %%
data = pd.concat((train, test), axis=0, sort=True)
len_train = len(train)
del train

# %%
data
# Out:
#            136     4       0     9
# 17       3852           11           268     4       0    14
# 18       3849           13           311     1       0    13
# 19       3846            1            38     1       0    22
# 20       3854            1            18     0       2    11
# 21       3842            0             0     0       2    13
# 22       3846            0             0     0       2     8
# 23       3850            0             1     0       2     9
# 24       3854            0             0     0       2    12
# 25       3861            0             0     0       2    10
# 26       3839           11           251     0       2     8
# 27       3864           14           315     3       2     0
# 28       3850           12           287     4       2    17
# 29       3842            2            50     4       2    23
# ...       ...          ...           ...   ...     ...   ...
# 1141653  3871            0             0     4       0    16
# 1141654  3871            1            18     0       0     8
# 1141655  3868            5           107     0       2     7
# 1141656  3871            7           165     1       0    15
# 1141657  3869            4            77     1       0     0
# 1141658  3871            2            38     3       2    10
# 1141659  3869            0             3     0       0     9
# 1141660  3873            2            45     0       2    18
# 1141661  3873            1            30     4       2     7
# 1141662  3868            0             1     0       1     3
# 1141663  3871            3            58     0       2     8
# 1141664  3872            0             0     0       1    18
# 1141665  3872            1            29     1       0    15
# 1141666  3873            5           127     0       2    21
# 1141667  3868            6           140     0       2    14
# 1141668  3870            3            65     2       2    14
# 1141669  3869            7           166     4       2     8
# 1141670  3870            0             0     0       2    22
# 1141671  3870           18           438     1       1    16
# 1141672  3869           63          1497     0       1     8
# 1141673  3868            0             0     0       1     9
# 1141674  3873            0             0     0       1     9
# 1141675  3868            1            30     0       0     9
# 1141676  3873            0             2     0       0    12
# 1141677  3872           14           329     0       0     7
# 1141678  3869            0             0     4       2    20
# 1141679  3872            0             1     1       2    21
# 1141680  3871            1            27     0       2    15
# 1141681  3871            0             8     4       2     8
# 1141682  3873            0             0     0       1     9
#
#          intersection_ft_count  intersection_it_count  intersection_it_score  \
# 0                            1                      0               0.000000
# 1                            0                      0               0.000000
# 2                            0                      0               0.000000
# 3                            0                      1               1.066367
# 4                            0                      0               0.000000
# 5                            1                      0               0.000000
# 6                            0                      0               0.000000
# 7                            0                      0               0.000000
# 8                            0                      0               0.000000
# 9                            0                      0               0.000000
# 10                           1                      0               0.000000
# 11                           1                      0               0.000000
# 12                           0                      0               0.000000
# 13                           0                      0               0.000000
# 14                           0                      0               0.000000
# 15                           0                      1               1.328859
# 16                           0                      0               0.000000
# 17                           0                      0               0.000000
# 18                           0                      0               0.000000
# 19                           0                      0               0.000000
# 20                           0                      1               1.110740
# 21                           1                      0               0.000000
# 22                           0                      0               0.000000
# 23                           0                      0               0.000000
# 24                           1                      0               0.000000
# 25                           1                      0               0.000000
# 26                           1                      0               0.000000
# 27                           3                      0               0.000000
# 28                           2                      0               0.000000
# 29                           0                      0               0.000000
# ...                        ...                    ...                    ...
# 1141653                      0                      0               0.000000
# 1141654                      1                      0               0.000000
# 1141655                      1                      0               0.000000
# 1141656                      1                      0               0.000000
# 1141657                      0                      0               0.000000
# 1141658                      0                      0               0.000000
# 1141659                      0                      0               0.000000
# 1141660                      0                      0               0.000000
# 1141661                      1                      1               0.675285
# 1141662                      0                      0               0.000000
# 1141663                      1                      0               0.000000
# 1141664                      0                      0               0.000000
# 1141665                      0                      0               0.000000
# 1141666                      1                      0               0.000000
# 1141667                      0                      0               0.000000
# 1141668                      1                      0               0.000000
# 1141669                      2                      0               0.000000
# 1141670                      0                      0               0.000000
# 1141671                      0                      0               0.000000
# 1141672                      0                      0               0.000000
# 1141673                      0                      2               1.407560
# 1141674                      0                      0               0.000000
# 1141675                      0                      1               0.857024
# 1141676                      0                      0               0.000000
# 1141677                      0                      0               0.000000
# 1141678                      0                      0               0.000000
# 1141679                      0                      0               0.000000
# 1141680                      1                      0               0.000000
# 1141681                      0                      0               0.000000
# 1141682                      0                      0               0.000000
#
#          label  ...  uid_hour_count  uid_hour_max  uid_hour_mean  \
# 0          0.0  ...               2            23      20.400000
# 1          0.0  ...               2            14       9.875000
# 2          0.0  ...               4            19      13.071428
# 3          0.0  ...               2            20       8.714286
# 4          0.0  ...               2            23      14.900000
# 5          0.0  ...               1            20      11.800000
# 6          0.0  ...               2            20      11.800000
# 7          1.0  ...               2            11       7.727273
# 8          0.0  ...               2            19      17.200000
# 9          0.0  ...               3            20      14.416667
# 10         1.0  ...               5            18       8.590164
# 11         1.0  ...               3            18       8.590164
# 12         1.0  ...               5            18       8.590164
# 13         0.0  ...               3            18       8.590164
# 14         0.0  ...               4            18       8.590164
# 15         0.0  ...               1            19      14.833333
# 16         1.0  ...               3            22       9.380953
# 17         1.0  ...               1            22       9.380953
# 18         0.0  ...               3            23      14.071428
# 19         0.0  ...               2            23      14.071428
# 20         0.0  ...               1            23      16.833334
# 21         0.0  ...               4            23      10.840000
# 22         0.0  ...               5            23      10.840000
# 23         0.0  ...               8            23      10.840000
# 24         0.0  ...               3            23      10.840000
# 25         0.0  ...               6            23      10.840000
# 26         0.0  ...               5            23      10.840000
# 27         1.0  ...               1            23      11.500000
# 28         1.0  ...               2            21      14.500000
# 29         0.0  ...               2            23      17.705883
# ...        ...  ...             ...           ...            ...
# 1141653    NaN  ...               2            16      12.416667
# 1141654    NaN  ...               2            22      12.000000
# 1141655    NaN  ...               1            22      11.058824
# 1141656    NaN  ...               1            15       8.055555
# 1141657    NaN  ...               1            23      15.875000
# 1141658    NaN  ...               1            17      14.000000
# 1141659    NaN  ...               4            13      10.823529
# 1141660    NaN  ...               1            18      17.000000
# 1141661    NaN  ...               1            19      11.800000
# 1141662    NaN  ...               1            20       9.880000
# 1141663    NaN  ...               8            23      11.900000
# 1141664    NaN  ...               5            22      11.785714
# 1141665    NaN  ...               3            20      12.933333
# 1141666    NaN  ...               2            23      15.888889
# 1141667    NaN  ...               1            21      13.357142
# 1141668    NaN  ...               2            14      14.000000
# 1141669    NaN  ...               1             8       8.000000
# 1141670    NaN  ...               1            22      10.117647
# 1141671    NaN  ...               1            17      16.500000
# 1141672    NaN  ...               3            11       8.900000
# 1141673    NaN  ...               9            21      11.095238
# 1141674    NaN  ...              12            23       8.362069
# 1141675    NaN  ...               1            22      12.545455
# 1141676    NaN  ...               2            23      13.500000
# 1141677    NaN  ...               7             9       7.600000
# 1141678    NaN  ...               1            23      19.777779
# 1141679    NaN  ...               1            23      21.000000
# 1141680    NaN  ...               1            21      16.916666
# 1141681    NaN  ...              10            23      11.421053
# 1141682    NaN  ...               4            23      12.500000
#
#          uid_hour_median  uid_hour_min  uid_hour_std  uid_week_count  \
# 0                   22.0            12      4.722288               2
# 1                    9.5             7      3.044316               2
# 2                   13.0             7      3.561855               3
# 3                    8.0             0      6.421689               1
# 4                   16.0             4      6.740425               2
# 5                   10.0             5      5.266245               1
# 6                   10.0             5      5.266245               5
# 7                    9.0             0      3.951985               3
# 8                   17.0            14      2.049390               1
# 9                   15.0             8      4.294993               2
# 10                   9.0             0      5.675611              11
# 11                   9.0             0      5.675611              13
# 12                   9.0             0      5.675611               9
# 13                   9.0             0      5.675611               7
# 14                   9.0             0      5.675611               6
# 15                  16.5             8      4.355074               3
# 16                   8.0             0      5.962182               5
# 17                   8.0             0      5.962182               5
# 18                  13.0             4      5.553437               3
# 19                  13.0             4      5.553437               4
# 20                  17.5            10      5.492419               1
# 21                  10.5             0      4.617447               9
# 22                  10.5             0      4.617447               9
# 23                  10.5             0      4.617447              10
# 24                  10.5             0      4.617447               5
# 25                  10.5             0      4.617447               5
# 26                  10.5             0      4.617447               9
# 27                  11.5             0     16.263456               1
# 28                  15.0             8      5.291502               2
# 29                  18.0            11      3.885304               4
# ...                  ...           ...           ...             ...
# 1141653             11.5            10      2.314316               2
# 1141654              9.5             8      5.549775               2
# 1141655             10.0             0      6.036044               2
# 1141656              8.0             3      2.667279               1
# 1141657             19.0             0      7.972049               1
# 1141658             15.0            10      3.605551               1
# 1141659             11.0             8      1.667157               3
# 1141660             17.0            16      1.414214               1
# 1141661             12.0             7      4.764451               2
# 1141662              9.0             0      4.807286               4
# 1141663              8.5             0      6.231499               2
# 1141664             11.0             1      5.179379               7
# 1141665             12.0            11      2.491892               1
# 1141666             17.0             8      5.577733               3
# 1141667             12.5             9      3.521519               4
# 1141668             14.0            14      0.000000               2
# 1141669              8.0             8           NaN               1
# 1141670              9.0             0      5.861765               3
# 1141671             16.5            16      0.707107               1
# 1141672              9.0             7      1.286684               2
# 1141673             10.0             0      4.129806              10
# 1141674              9.0             0      4.666786              15
# 1141675             11.0             8      4.131916               2
# 1141676             11.5             8      5.215926               4
# 1141677              7.0             7      0.966092               2
# 1141678             21.0            13      3.419714               1
# 1141679             21.5            18      2.160247               1
# 1141680             18.0            11      3.315483               2
# 1141681              8.0             7      6.176261               1
# 1141682              9.0             8      5.966574               4
#
#          uid_week_mean  uid_week_median  uid_week_std
# 0             2.200000              2.0      1.643168
# 1             3.625000              4.0      1.922610
# 2             3.357143              3.5      1.736803
# 3             3.428571              3.0      1.718249
# 4             3.000000              3.0      2.108185
# 5             3.900000              4.0      1.100505
# 6             3.900000              4.0      1.100505
# 7             3.000000              3.0      2.529822
# 8             2.400000              3.0      1.816590
# 9             3.583333              3.5      2.020726
# 10            3.065574              3.0      1.851746
# 11            3.065574              3.0      1.851746
# 12            3.065574              3.0      1.851746
# 13            3.065574              3.0      1.851746
# 14            3.065574              3.0      1.851746
# 15            3.833333              4.0      0.752773
# 16            3.380952              3.0      2.085094
# 17            3.380952              3.0      2.085094
# 18            2.714286              3.0      2.198901
# 19            2.714286              3.0      2.198901
# 20            3.333333              3.5      2.065591
# 21            2.800000              3.0      2.138090
# 22            2.800000              3.0      2.138090
# 23            2.800000              3.0      2.138090
# 24            2.800000              3.0      2.138090
# 25            2.800000              3.0      2.138090
# 26            2.800000              3.0      2.138090
# 27            0.500000              0.5      0.707107
# 28            2.000000              2.0      1.414214
# 29            3.294118              3.0      2.143732
# ...                ...              ...           ...
# 1141653       2.916667              3.0      1.928652
# 1141654       2.333333              2.5      2.065591
# 1141655       2.588235              3.0      1.872793
# 1141656       3.222222              3.0      1.864705
# 1141657       2.250000              2.5      1.581139
# 1141658       1.000000              1.0      1.000000
# 1141659       2.764706              3.0      1.714986
# 1141660       3.000000              3.0      1.414214
# 1141661       1.200000              1.0      0.836660
# 1141662       3.080000              3.0      2.215852
# 1141663       3.050000              3.0      1.904980
# 1141664       2.732143              2.5      2.235995
# 1141665       3.533333              4.0      2.166850
# 1141666       3.111111              3.0      1.615893
# 1141667       3.357143              4.0      1.984833
# 1141668       6.000000              6.0      0.000000
# 1141669       5.000000              5.0           NaN
# 1141670       3.000000              3.0      2.150581
# 1141671       3.000000              3.0      4.242641
# 1141672       3.500000              3.5      1.581139
# 1141673       2.968254              2.0      1.917393
# 1141674       3.103448              3.0      1.888930
# 1141675       2.909091              3.0      2.071451
# 1141676       3.166667              3.0      2.093407
# 1141677       4.300000              5.0      2.110819
# 1141678       3.333333              3.0      2.000000
# 1141679       4.000000              4.5      2.160247
# 1141680       3.083333              3.0      2.020726
# 1141681       3.000000              3.0      1.795055
# 1141682       2.625000              2.0      1.962142
#
# [10630845 rows x 166 columns]

# %%
# count 特征
# count_fea = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# for feat in count_fea:
#     col_name = '{}_count'.format(feat)
#     data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
#     data.loc[data[col_name] < 2, feat] = -1
#     data[feat] += 1
#     data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
#     data[col_name] = (data[col_name] - data[col_name].min()) / (data[col_name].max() - data[col_name].min())

# %%
# 所有没有归一化的计数特征, 次数小于2的计数叠加为取值为-1的计数, 然后归一化
# 操作有点复杂, 对于交叉特征, 要先找出两个都是-1的当前计数是 a, 然后找出计数小于2的数量 b, 然后这两个的计数都改为 a+b
# 理解错了, 是将小于2的特征看做一个新的特征,不是和取值-1的合并
# for feat in data.keys():
#     if feat[-6:] == '_count':
#         feat_sub = feat.split('_')[:-1]
        
#         # 切成两部分, 两部分都不是特征下一个
#         is_feat = False
#         for i in range(len(feat_sub)-1):
#             feat1 = '_'.join(feat_sub[:i+1])
#             feat2 = '_'.join(feat_sub[i+1:])
#             if ((feat1 in data.keys()) & (feat2 in data.keys())):
#                 feat_sub = [feat1, feat2]
#                 is_feat = True
#                 break
    
#         if not is_feat:
#             continue

#         idx_less = data[feat].values < 2
#         num_less = np.sum(idx_less)

#         # idx_neg_1 = (data[feat_sub[0]] == -1)
#         # for sub_f in feat_sub[1:]:
#         #     idx_neg_1 = (idx_neg_1 & (data[sub_f] == -1))
        
#         # num_neg_1 = np.sum(idx_neg_1)

#         # new_count = num_less + num_neg_1
#         # data.loc[(idx_less | idx_neg_1), feat] = new_count
#         # print(feat, num_less, num_neg_1, new_count)

#         data.loc[idx_less, feat] = num_less
#         print(feat, num_less)

#         data[feat] = (data[feat] - data[feat].min()) / (data[feat].max() - data[feat].min()).astype('float32')

# %%
data['wk'] = data['day'] % 7
# Out:
# [2019-12-10 17:35:45,405] INFO in utils: Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [2019-12-10 17:35:45,406] INFO in utils: NumExpr defaulting to 8 threads.

# %%
# count 二阶组合特征
# count_feats = ['freq', 'gender', 'score', 'qid_enc', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'hour', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour']

# # 'qid_enc' 与其他所有特征组合计数: 877709: 839029
# count_feats = ['qid_enc', 'freq', 'gender', 'score', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'hour', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'day']

# tmp_data = data[count_feats]
# for fi in (count_feats[0:1]):
#     other_feats = [f for f in count_feats if f != fi]
#     for fj in other_feats:
#         t1 = tmp_data.groupby([fi, fj])
#         leftover = [f for f in other_feats if f != fj]

#         print(fi, fj)
#         # 计数,一次就好,都一样的 
#         t2 = t1[leftover[0]].agg(['count'])
#         t2.columns = [fi+'_'+fj+sub for sub in ['_count']]
#         data = pd.merge(data, t2, on=[fi, fj], how='left')

#         # for fk in leftover:
#         #     t2 = t1[fk].agg(['mean', 'sum', 'std'])
#         #     t2.columns = [fi+'_'+fj+'_'+fk+sub for sub in ['_mean', '_sum', '_std']]
#         #     data = pd.merge(data, t2, on=[fi, fj], how='left')
#         #     print(fi, fj, fk)
# print(data.head())

# %%
# # 'uid_enc', 与其他所有特征组合计数: 878069 删除了些特征 878379:839113
# count_feats = ['uid_enc', 'hour', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'day']

# tmp_data = data[count_feats]
# fi = count_feats[0]
# other_feats = [f for f in count_feats if f != fi]
# for fj in other_feats:
#     t1 = tmp_data.groupby([fi, fj])
#     leftover = [f for f in other_feats if f != fj]
#     print(fi, fj)
#     # 计数,一次就好,都一样的 
#     t2 = t1[leftover[0]].agg(['count'])
#     t2.columns = [fi+'_'+fj+sub for sub in ['_count']]
#     data = pd.merge(data, t2, on=[fi, fj], how='left')

# %%
# # 'hour' 与其他所有特征组合计数: 875196
# count_feats = ['hour', 'freq', 'gender', 'score', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'day']

# tmp_data = data[count_feats]
# for fi in (count_feats[0:1]):
#     other_feats = [f for f in count_feats if f != fi]
#     for fj in other_feats:
#         t1 = tmp_data.groupby([fi, fj])
#         leftover = [f for f in other_feats if f != fj]

#         print(fi, fj)
#         # 计数,一次就好,都一样的 
#         t2 = t1[leftover[0]].agg(['count'])
#         t2.columns = [fi+'_'+fj+sub for sub in ['_count']]
#         data = pd.merge(data, t2, on=[fi, fj], how='left')

# %%
# # 'day' 与其他所有特征组合计数: 881459: 
# count_feats = ['day', 'freq', 'gender', 'score', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'hour']

# tmp_data = data[count_feats]
# for fi in (count_feats[0:1]):
#     other_feats = [f for f in count_feats if f != fi]
#     for fj in other_feats:
#         t1 = tmp_data.groupby([fi, fj])
#         leftover = [f for f in other_feats if f != fj]

#         print(fi, fj)
#         # 计数,一次就好,都一样的 
#         t2 = t1[leftover[0]].agg(['count'])
#         t2.columns = [fi+'_'+fj+sub for sub in ['_count']]
#         data = pd.merge(data, t2, on=[fi, fj], how='left')
# Out:
# day freq
# day gender
# day score
# day uf_b1
# day uf_b2
# day uf_b3
# day uf_b4
# day uf_b5
# day uf_c1
# day uf_c2
# day uf_c3
# day uf_c4
# day uf_c5
# day q_hour
# day wk
# day q_week
# day diff_iq_day
# day diff_iq_hour
# day hour

# %%
feat_counts_save = []

other_feats = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
for fj in other_feats:
    feat_counts_save.append(fj+'_count')

fi = 'qid_enc'
other_feats = ['freq', 'gender', 'score', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'hour', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'day']
for fj in other_feats:
    feat_counts_save.append(fi+'_'+fj+'_count')
fi = 'uid_enc'
other_feats = ['hour', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'day']
for fj in other_feats:
    feat_counts_save.append(fi+'_'+fj+'_count')
fi = 'day'
other_feats = ['freq', 'gender', 'score', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'wk', 'q_week', 'diff_iq_day', 'diff_iq_hour', 'hour']
for fj in other_feats:
    feat_counts_save.append(fi+'_'+fj+'_count')

print(feat_counts_save)

# data[feat_counts_save].to_csv(f'{feature_path}/count_features.txt', index=None, header=None, sep='\t')
# 加载 invete feature 2
t1 = pd.read_csv(f'{feature_path}/count_features.txt', sep='\t', header=None)
t1.columns = feat_counts_save
print(len(t1), len(data))
t1 = t1.reset_index(drop= True)
data = data.reset_index(drop= True)
data = pd.concat([data, t1], axis=1)
# Out:
# ['uid_enc_count', 'qid_enc_count', 'gender_count', 'freq_count', 'uf_c1_count', 'uf_c2_count', 'uf_c3_count', 'uf_c4_count', 'uf_c5_count', 'qid_enc_freq_count', 'qid_enc_gender_count', 'qid_enc_score_count', 'qid_enc_uid_enc_count', 'qid_enc_uf_b1_count', 'qid_enc_uf_b2_count', 'qid_enc_uf_b3_count', 'qid_enc_uf_b4_count', 'qid_enc_uf_b5_count', 'qid_enc_uf_c1_count', 'qid_enc_uf_c2_count', 'qid_enc_uf_c3_count', 'qid_enc_uf_c4_count', 'qid_enc_uf_c5_count', 'qid_enc_hour_count', 'qid_enc_q_hour_count', 'qid_enc_wk_count', 'qid_enc_q_week_count', 'qid_enc_diff_iq_day_count', 'qid_enc_diff_iq_hour_count', 'qid_enc_day_count', 'uid_enc_hour_count', 'uid_enc_q_hour_count', 'uid_enc_wk_count', 'uid_enc_q_week_count', 'uid_enc_diff_iq_day_count', 'uid_enc_diff_iq_hour_count', 'uid_enc_day_count', 'day_freq_count', 'day_gender_count', 'day_score_count', 'day_uf_b1_count', 'day_uf_b2_count', 'day_uf_b3_count', 'day_uf_b4_count', 'day_uf_b5_count', 'day_uf_c1_count', 'day_uf_c2_count', 'day_uf_c3_count', 'day_uf_c4_count', 'day_uf_c5_count', 'day_q_hour_count', 'day_wk_count', 'day_q_week_count', 'day_diff_iq_day_count', 'day_diff_iq_hour_count', 'day_hour_count']

# %%
# # # 'diff_iq_day' 与其他所有特征组合计数: 8810
# count_feats = ['diff_iq_day', 'freq', 'gender', 'score', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'wk', 'q_week', 'diff_iq_hour', 'hour']

# tmp_data = data[count_feats]
# for fi in (count_feats[0:1]):
#     other_feats = [f for f in count_feats if f != fi]
#     for fj in other_feats:
#         t1 = tmp_data.groupby([fi, fj])
#         leftover = [f for f in other_feats if f != fj]

#         print(fi, fj)
#         # 计数,一次就好,都一样的 
#         t2 = t1[leftover[0]].agg(['count'])
#         t2.columns = [fi+'_'+fj+sub for sub in ['_count']]
#         data = pd.merge(data, t2, on=[fi, fj], how='left')
# Out:
# diff_iq_day freq
# diff_iq_day gender
# diff_iq_day score
# diff_iq_day uf_b1
# diff_iq_day uf_b2
# diff_iq_day uf_b3
# diff_iq_day uf_b4
# diff_iq_day uf_b5
# diff_iq_day uf_c1
# diff_iq_day uf_c2
# diff_iq_day uf_c3
# diff_iq_day uf_c4
# diff_iq_day uf_c5
# diff_iq_day q_hour
# diff_iq_day wk
# diff_iq_day q_week
# diff_iq_day diff_iq_hour
# diff_iq_day hour

# %%
# # 'qid_enc','wk' 与其他所有特征组合计数: 878245: 839068
# count_feats = ['qid_enc', 'wk', 'freq', 'gender', 'score', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'hour', 'q_hour', 'day', 'q_week', 'diff_iq_day', 'diff_iq_hour']

# tmp_data = data[count_feats]
# fi = count_feats[0:2]
# other_feats = [f for f in count_feats if f not in fi]
# for fj in other_feats:
#     t1 = tmp_data.groupby(fi + [fj])
#     leftover = [f for f in other_feats if f != fj]
#     print(fi + [fj])
#     # 计数,一次就好,都一样的 
#     t2 = t1[leftover[0]].agg(['count'])
#     t2.columns = ['_'.join(fi)+'_'+fj+sub for sub in ['_count']]
#     data = pd.merge(data, t2, on=fi + [fj], how='left')
# print(data.head(1))

# %%
# 'qid_enc','hour' 与其他所有特征组合计数: 878196
#count_feats = ['qid_enc', 'hour', 'freq', 'gender', 'score', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'day', 'q_week', 'diff_iq_day', 'diff_iq_hour']

#tmp_data = data[count_feats]
#fi = count_feats[0:2]
#other_feats = [f for f in count_feats if f not in fi]
#for fj in other_feats:
#    t1 = tmp_data.groupby(fi + [fj])
#    leftover = [f for f in other_feats if f != fj]
##    print(fi + [fj])
    # 计数,一次就好,都一样的 
  ##  t2 = t1[leftover[0]].agg(['count'])
 #   t2.columns = ['_'.join(fi)+'_'+fj+sub for sub in ['_count']]
 #   data = pd.merge(data, t2, on=fi + [fj], how='left')
#print(data.head(1))

# %%
# # 'qid_enc','day' 与其他所有特征组合计数: 
# count_feats = ['qid_enc', 'day', 'freq', 'gender', 'score', 'uid_enc', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'q_hour', 'q_week', 'diff_iq_day', 'diff_iq_hour']

# tmp_data = data[count_feats]
# fi = count_feats[0:2]
# other_feats = [f for f in count_feats if f not in fi]
# for fj in other_feats:
#     t1 = tmp_data.groupby(fi + [fj])
#     leftover = [f for f in other_feats if f != fj]
#     print(fi + [fj])
#     # 计数,一次就好,都一样的 
#     t2 = t1[leftover[0]].agg(['count'])
#     t2.columns = ['_'.join(fi)+'_'+fj+sub for sub in ['_count']]
#     data = pd.merge(data, t2, on=fi + [fj], how='left')
# print(data.head(1))

# %%
drop_feat = ['label', 'uid', 'qid', 'dt', 'day'] 
drop_feat += ['u_is_rec_mean', 'u_reci_uncheer_mean', 'q_is_dest_sum', 'u_reci_uncheer_sum', 'u_is_rec_max', 
             'u_is_dest_mean','q_reci_uncheer_mean', 'q_reci_uncheer_sum', 'u_is_dest_sum', 'q_is_dest_max',
             'q_reci_uncheer_max', 'u_reci_tks_max', 'q_reci_mark_max','u_reci_dis_max', 'q_has_video_mean',
             'q_reci_no_help_mean', 'count_u_topic', 'u_has_video_mean', 'q_reci_dis_sum', 'q_reci_mark_sum',
             'q_reci_tks_sum','q_reci_tks_max','q_reci_dis_max','u_reci_mark_max','q_is_good_mean',
             'q_reci_no_help_sum', 'q_reci_xxx_max', 'u_reci_xxx_max','u_reci_no_help_sum','u_reci_xxx_sum',
              'u_is_good_mean','q_reci_no_help_max','u_has_img_max','u_is_good_sum','u_reci_no_help_max',
              'u_has_video_sum','uf_b5','q_reci_xxx_sum','q_is_good_sum','q_has_img_max','q_has_video_sum',
              'q_has_video_max','u_has_video_max','q_is_good_max','q_is_rec_max','u_is_good_max',
              'q_is_dest_mean','u_reci_uncheer_max','uf_c5_count','u_is_dest_max','q_is_rec_mean',
              'q_is_rec_sum','u_is_rec_sum', 'q_reci_xxx_mean','u_reci_xxx_mean','u_reci_comment_max',
              'q_reci_comment_sum','u_reci_cheer_max','u_reci_dis_sum','u_reci_tks_sum','q_has_img_sum',
              'q_reci_comment_max','q_reci_cheer_max','u_reci_no_help_mean','u_has_img_sum','u_reci_mark_sum']
feature_cols = [x for x in data.columns if x not in drop_feat]
# feature_cols

# %%
logging.info("feature size %s", len(feature_cols))

X_train_all = data.iloc[:len_train][feature_cols]
y_train_all = data.iloc[:len_train]['label']
X_test = data.iloc[len_train:]
assert len(X_test) == sub_size

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for index, (train_idx, val_idx) in enumerate(fold.split(X=X_train_all, y=y_train_all)):
    break

X_train, X_val, y_train, y_val = X_train_all.iloc[train_idx][feature_cols], X_train_all.iloc[val_idx][feature_cols], \
                                 y_train_all.iloc[train_idx], \
                                 y_train_all.iloc[val_idx]
del X_train_all

logging.info("train shape %s, val shape %s, test shape %s", X_train.shape, X_val.shape, X_test.shape)

model_lgb = LGBMClassifier(n_estimators=2000, n_jobs=-1, objective='binary', seed=1000, silent=True)
model_lgb.fit(X_train, y_train,
              eval_metric=['logloss', 'auc'],
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=50)
# Out:
# s binary_logloss: 0.306385
# [1488]	valid_0's auc: 0.880053	valid_0's binary_logloss: 0.306385
# [1489]	valid_0's auc: 0.880055	valid_0's binary_logloss: 0.306383
# [1490]	valid_0's auc: 0.88006	valid_0's binary_logloss: 0.306376
# [1491]	valid_0's auc: 0.880061	valid_0's binary_logloss: 0.306376
# [1492]	valid_0's auc: 0.880064	valid_0's binary_logloss: 0.306373
# [1493]	valid_0's auc: 0.880064	valid_0's binary_logloss: 0.306373
# [1494]	valid_0's auc: 0.880067	valid_0's binary_logloss: 0.306368
# [1495]	valid_0's auc: 0.88007	valid_0's binary_logloss: 0.306365
# [1496]	valid_0's auc: 0.880074	valid_0's binary_logloss: 0.30636
# [1497]	valid_0's auc: 0.880082	valid_0's binary_logloss: 0.30635
# [1498]	valid_0's auc: 0.880086	valid_0's binary_logloss: 0.306346
# [1499]	valid_0's auc: 0.880092	valid_0's binary_logloss: 0.30634
# [1500]	valid_0's auc: 0.880093	valid_0's binary_logloss: 0.306339
# [1501]	valid_0's auc: 0.880096	valid_0's binary_logloss: 0.306336
# [1502]	valid_0's auc: 0.880099	valid_0's binary_logloss: 0.306331
# [1503]	valid_0's auc: 0.8801	valid_0's binary_logloss: 0.306331
# [1504]	valid_0's auc: 0.8801	valid_0's binary_logloss: 0.306331
# [1505]	valid_0's auc: 0.8801	valid_0's binary_logloss: 0.306331
# [1506]	valid_0's auc: 0.880105	valid_0's binary_logloss: 0.306324
# [1507]	valid_0's auc: 0.880113	valid_0's binary_logloss: 0.306316
# [1508]	valid_0's auc: 0.880119	valid_0's binary_logloss: 0.306308
# [1509]	valid_0's auc: 0.880122	valid_0's binary_logloss: 0.306305
# [1510]	valid_0's auc: 0.88013	valid_0's binary_logloss: 0.306295
# [1511]	valid_0's auc: 0.880146	valid_0's binary_logloss: 0.306277
# [1512]	valid_0's auc: 0.880155	valid_0's binary_logloss: 0.306268
# [1513]	valid_0's auc: 0.880161	valid_0's binary_logloss: 0.306261
# [1514]	valid_0's auc: 0.880169	valid_0's binary_logloss: 0.306254
# [1515]	valid_0's auc: 0.880171	valid_0's binary_logloss: 0.306252
# [1516]	valid_0's auc: 0.880172	valid_0's binary_logloss: 0.306251
# [1517]	valid_0's auc: 0.880173	valid_0's binary_logloss: 0.306249
# [1518]	valid_0's auc: 0.880174	valid_0's binary_logloss: 0.306247
# [1519]	valid_0's auc: 0.880175	valid_0's binary_logloss: 0.306246
# [1520]	valid_0's auc: 0.880179	valid_0's binary_logloss: 0.306243
# [1521]	valid_0's auc: 0.88018	valid_0's binary_logloss: 0.306242
# [1522]	valid_0's auc: 0.880181	valid_0's binary_logloss: 0.306241
# [1523]	valid_0's auc: 0.880182	valid_0's binary_logloss: 0.30624
# [1524]	valid_0's auc: 0.880185	valid_0's binary_logloss: 0.306236
# [1525]	valid_0's auc: 0.880194	valid_0's binary_logloss: 0.306228
# [1526]	valid_0's auc: 0.880196	valid_0's binary_logloss: 0.306226
# [1527]	valid_0's auc: 0.880199	valid_0's binary_logloss: 0.306222
# [1528]	valid_0's auc: 0.880208	valid_0's binary_logloss: 0.306213
# [1529]	valid_0's auc: 0.880207	valid_0's binary_logloss: 0.306213
# [1530]	valid_0's auc: 0.880208	valid_0's binary_logloss: 0.306211
# [1531]	valid_0's auc: 0.880209	valid_0's binary_logloss: 0.30621
# [1532]	valid_0's auc: 0.88021	valid_0's binary_logloss: 0.306208
# [1533]	valid_0's auc: 0.880213	valid_0's binary_logloss: 0.306204
# [1534]	valid_0's auc: 0.880213	valid_0's binary_logloss: 0.306204
# [1535]	valid_0's auc: 0.880214	valid_0's binary_logloss: 0.306203
# [1536]	valid_0's auc: 0.880216	valid_0's binary_logloss: 0.306201
# [1537]	valid_0's auc: 0.880223	valid_0's binary_logloss: 0.306194
# [1538]	valid_0's auc: 0.880224	valid_0's binary_logloss: 0.306194
# [1539]	valid_0's auc: 0.880228	valid_0's binary_logloss: 0.30619
# [1540]	valid_0's auc: 0.880231	valid_0's binary_logloss: 0.306187
# [1541]	valid_0's auc: 0.880232	valid_0's binary_logloss: 0.306185
# [1542]	valid_0's auc: 0.880234	valid_0's binary_logloss: 0.306246
# [1543]	valid_0's auc: 0.880228	valid_0's binary_logloss: 0.306353
# [1544]	valid_0's auc: 0.880239	valid_0's binary_logloss: 0.306179
# [1545]	valid_0's auc: 0.880244	valid_0's binary_logloss: 0.306173
# [1546]	valid_0's auc: 0.880242	valid_0's binary_logloss: 0.3062
# [1547]	valid_0's auc: 0.880252	valid_0's binary_logloss: 0.306189
# [1548]	valid_0's auc: 0.880257	valid_0's binary_logloss: 0.306184
# [1549]	valid_0's auc: 0.880264	valid_0's binary_logloss: 0.306176
# [1550]	valid_0's auc: 0.880274	valid_0's binary_logloss: 0.306166
# [1551]	valid_0's auc: 0.880287	valid_0's binary_logloss: 0.306154
# [1552]	valid_0's auc: 0.880291	valid_0's binary_logloss: 0.306148
# [1553]	valid_0's auc: 0.880295	valid_0's binary_logloss: 0.306143
# [1554]	valid_0's auc: 0.880299	valid_0's binary_logloss: 0.306138
# [1555]	valid_0's auc: 0.880305	valid_0's binary_logloss: 0.306131
# [1556]	valid_0's auc: 0.880307	valid_0's binary_logloss: 0.306129
# [1557]	valid_0's auc: 0.880307	valid_0's binary_logloss: 0.306129
# [1558]	valid_0's auc: 0.880307	valid_0's binary_logloss: 0.306129
# [1559]	valid_0's auc: 0.880307	valid_0's binary_logloss: 0.306128
# [1560]	valid_0's auc: 0.88031	valid_0's binary_logloss: 0.306125
# [1561]	valid_0's auc: 0.880315	valid_0's binary_logloss: 0.306121
# [1562]	valid_0's auc: 0.880315	valid_0's binary_logloss: 0.306122
# [1563]	valid_0's auc: 0.880324	valid_0's binary_logloss: 0.306113
# [1564]	valid_0's auc: 0.880336	valid_0's binary_logloss: 0.306084
# [1565]	valid_0's auc: 0.880344	valid_0's binary_logloss: 0.306076
# [1566]	valid_0's auc: 0.880346	valid_0's binary_logloss: 0.306074
# [1567]	valid_0's auc: 0.880353	valid_0's binary_logloss: 0.306066
# [1568]	valid_0's auc: 0.880353	valid_0's binary_logloss: 0.306066
# [1569]	valid_0's auc: 0.880357	valid_0's binary_logloss: 0.30615
# [1570]	valid_0's auc: 0.880363	valid_0's binary_logloss: 0.306143
# [1571]	valid_0's auc: 0.880372	valid_0's binary_logloss: 0.306135
# [1572]	valid_0's auc: 0.880377	valid_0's binary_logloss: 0.306129
# [1573]	valid_0's auc: 0.880383	valid_0's binary_logloss: 0.306122
# [1574]	valid_0's auc: 0.880395	valid_0's binary_logloss: 0.30611
# [1575]	valid_0's auc: 0.880401	valid_0's binary_logloss: 0.306103
# [1576]	valid_0's auc: 0.880406	valid_0's binary_logloss: 0.306098
# [1577]	valid_0's auc: 0.880412	valid_0's binary_logloss: 0.306092
# [1578]	valid_0's auc: 0.880413	valid_0's binary_logloss: 0.306091
# [1579]	valid_0's auc: 0.880412	valid_0's binary_logloss: 0.306121
# [1580]	valid_0's auc: 0.88042	valid_0's binary_logloss: 0.306113
# [1581]	valid_0's auc: 0.880421	valid_0's binary_logloss: 0.306111
# [1582]	valid_0's auc: 0.880421	valid_0's binary_logloss: 0.306111
# [1583]	valid_0's auc: 0.880423	valid_0's binary_logloss: 0.306108
# [1584]	valid_0's auc: 0.880426	valid_0's binary_logloss: 0.306105
# [1585]	valid_0's auc: 0.880431	valid_0's binary_logloss: 0.306099
# [1586]	valid_0's auc: 0.880432	valid_0's binary_logloss: 0.306097
# [1587]	valid_0's auc: 0.880436	valid_0's binary_logloss: 0.306092
# [1588]	valid_0's auc: 0.880435	valid_0's binary_logloss: 0.306093
# [1589]	valid_0's auc: 0.880438	valid_0's binary_logloss: 0.30609
# [1590]	valid_0's auc: 0.880438	valid_0's binary_logloss: 0.306089
# [1591]	valid_0's auc: 0.880432	valid_0's binary_logloss: 0.306358
# [1592]	valid_0's auc: 0.880442	valid_0's binary_logloss: 0.306091
# [1593]	valid_0's auc: 0.880443	valid_0's binary_logloss: 0.306089
# [1594]	valid_0's auc: 0.880445	valid_0's binary_logloss: 0.306058
# [1595]	valid_0's auc: 0.880448	valid_0's binary_logloss: 0.306049
# [1596]	valid_0's auc: 0.880449	valid_0's binary_logloss: 0.306048
# [1597]	valid_0's auc: 0.880449	valid_0's binary_logloss: 0.306048
# [1598]	valid_0's auc: 0.880449	valid_0's binary_logloss: 0.306052
# [1599]	valid_0's auc: 0.880446	valid_0's binary_logloss: 0.306169
# [1600]	valid_0's auc: 0.880448	valid_0's binary_logloss: 0.306167
# [1601]	valid_0's auc: 0.880452	valid_0's binary_logloss: 0.306144
# [1602]	valid_0's auc: 0.880458	valid_0's binary_logloss: 0.306092
# [1603]	valid_0's auc: 0.88046	valid_0's binary_logloss: 0.306073
# [1604]	valid_0's auc: 0.880463	valid_0's binary_logloss: 0.306091
# [1605]	valid_0's auc: 0.880472	valid_0's binary_logloss: 0.305976
# [1606]	valid_0's auc: 0.88048	valid_0's binary_logloss: 0.305965
# [1607]	valid_0's auc: 0.880483	valid_0's binary_logloss: 0.306052
# [1608]	valid_0's auc: 0.880485	valid_0's binary_logloss: 0.306016
# [1609]	valid_0's auc: 0.880488	valid_0's binary_logloss: 0.306012
# [1610]	valid_0's auc: 0.880492	valid_0's binary_logloss: 0.306007
# [1611]	valid_0's auc: 0.880492	valid_0's binary_logloss: 0.306006
# [1612]	valid_0's auc: 0.880495	valid_0's binary_logloss: 0.306002
# [1613]	valid_0's auc: 0.880498	valid_0's binary_logloss: 0.305962
# [1614]	valid_0's auc: 0.880501	valid_0's binary_logloss: 0.305993
# [1615]	valid_0's auc: 0.880503	valid_0's binary_logloss: 0.305993
# [1616]	valid_0's auc: 0.880502	valid_0's binary_logloss: 0.305993
# [1617]	valid_0's auc: 0.880505	valid_0's binary_logloss: 0.305987
# [1618]	valid_0's auc: 0.880506	valid_0's binary_logloss: 0.305986
# [1619]	valid_0's auc: 0.880507	valid_0's binary_logloss: 0.305985
# [1620]	valid_0's auc: 0.880508	valid_0's binary_logloss: 0.305985
# [1621]	valid_0's auc: 0.880505	valid_0's binary_logloss: 0.306092
# [1622]	valid_0's auc: 0.880505	valid_0's binary_logloss: 0.306092
# [1623]	valid_0's auc: 0.880505	valid_0's binary_logloss: 0.30611
# [1624]	valid_0's auc: 0.880504	valid_0's binary_logloss: 0.306181
# [1625]	valid_0's auc: 0.880506	valid_0's binary_logloss: 0.30612
# [1626]	valid_0's auc: 0.880507	valid_0's binary_logloss: 0.306066
# [1627]	valid_0's auc: 0.880503	valid_0's binary_logloss: 0.306201
# [1628]	valid_0's auc: 0.880512	valid_0's binary_logloss: 0.306062
# [1629]	valid_0's auc: 0.880517	valid_0's binary_logloss: 0.306058
# [1630]	valid_0's auc: 0.880526	valid_0's binary_logloss: 0.306046
# [1631]	valid_0's auc: 0.880534	valid_0's binary_logloss: 0.306035
# [1632]	valid_0's auc: 0.880535	valid_0's binary_logloss: 0.306034
# [1633]	valid_0's auc: 0.880543	valid_0's binary_logloss: 0.306027
# [1634]	valid_0's auc: 0.880547	valid_0's binary_logloss: 0.306023
# [1635]	valid_0's auc: 0.880553	valid_0's binary_logloss: 0.306015
# [1636]	valid_0's auc: 0.880553	valid_0's binary_logloss: 0.306015
# [1637]	valid_0's auc: 0.880553	valid_0's binary_logloss: 0.306015
# [1638]	valid_0's auc: 0.88056	valid_0's binary_logloss: 0.306006
# [1639]	valid_0's auc: 0.880568	valid_0's binary_logloss: 0.305998
# [1640]	valid_0's auc: 0.88057	valid_0's binary_logloss: 0.305996
# [1641]	valid_0's auc: 0.880572	valid_0's binary_logloss: 0.305994
# [1642]	valid_0's auc: 0.880575	valid_0's binary_logloss: 0.30599
# [1643]	valid_0's auc: 0.880581	valid_0's binary_logloss: 0.305983
# [1644]	valid_0's auc: 0.880582	valid_0's binary_logloss: 0.305982
# [1645]	valid_0's auc: 0.880586	valid_0's binary_logloss: 0.305978
# [1646]	valid_0's auc: 0.880586	valid_0's binary_logloss: 0.305977
# [1647]	valid_0's auc: 0.880595	valid_0's binary_logloss: 0.305968
# [1648]	valid_0's auc: 0.880595	valid_0's binary_logloss: 0.305968
# [1649]	valid_0's auc: 0.880598	valid_0's binary_logloss: 0.305964
# [1650]	valid_0's auc: 0.880601	valid_0's binary_logloss: 0.30596
# [1651]	valid_0's auc: 0.880605	valid_0's binary_logloss: 0.305955
# [1652]	valid_0's auc: 0.880607	valid_0's binary_logloss: 0.305952
# [1653]	valid_0's auc: 0.880611	valid_0's binary_logloss: 0.305948
# [1654]	valid_0's auc: 0.880613	valid_0's binary_logloss: 0.305945
# [1655]	valid_0's auc: 0.880615	valid_0's binary_logloss: 0.305943
# [1656]	valid_0's auc: 0.880624	valid_0's binary_logloss: 0.305933
# [1657]	valid_0's auc: 0.88063	valid_0's binary_logloss: 0.305927
# [1658]	valid_0's auc: 0.880631	valid_0's binary_logloss: 0.305926
# [1659]	valid_0's auc: 0.880633	valid_0's binary_logloss: 0.305924
# [1660]	valid_0's auc: 0.880637	valid_0's binary_logloss: 0.305918
# [1661]	valid_0's auc: 0.880641	valid_0's binary_logloss: 0.305914
# [1662]	valid_0's auc: 0.880642	valid_0's binary_logloss: 0.305911
# [1663]	valid_0's auc: 0.880655	valid_0's binary_logloss: 0.305898
# [1664]	valid_0's auc: 0.880659	valid_0's binary_logloss: 0.305892
# [1665]	valid_0's auc: 0.880663	valid_0's binary_logloss: 0.305886
# [1666]	valid_0's auc: 0.880668	valid_0's binary_logloss: 0.305881
# [1667]	valid_0's auc: 0.880668	valid_0's binary_logloss: 0.30588
# [1668]	valid_0's auc: 0.880668	valid_0's binary_logloss: 0.30588
# [1669]	valid_0's auc: 0.880671	valid_0's binary_logloss: 0.305877
# [1670]	valid_0's auc: 0.880673	valid_0's binary_logloss: 0.305875
# [1671]	valid_0's auc: 0.880679	valid_0's binary_logloss: 0.305868
# [1672]	valid_0's auc: 0.880685	valid_0's binary_logloss: 0.305862
# [1673]	valid_0's auc: 0.880685	valid_0's binary_logloss: 0.305862
# [1674]	valid_0's auc: 0.880693	valid_0's binary_logloss: 0.305853
# [1675]	valid_0's auc: 0.880702	valid_0's binary_logloss: 0.305844
# [1676]	valid_0's auc: 0.880705	valid_0's binary_logloss: 0.30584
# [1677]	valid_0's auc: 0.880711	valid_0's binary_logloss: 0.305833
# [1678]	valid_0's auc: 0.880715	valid_0's binary_logloss: 0.305828
# [1679]	valid_0's auc: 0.880717	valid_0's binary_logloss: 0.305826
# [1680]	valid_0's auc: 0.88072	valid_0's binary_logloss: 0.305823
# [1681]	valid_0's auc: 0.880721	valid_0's binary_logloss: 0.305822
# [1682]	valid_0's auc: 0.880721	valid_0's binary_logloss: 0.305822
# [1683]	valid_0's auc: 0.880721	valid_0's binary_logloss: 0.305822
# [1684]	valid_0's auc: 0.88072	valid_0's binary_logloss: 0.305823
# [1685]	valid_0's auc: 0.880729	valid_0's binary_logloss: 0.305814
# [1686]	valid_0's auc: 0.880734	valid_0's binary_logloss: 0.305809
# [1687]	valid_0's auc: 0.880738	valid_0's binary_logloss: 0.305805
# [1688]	valid_0's auc: 0.880743	valid_0's binary_logloss: 0.305798
# [1689]	valid_0's auc: 0.880744	valid_0's binary_logloss: 0.305799
# [1690]	valid_0's auc: 0.880739	valid_0's binary_logloss: 0.305951
# [1691]	valid_0's auc: 0.880738	valid_0's binary_logloss: 0.305961
# [1692]	valid_0's auc: 0.880742	valid_0's binary_logloss: 0.305957
# [1693]	valid_0's auc: 0.880746	valid_0's binary_logloss: 0.305952
# [1694]	valid_0's auc: 0.880749	valid_0's binary_logloss: 0.305949
# [1695]	valid_0's auc: 0.880757	valid_0's binary_logloss: 0.305941
# [1696]	valid_0's auc: 0.880766	valid_0's binary_logloss: 0.305929
# [1697]	valid_0's auc: 0.880768	valid_0's binary_logloss: 0.305926
# [1698]	valid_0's auc: 0.880779	valid_0's binary_logloss: 0.305914
# [1699]	valid_0's auc: 0.880783	valid_0's binary_logloss: 0.30591
# [1700]	valid_0's auc: 0.880782	valid_0's binary_logloss: 0.305911
# [1701]	valid_0's auc: 0.880784	valid_0's binary_logloss: 0.305909
# [1702]	valid_0's auc: 0.880786	valid_0's binary_logloss: 0.305906
# [1703]	valid_0's auc: 0.880792	valid_0's binary_logloss: 0.305901
# [1704]	valid_0's auc: 0.8808	valid_0's binary_logloss: 0.305893
# [1705]	valid_0's auc: 0.8808	valid_0's binary_logloss: 0.305892
# [1706]	valid_0's auc: 0.880805	valid_0's binary_logloss: 0.305887
# [1707]	valid_0's auc: 0.88081	valid_0's binary_logloss: 0.30588
# [1708]	valid_0's auc: 0.880815	valid_0's binary_logloss: 0.305875
# [1709]	valid_0's auc: 0.880822	valid_0's binary_logloss: 0.305868
# [1710]	valid_0's auc: 0.880825	valid_0's binary_logloss: 0.305865
# [1711]	valid_0's auc: 0.880826	valid_0's binary_logloss: 0.305864
# [1712]	valid_0's auc: 0.880829	valid_0's binary_logloss: 0.305862
# [1713]	valid_0's auc: 0.88083	valid_0's binary_logloss: 0.305859
# [1714]	valid_0's auc: 0.880838	valid_0's binary_logloss: 0.305851
# [1715]	valid_0's auc: 0.880839	valid_0's binary_logloss: 0.305849
# [1716]	valid_0's auc: 0.880845	valid_0's binary_logloss: 0.305843
# [1717]	valid_0's auc: 0.880853	valid_0's binary_logloss: 0.305836
# [1718]	valid_0's auc: 0.880853	valid_0's binary_logloss: 0.305836
# [1719]	valid_0's auc: 0.880853	valid_0's binary_logloss: 0.305835
# [1720]	valid_0's auc: 0.880854	valid_0's binary_logloss: 0.305835
# [1721]	valid_0's auc: 0.880856	valid_0's binary_logloss: 0.305832
# [1722]	valid_0's auc: 0.880859	valid_0's binary_logloss: 0.30583
# [1723]	valid_0's auc: 0.880858	valid_0's binary_logloss: 0.30583
# [1724]	valid_0's auc: 0.88087	valid_0's binary_logloss: 0.305818
# [1725]	valid_0's auc: 0.880872	valid_0's binary_logloss: 0.305816
# [1726]	valid_0's auc: 0.880877	valid_0's binary_logloss: 0.305811
# [1727]	valid_0's auc: 0.880878	valid_0's binary_logloss: 0.305809
# [1728]	valid_0's auc: 0.880884	valid_0's binary_logloss: 0.305801
# [1729]	valid_0's auc: 0.880889	valid_0's binary_logloss: 0.305797
# [1730]	valid_0's auc: 0.880895	valid_0's binary_logloss: 0.30579
# [1731]	valid_0's auc: 0.880902	valid_0's binary_logloss: 0.305782
# [1732]	valid_0's auc: 0.880907	valid_0's binary_logloss: 0.305774
# [1733]	valid_0's auc: 0.880908	valid_0's binary_logloss: 0.305773
# [1734]	valid_0's auc: 0.880914	valid_0's binary_logloss: 0.305768
# [1735]	valid_0's auc: 0.880914	valid_0's binary_logloss: 0.305767
# [1736]	valid_0's auc: 0.880913	valid_0's binary_logloss: 0.305768
# [1737]	valid_0's auc: 0.880913	valid_0's binary_logloss: 0.305767
# [1738]	valid_0's auc: 0.880915	valid_0's binary_logloss: 0.305765
# [1739]	valid_0's auc: 0.880916	valid_0's binary_logloss: 0.305764
# [1740]	valid_0's auc: 0.880915	valid_0's binary_logloss: 0.305765
# [1741]	valid_0's auc: 0.880914	valid_0's binary_logloss: 0.305766
# [1742]	valid_0's auc: 0.880916	valid_0's binary_logloss: 0.305845
# [1743]	valid_0's auc: 0.880903	valid_0's binary_logloss: 0.30619
# [1744]	valid_0's auc: 0.880909	valid_0's binary_logloss: 0.306033
# [1745]	valid_0's auc: 0.880914	valid_0's binary_logloss: 0.305933
# [1746]	valid_0's auc: 0.880917	valid_0's binary_logloss: 0.305929
# [1747]	valid_0's auc: 0.880916	valid_0's binary_logloss: 0.305929
# [1748]	valid_0's auc: 0.880917	valid_0's binary_logloss: 0.305929
# [1749]	valid_0's auc: 0.880925	valid_0's binary_logloss: 0.305918
# [1750]	valid_0's auc: 0.880939	valid_0's binary_logloss: 0.305903
# [1751]	valid_0's auc: 0.880945	valid_0's binary_logloss: 0.305898
# [1752]	valid_0's auc: 0.880951	valid_0's binary_logloss: 0.305875
# [1753]	valid_0's auc: 0.880956	valid_0's binary_logloss: 0.30587
# [1754]	valid_0's auc: 0.880964	valid_0's binary_logloss: 0.305861
# [1755]	valid_0's auc: 0.880972	valid_0's binary_logloss: 0.305845
# [1756]	valid_0's auc: 0.880974	valid_0's binary_logloss: 0.305844
# [1757]	valid_0's auc: 0.880979	valid_0's binary_logloss: 0.305839
# [1758]	valid_0's auc: 0.880979	valid_0's binary_logloss: 0.30603
# [1759]	valid_0's auc: 0.88098	valid_0's binary_logloss: 0.305993
# [1760]	valid_0's auc: 0.880985	valid_0's binary_logloss: 0.305988
# [1761]	valid_0's auc: 0.880985	valid_0's binary_logloss: 0.306085
# [1762]	valid_0's auc: 0.880975	valid_0's binary_logloss: 0.306226
# [1763]	valid_0's auc: 0.880974	valid_0's binary_logloss: 0.306349
# [1764]	valid_0's auc: 0.880987	valid_0's binary_logloss: 0.305971
# [1765]	valid_0's auc: 0.880987	valid_0's binary_logloss: 0.305971
# [1766]	valid_0's auc: 0.880989	valid_0's binary_logloss: 0.305968
# [1767]	valid_0's auc: 0.880993	valid_0's binary_logloss: 0.305963
# [1768]	valid_0's auc: 0.880993	valid_0's binary_logloss: 0.305963
# [1769]	valid_0's auc: 0.880994	valid_0's binary_logloss: 0.305962
# [1770]	valid_0's auc: 0.880993	valid_0's binary_logloss: 0.305963
# [1771]	valid_0's auc: 0.880998	valid_0's binary_logloss: 0.305958
# [1772]	valid_0's auc: 0.880997	valid_0's binary_logloss: 0.305959
# [1773]	valid_0's auc: 0.880997	valid_0's binary_logloss: 0.305959
# [1774]	valid_0's auc: 0.880998	valid_0's binary_logloss: 0.305959
# [1775]	valid_0's auc: 0.881	valid_0's binary_logloss: 0.305957
# [1776]	valid_0's auc: 0.881005	valid_0's binary_logloss: 0.305916
# [1777]	valid_0's auc: 0.880998	valid_0's binary_logloss: 0.306129
# [1778]	valid_0's auc: 0.88101	valid_0's binary_logloss: 0.305815
# [1779]	valid_0's auc: 0.881014	valid_0's binary_logloss: 0.30581
# [1780]	valid_0's auc: 0.881017	valid_0's binary_logloss: 0.305778
# [1781]	valid_0's auc: 0.88102	valid_0's binary_logloss: 0.305775
# [1782]	valid_0's auc: 0.881019	valid_0's binary_logloss: 0.305776
# [1783]	valid_0's auc: 0.881019	valid_0's binary_logloss: 0.305776
# [1784]	valid_0's auc: 0.881021	valid_0's binary_logloss: 0.305773
# [1785]	valid_0's auc: 0.881022	valid_0's binary_logloss: 0.305773
# [1786]	valid_0's auc: 0.881024	valid_0's binary_logloss: 0.305791
# [1787]	valid_0's auc: 0.881023	valid_0's binary_logloss: 0.305792
# [1788]	valid_0's auc: 0.881024	valid_0's binary_logloss: 0.305792
# [1789]	valid_0's auc: 0.881024	valid_0's binary_logloss: 0.305791
# Early stopping, best iteration is:
# [1739]	valid_0's auc: 0.880916	valid_0's binary_logloss: 0.305764
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=2000, n_jobs=-1, num_leaves=31, objective='binary',
#                random_state=None, reg_alpha=0.0, reg_lambda=0.0, seed=1000,
#                silent=True, subsample=1.0, subsample_for_bin=200000,
#                subsample_freq=0)

# %%
# sub = pd.read_csv(f'{base_path}/invite_info_evaluate_0926.txt', sep='\t', header=None)
# sub.columns = ['qid', 'uid', 'dt']
sub['label'] = model_lgb.predict_proba(X_test[feature_cols])[:, 1]

# %%
sub.to_csv('./result/submit_%.6f.txt' % (model_lgb.best_score_['valid_0']['auc']), index=None, header=None, sep='\t')

# %%
fi = pd.DataFrame({'feature': feature_cols, 'imp': model_lgb.feature_importances_})
fi['rate'] = fi['imp'] / fi['imp'].sum()
fi
# Out:
#                             feature  imp      rate
# 0                       diff_iq_day  150  0.002875
# 1                      diff_iq_hour  489  0.009373
# 2                              freq  153  0.002933
# 3                            gender   96  0.001840
# 4                              hour  909  0.017424
# 5             intersection_ft_count  205  0.003929
# 6             intersection_it_count   59  0.001131
# 7             intersection_it_score  176  0.003374
# 8                 q_ans_kfold_count  550  0.010542
# 9                q_diff_qa_days_max  518  0.009929
# 10              q_diff_qa_days_mean  639  0.012248
# 11               q_diff_qa_days_sum  491  0.009412
# 12                   q_has_img_mean  253  0.004850
# 13                           q_hour  220  0.004217
# 14                q_inv_kfold_count  379  0.007265
# 15                 q_inv_kfold_mean  448  0.008587
# 16                  q_inv_kfold_std  307  0.005885
# 17                  q_inv_kfold_sum  261  0.005003
# 18                q_reci_cheer_mean  266  0.005099
# 19                 q_reci_cheer_sum  194  0.003719
# 20              q_reci_comment_mean  216  0.004140
# 21                  q_reci_dis_mean  151  0.002894
# 22                 q_reci_mark_mean  143  0.002741
# 23                  q_reci_tks_mean  158  0.003029
# 24                           q_week  184  0.003527
# 25                 q_word_count_max  259  0.004965
# 26                q_word_count_mean  493  0.009450
# 27                 q_word_count_sum  289  0.005540
# 28                    qid_day_count  549  0.010523
# 29             qid_diff_day_daymean  588  0.011271
# ..                              ...  ...       ...
# 142                 day_uf_b5_count  243  0.004658
# 143                 day_uf_c1_count  140  0.002684
# 144                 day_uf_c2_count  104  0.001993
# 145                 day_uf_c3_count  160  0.003067
# 146                 day_uf_c4_count  154  0.002952
# 147                 day_uf_c5_count  316  0.006057
# 148                day_q_hour_count  386  0.007399
# 149                    day_wk_count  892  0.017098
# 150                day_q_week_count  403  0.007725
# 151           day_diff_iq_day_count  661  0.012670
# 152          day_diff_iq_hour_count  813  0.015584
# 153                  day_hour_count  860  0.016485
# 154          diff_iq_day_freq_count  246  0.004715
# 155        diff_iq_day_gender_count  126  0.002415
# 156         diff_iq_day_score_count  422  0.008089
# 157         diff_iq_day_uf_b1_count   73  0.001399
# 158         diff_iq_day_uf_b2_count   65  0.001246
# 159         diff_iq_day_uf_b3_count   77  0.001476
# 160         diff_iq_day_uf_b4_count  111  0.002128
# 161         diff_iq_day_uf_b5_count   65  0.001246
# 162         diff_iq_day_uf_c1_count  121  0.002319
# 163         diff_iq_day_uf_c2_count   81  0.001553
# 164         diff_iq_day_uf_c3_count  146  0.002799
# 165         diff_iq_day_uf_c4_count  116  0.002224
# 166         diff_iq_day_uf_c5_count   99  0.001898
# 167        diff_iq_day_q_hour_count  329  0.006306
# 168            diff_iq_day_wk_count  319  0.006115
# 169        diff_iq_day_q_week_count    0  0.000000
# 170  diff_iq_day_diff_iq_hour_count  177  0.003393
# 171          diff_iq_day_hour_count  789  0.015124
#
# [172 rows x 3 columns]

# %%
fi.sort_values(by='rate', ascending=False)[-30:]
# Out:
#                       feature  imp      rate
# 119       qid_enc_uf_c4_count   81  0.001553
# 159   diff_iq_day_uf_b3_count   77  0.001476
# 106               uf_c4_count   76  0.001457
# 122      qid_enc_q_hour_count   73  0.001399
# 157   diff_iq_day_uf_b1_count   73  0.001399
# 34   qid_diff_week_weekmedian   72  0.001380
# 86   uid_diff_week_weekmedian   71  0.001361
# 103               uf_c1_count   71  0.001361
# 131      uid_enc_q_week_count   66  0.001265
# 96            uid_week_median   66  0.001265
# 161   diff_iq_day_uf_b5_count   65  0.001246
# 158   diff_iq_day_uf_b2_count   65  0.001246
# 6       intersection_it_count   59  0.001131
# 128        uid_enc_hour_count   58  0.001112
# 123          qid_enc_wk_count   56  0.001073
# 111       qid_enc_uf_b1_count   49  0.000939
# 113       qid_enc_uf_b3_count   44  0.000843
# 130          uid_enc_wk_count   40  0.000767
# 104               uf_c2_count   34  0.000652
# 129      uid_enc_q_hour_count   33  0.000633
# 112       qid_enc_uf_b2_count   31  0.000594
# 115       qid_enc_uf_b5_count   26  0.000498
# 74                      uf_b4   19  0.000364
# 124      qid_enc_q_week_count    9  0.000173
# 79                      uf_c5    9  0.000173
# 72                      uf_b2    5  0.000096
# 71                      uf_b1    4  0.000077
# 73                      uf_b3    1  0.000019
# 101              gender_count    0  0.000000
# 169  diff_iq_day_q_week_count    0  0.000000

# %%
print(np.min(t1))
print( model_lgb.best_score_['valid_0']['auc'])
print([feat for feat in data.keys() if ((feat[-6:] != '_count') & (feat[-7:] != '_psd_lb') & (feat[-4:] != '_max') & (feat[-4:] != '_min') & (feat[-4:] != '_sum') 
                                      & (feat[-4:] != '_std') & (feat[-6:] != 'median') 
                                      & (feat[-4:] != 'mean'))])
# Out:
# freq  gender  score  uf_b1  uf_b2  uf_b3  uf_b4  uf_b5  \
# diff_iq_day hour
# -32         12       0       0    461      0      0      0      0      0
#             16       0       0    448      0      0      0      0      0
# -26         2        0       0    260      0      0      0      0      0
# -20         14       0       0    820      0      1      0      1      0
#             23       0       0    590      0      0      0      0      0
# -18         12       4       1    287      1      0      0      0      0
#             17       0       1    601      0      0      0      1      0
#             20       0       0    359      0      0      0      0      0
#             21       0       1    344      1      1      0      0      0
# -16         17       4       0    300      0      0      0      0      0
#             19       4       2    320      1      0      0      0      0
# -15         11       4       0    411      1      0      0      0      0
# -14         8        4       1    442      1      0      0      0      0
#             9        0       0    470      0      0      0      0      0
#             10       0       0    546      0      0      0      1      0
# -13         8        0       1    560      1      0      0      0      0
#             10       0       1    448      0      0      0      0      0
#             11       0       2    346      1      0      0      0      0
#             12       0       0    369      0      0      0      0      0
#             16       0       1    451      1      0      0      0      0
#             19       4       2    347      1      0      0      0      0
# -12         11       0       0    405      0      0      0      0      0
# -11         13       0       2    593      1      0      0      1      0
# -9          23       0       1    419      0      0      0      0      0
# -2          9        0       1    616      1      0      0      0      0
#             14       0       0    480      1      0      0      0      0
#  0          0        0       0    209      0      0      0      0      0
#             1        0       0    217      0      0      0      0      0
#             2        0       0    230      0      0      0      0      0
#             3        0       0    182      0      0      0      0      0
# ...                ...     ...    ...    ...    ...    ...    ...    ...
#  2993       23       0       2    390      1      0      0      0      0
#  2994       7        0       1    611      0      1      0      1      0
#  2995       17       0       0    625      0      0      0      1      0
#  2997       0        4       1    711      1      0      0      0      0
#             13       0       1    730      1      0      0      0      0
#             14       0       1    627      1      0      0      0      0
#  2998       13       0       0    429      1      0      0      0      0
#  3002       15       0       1    565      1      0      0      1      0
#  3003       15       4       0    546      1      0      0      0      0
#  3008       21       0       0    544      0      0      0      1      0
#  3014       16       4       1    526      1      0      0      1      0
#  3018       22       0       0    448      0      0      0      0      0
#  3024       21       0       2    400      1      0      0      1      0
#  3025       9        0       0    340      0      0      0      0      0
#             16       4       1    558      1      0      0      1      0
#  3027       19       4       2    261      1      0      0      0      0
#  3028       11       0       2    394      1      0      0      1      0
#  3032       16       0       1    642      1      0      0      1      0
#  3040       13       0       1    553      1      0      0      1      0
#             21       4       1    438      0      1      0      1      0
#  3051       10       0       0    576      1      0      0      1      1
#             14       0       1    714      1      1      0      1      0
#  3052       6        4       1    543      1      0      0      0      0
#  3060       0        0       1    462      0      0      0      0      0
#  3068       7        0       0    569      0      0      0      0      0
#             10       0       2    429      1      0      0      0      0
#  3078       14       0       0    470      0      0      0      1      0
#  3096       8        0       0    596      0      0      0      1      0
#  3101       13       0       1    632      1      0      0      0      0
#  3106       22       0       1    663      1      0      0      1      1
#
#                   uf_c1  uf_c2  uf_c3  uf_c4  uf_c5  q_hour  wk  q_week  \
# diff_iq_day hour
# -32         12     1190    130    181   1186      0      12   3       0
#             16     1190    130    266    750      0       8   3       0
# -26         2       294    130    181    818      1       3   1       6
# -20         14     1636    190    188    815      1       0   4       3
#             23      480     48    124     63      1       0   4       3
# -18         12     1427     31    119    758      1      17   5       2
#             17     1190    130      6    758      1      17   2       6
#             20      411     48      6    758      1      17   5       2
#             21     1190    130    396   1438      1      17   5       2
# -16         17     1190    130      0    555      1      17   0       2
#             19     1190    130    119    758      1      17   0       2
# -15         11     1190    130    167    621      1      17   1       2
# -14         8      1190    130    394    758      1      17   2       2
#             9      1190     48      6    420      1       4   6       6
#             10     1190    130    261    758      1       4   6       6
# -13         8      1190    130    275     26      1      17   3       2
#             10       68    130      6    530      1      22   2       1
#             11     1190    130      0    531      1      17   3       2
#             12      192     48      0    478      0      22   2       1
#             16     1002    232    234    758      0      17   3       2
#             19     1190    130     32    758      0      17   3       2
# -12         11     1190     48      0    219      1      17   4       2
# -11         13      223    282      6   1373      1      13   6       3
# -9          23      875    130     38    758      0      11   3       5
# -2          9       890    185    311   1412      1      14   3       5
#             14     1190     31    186    758      1       0   3       5
#  0          0         5      4      0      0      0       0   0       0
#             1         5      8      0      0      0       0   0       0
#             2         5      8      0      0      0       0   0       0
#             3         5      8      0      0      0       0   0       0
# ...                 ...    ...    ...    ...    ...     ...  ..     ...
#  2993       23     1790    271    183     70      1       0   5       1
#  2994       7       381    190      0    478      1       1   4       6
#  2995       17      661    130     73    758      1      22   0       1
#  2997       0      1190    130      6    758      1       0   2       1
#             13     1190    130      0   1408      1       0   2       1
#             14     1190    130      6    758      1      22   3       2
#  2998       13     1190    130      0    478      1      13   5       3
#  3002       15      704    130    167    420      1      22   0       1
#  3003       15     1190    130      0    961      1      13   3       3
#  3008       21     1190    130      6    927      1       0   2       4
#  3014       16     1190    130    237    864      1       8   3       6
#  3018       22     1190    113      6    905      1      18   1       0
#  3024       21     1683    139    119    758      0       9   3       3
#  3025       9       381     48      6    268      0       9   4       3
#             16     2161     31    275     26      1      22   1       0
#  3027       19     1190    130    181     15      1      20   0       4
#  3028       11      875    232    394    758      1      20   1       4
#  3032       16      688    113     14    758      1      11   2       1
#  3040       13     1190    130      0    758      1       0   5       3
#             21     1539    190    237    864      1       0   5       3
#  3051       10     1190    130    202    905      1      14   0       1
#             14     1190    130    119    758      1      20   0       1
#  3052       6      1519    229    183    596      1      20   1       1
#  3060       0       779    130    119    596      0      10   2       1
#  3068       7        68     34      6     26      1      19   3       1
#             10     1190    130    275   1211      0      21   1       6
#  3078       14     1002     34     54    758      1      22   1       3
#  3096       8      1190    130    186   1438      1      11   1       6
#  3101       13     1190    130    275    693      1       0   6       6
#  3106       22      744    113    237    864      1      23   6       1
#
#                   diff_iq_hour
# diff_iq_day hour
# -32         12            -768
#             16            -760
# -26         2             -625
# -20         14            -466
#             23            -457
# -18         12            -437
#             17            -432
#             20            -429
#             21            -428
# -16         17            -384
#             19            -382
# -15         11            -366
# -14         8             -345
#             9             -331
#             10            -330
# -13         8             -321
#             10            -324
#             11            -318
#             12            -322
#             16            -313
#             19            -310
# -12         11            -294
# -11         13            -264
# -9          23            -204
# -2          9              -53
#             14             -34
#  0          0                0
#             1                0
#             2                0
#             3                0
# ...                        ...
#  2993       23           71855
#  2994       7            71862
#  2995       17           71875
#  2997       0            71928
#             13           71941
#             14           71920
#  2998       13           71952
#  3002       15           72041
#  3003       15           72074
#  3008       21           72213
#  3014       16           72344
#  3018       22           72436
#  3024       21           72588
#  3025       9            72600
#             16           72594
#  3027       19           72647
#  3028       11           72663
#  3032       16           72773
#  3040       13           72973
#             21           72981
#  3051       10           73220
#             14           73218
#  3052       6            73234
#  3060       0            73430
#  3068       7            73620
#             10           73621
#  3078       14           73864
#  3096       8            74301
#  3101       13           74437
#  3106       22           74543
#
# [32065 rows x 17 columns]
# 0.8809158134696727
# ['day', 'diff_iq_day', 'diff_iq_hour', 'freq', 'gender', 'hour', 'intersection_it_score', 'label', 'q_hour', 'q_week', 'qid', 'qid_enc', 'score', 'uf_b1', 'uf_b2', 'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'uid', 'uid_enc', 'wk']
