# %%
# -*- coding: utf-8 -*-


import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
import logging

# %%
log_fmt = "[%(asctime)s] %(levelname)s in %(module)s: %(message)s"
logging.basicConfig(format=log_fmt, level=logging.INFO)

import warnings
warnings.filterwarnings('ignore')


def extract_day(s):
    return s.apply(lambda x: int(x.split('-')[0][1:]))


def extract_hour(s):
    return s.apply(lambda x: int(x.split('-')[1][1:]))

# %%
base_path = './data'

# %%
# 加载邀请回答数据

train = pd.read_csv(f'{base_path}/invite_info_0926.txt', sep='\t', header=None)
train.columns = ['qid', 'uid', 'dt', 'label']
logging.info("invite %s", train.shape)

test = pd.read_csv(f'{base_path}/invite_info_evaluate_0926.txt', sep='\t', header=None)
test.columns = ['qid', 'uid', 'dt']
logging.info("test %s", test.shape)

sub = test.copy()

sub_size = len(sub)

train['day'] = extract_day(train['dt'])
train['hour'] = extract_hour(train['dt'])

test['day'] = extract_day(test['dt'])
test['hour'] = extract_hour(test['dt'])

del train['dt'], test['dt']
# Out:
# [2019-11-27 06:56:51,053] INFO in <ipython-input-71-d8d667ebe145>: invite (9489162, 4)
# [2019-11-27 06:56:54,180] INFO in <ipython-input-71-d8d667ebe145>: test (1141683, 3)

# %%
# 加载问题
ques = pd.read_csv(f'{base_path}/question_info_0926.txt', header=None, sep='\t')
ques.columns = ['qid', 'q_dt', 'title_t1', 'title_t2', 'desc_t1', 'desc_t2', 'topic']
del ques['title_t1'], ques['title_t2'], ques['desc_t1'], ques['desc_t2']
logging.info("ques %s", ques.shape)

ques['q_day'] = extract_day(ques['q_dt'])
ques['q_hour'] = extract_hour(ques['q_dt'])

del ques['q_dt']
# Out:
# [2019-11-27 06:58:36,395] INFO in <ipython-input-72-9063dae39e17>: ques (1829900, 3)

# %%
# 加载回答
ans = pd.read_csv(f'{base_path}/answer_info_0926.txt', header=None, sep='\t')
ans.columns = ['aid', 'qid', 'uid', 'ans_dt', 'ans_t1', 'ans_t2', 'is_good', 'is_rec', 'is_dest', 'has_img',
               'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
               'reci_xxx', 'reci_no_help', 'reci_dis']
del ans['ans_t1'], ans['ans_t2']
logging.info("ans %s", ans.shape)

ans['a_day'] = extract_day(ans['ans_dt'])
ans['a_hour'] = extract_hour(ans['ans_dt'])
del ans['ans_dt']

ans = pd.merge(ans, ques, on='qid', how='left')
del ques
# Out:
# [2019-11-27 07:00:31,188] INFO in <ipython-input-73-0f04b531e5be>: ans (4513735, 18)

# %%
ans.columns
# Out:
# Index(['aid', 'qid', 'uid', 'is_good', 'is_rec', 'is_dest', 'has_img',
#        'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment',
#        'reci_mark', 'reci_tks', 'reci_xxx', 'reci_no_help', 'reci_dis',
#        'a_day', 'a_hour', 'topic', 'q_day', 'q_hour'],
#       dtype='object')

# %%
# 回答距提问的天数
ans['diff_qa_days'] = ans['a_day'] - ans['q_day']

# %%
# 时间窗口划分
train_start = 3838
train_end = 3867

val_start = 3868
val_end = 3874

label_end = 3867
label_start = label_end - 6

train_label_feature_end = label_end - 7
train_label_feature_start = train_label_feature_end - 22

train_ans_feature_end = label_end - 7
train_ans_feature_start = train_ans_feature_end - 50

val_label_feature_end = val_start - 1
val_label_feature_start = val_label_feature_end - 22

val_ans_feature_end = val_start - 1
val_ans_feature_start = val_ans_feature_end - 50

# 3838~3860
train_label_feature = train[(train['day'] >= train_label_feature_start) & (train['day'] <= train_label_feature_end)]
logging.info("train_label_feature %s", train_label_feature.shape)

# 3845~3867
val_label_feature = train[(train['day'] >= val_label_feature_start) & (train['day'] <= val_label_feature_end)]
logging.info("val_label_feature %s", val_label_feature.shape)

# 3861~3867
train_label = train[(train['day'] > train_label_feature_end)]

logging.info("train feature start %s end %s, label start %s end %s", train_label_feature['day'].min(),
             train_label_feature['day'].max(), train_label['day'].min(), train_label['day'].max())

logging.info("test feature start %s end %s, label start %s end %s", val_label_feature['day'].min(),
             val_label_feature['day'].max(), test['day'].min(), test['day'].max())
# Out:
# [2019-11-27 07:01:13,895] INFO in <ipython-input-76-5d7f58c037fb>: train_label_feature (6895493, 5)
# [2019-11-27 07:01:14,879] INFO in <ipython-input-76-5d7f58c037fb>: val_label_feature (7583553, 5)
# [2019-11-27 07:01:15,389] INFO in <ipython-input-76-5d7f58c037fb>: train feature start 3838 end 3860, label start 3861 end 3867
# [2019-11-27 07:01:15,426] INFO in <ipython-input-76-5d7f58c037fb>: test feature start 3845 end 3867, label start 3868 end 3874

# %%
# ans的时间范围 3807~3874

# 3810~3860
train_ans_feature = ans[(ans['a_day'] >= train_ans_feature_start) & (ans['a_day'] <= train_ans_feature_end)]

# 3817~3867
val_ans_feature = ans[(ans['a_day'] >= val_ans_feature_start) & (ans['a_day'] <= val_ans_feature_end)]

logging.info("train ans feature %s, start %s end %s", train_ans_feature.shape, train_ans_feature['a_day'].min(),
             train_ans_feature['a_day'].max())

logging.info("val ans feature %s, start %s end %s", val_ans_feature.shape, val_ans_feature['a_day'].min(),
             val_ans_feature['a_day'].max())

fea_cols = ['is_good', 'is_rec', 'is_dest', 'has_img', 'has_video', 'word_count',
            'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
            'reci_xxx', 'reci_no_help', 'reci_dis', 'diff_qa_days']
# Out:
# [2019-11-27 07:01:21,180] INFO in <ipython-input-77-cc959fd6ea4e>: train ans feature (3828707, 23), start 3807 end 3860
# [2019-11-27 07:01:21,200] INFO in <ipython-input-77-cc959fd6ea4e>: val ans feature (4162522, 23), start 3814 end 3867

# %%
def extract_feature1(target, label_feature, ans_feature):
    # 问题特征
    t1 = label_feature.groupby('qid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['qid', 'q_inv_mean', 'q_inv_sum', 'q_inv_std', 'q_inv_count'] # 回答率,回答次数,标准差,邀请次数
    target = pd.merge(target, t1, on='qid', how='left')

    # 用户特征
    t1 = label_feature.groupby('uid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['uid', 'u_inv_mean', 'u_inv_sum', 'u_inv_std', 'u_inv_count']
    target = pd.merge(target, t1, on='uid', how='left')
    #
    # train_size = len(train)
    # data = pd.concat((train, test), sort=True)

    # 回答部分特征
    t1 = ans_feature.groupby('qid')['aid'].count().reset_index()
    t1.columns = ['qid', 'q_ans_count']          # 在 answer_info 中的回答次数
    target = pd.merge(target, t1, on='qid', how='left')

    t1 = ans_feature.groupby('uid')['aid'].count().reset_index()
    t1.columns = ['uid', 'u_ans_count']          # 在 answer_info 中的回答次数
    target = pd.merge(target, t1, on='uid', how='left')

    for col in fea_cols:
        t1 = ans_feature.groupby('uid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['uid', f'u_{col}_sum', f'u_{col}_max', f'u_{col}_mean']
        target = pd.merge(target, t1, on='uid', how='left')

        t1 = ans_feature.groupby('qid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['qid', f'q_{col}_sum', f'q_{col}_max', f'q_{col}_mean']
        target = pd.merge(target, t1, on='qid', how='left')
        logging.info("extract %s", col)
    return target

# %%
train_label = extract_feature1(train_label, train_label_feature, train_ans_feature)
test = extract_feature1(test, val_label_feature, val_ans_feature)
# Out:
# [2019-11-27 07:02:34,625] INFO in <ipython-input-78-0fafb00ac390>: extract is_good
# [2019-11-27 07:02:57,442] INFO in <ipython-input-78-0fafb00ac390>: extract is_rec
# [2019-11-27 07:03:21,116] INFO in <ipython-input-78-0fafb00ac390>: extract is_dest
# [2019-11-27 07:03:44,858] INFO in <ipython-input-78-0fafb00ac390>: extract has_img
# [2019-11-27 07:04:08,815] INFO in <ipython-input-78-0fafb00ac390>: extract has_video
# [2019-11-27 07:04:33,625] INFO in <ipython-input-78-0fafb00ac390>: extract word_count
# [2019-11-27 07:04:58,909] INFO in <ipython-input-78-0fafb00ac390>: extract reci_cheer
# [2019-11-27 07:05:24,266] INFO in <ipython-input-78-0fafb00ac390>: extract reci_uncheer
# [2019-11-27 07:05:50,765] INFO in <ipython-input-78-0fafb00ac390>: extract reci_comment
# [2019-11-27 07:06:14,743] INFO in <ipython-input-78-0fafb00ac390>: extract reci_mark
# [2019-11-27 07:06:30,578] INFO in <ipython-input-78-0fafb00ac390>: extract reci_tks
# [2019-11-27 07:06:57,470] INFO in <ipython-input-78-0fafb00ac390>: extract reci_xxx
# [2019-11-27 07:07:23,843] INFO in <ipython-input-78-0fafb00ac390>: extract reci_no_help
# [2019-11-27 07:07:51,391] INFO in <ipython-input-78-0fafb00ac390>: extract reci_dis
# [2019-11-27 07:08:19,579] INFO in <ipython-input-78-0fafb00ac390>: extract diff_qa_days
# [2019-11-27 07:09:32,264] INFO in <ipython-input-78-0fafb00ac390>: extract is_good
# [2019-11-27 07:09:55,274] INFO in <ipython-input-78-0fafb00ac390>: extract is_rec
# [2019-11-27 07:10:18,285] INFO in <ipython-input-78-0fafb00ac390>: extract is_dest
# [2019-11-27 07:10:41,253] INFO in <ipython-input-78-0fafb00ac390>: extract has_img
# [2019-11-27 07:11:04,404] INFO in <ipython-input-78-0fafb00ac390>: extract has_video
# [2019-11-27 07:11:28,123] INFO in <ipython-input-78-0fafb00ac390>: extract word_count
# [2019-11-27 07:11:51,957] INFO in <ipython-input-78-0fafb00ac390>: extract reci_cheer
# [2019-11-27 07:12:14,885] INFO in <ipython-input-78-0fafb00ac390>: extract reci_uncheer
# [2019-11-27 07:12:37,596] INFO in <ipython-input-78-0fafb00ac390>: extract reci_comment
# [2019-11-27 07:13:00,896] INFO in <ipython-input-78-0fafb00ac390>: extract reci_mark
# [2019-11-27 07:13:24,388] INFO in <ipython-input-78-0fafb00ac390>: extract reci_tks
# [2019-11-27 07:13:48,596] INFO in <ipython-input-78-0fafb00ac390>: extract reci_xxx
# [2019-11-27 07:14:12,478] INFO in <ipython-input-78-0fafb00ac390>: extract reci_no_help
# [2019-11-27 07:14:36,286] INFO in <ipython-input-78-0fafb00ac390>: extract reci_dis
# [2019-11-27 07:15:00,176] INFO in <ipython-input-78-0fafb00ac390>: extract diff_qa_days

# %%
# 特征提取结束
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)
assert len(test) == sub_size
# Out:
# [2019-11-27 07:15:00,259] INFO in <ipython-input-80-464c91a59cf8>: train shape (2593669, 105), test shape (1141683, 104)

# %%
# 加载用户
user = pd.read_csv(f'{base_path}/member_info_0926.txt', header=None, sep='\t')
user.columns = ['uid', 'gender', 'freq', 'uf_b1', 'uf_b2',
                'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'score', 'follow_topic',
                'inter_topic']

del user['follow_topic'], user['inter_topic']
logging.info("user %s", user.shape)

unq = user.nunique()
logging.info("user unq %s", unq)

for x in unq[unq == 1].index:
    del user[x]
    logging.info('del unq==1 %s', x)

t = user.dtypes
cats = [x for x in t[t == 'object'].index if x not in ['follow_topic', 'inter_topic', 'uid']]
logging.info("user cat %s", cats)

for d in cats:
    lb = LabelEncoder()
    user[d] = lb.fit_transform(user[d])
    logging.info('encode %s', d)

q_lb = LabelEncoder()
q_lb.fit(list(train_label['qid'].astype(str).values) + list(test['qid'].astype(str).values))
train_label['qid_enc'] = q_lb.transform(train_label['qid'])
test['qid_enc'] = q_lb.transform(test['qid'])

u_lb = LabelEncoder()
u_lb.fit(user['uid'])
train_label['uid_enc'] = u_lb.transform(train_label['uid'])
test['uid_enc'] = u_lb.transform(test['uid'])
# Out:
# [2019-11-27 07:15:17,972] INFO in <ipython-input-81-7cebf38ed8f9>: user (1931654, 14)
# [2019-11-27 07:15:24,496] INFO in <ipython-input-81-7cebf38ed8f9>: user unq uid       1931654
# gender          3
# freq            5
# uf_b1           2
# uf_b2           2
# uf_b3           2
# uf_b4           2
# uf_b5           2
# uf_c1        2561
# uf_c2         291
# uf_c3         428
# uf_c4        1556
# uf_c5           2
# score         732
# dtype: int64
# [2019-11-27 07:15:24,505] INFO in <ipython-input-81-7cebf38ed8f9>: user cat ['gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# [2019-11-27 07:15:26,227] INFO in <ipython-input-81-7cebf38ed8f9>: encode gender
# [2019-11-27 07:15:28,042] INFO in <ipython-input-81-7cebf38ed8f9>: encode freq
# [2019-11-27 07:15:29,687] INFO in <ipython-input-81-7cebf38ed8f9>: encode uf_c1
# [2019-11-27 07:15:31,306] INFO in <ipython-input-81-7cebf38ed8f9>: encode uf_c2
# [2019-11-27 07:15:32,885] INFO in <ipython-input-81-7cebf38ed8f9>: encode uf_c3
# [2019-11-27 07:15:34,431] INFO in <ipython-input-81-7cebf38ed8f9>: encode uf_c4
# [2019-11-27 07:15:35,958] INFO in <ipython-input-81-7cebf38ed8f9>: encode uf_c5

# %%
# merge user
train_label = pd.merge(train_label, user, on='uid', how='left')
test = pd.merge(test, user, on='uid', how='left')
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

data = pd.concat((train_label, test), axis=0, sort=True)
del train_label, test
# Out:
# [2019-11-27 07:16:18,355] INFO in <ipython-input-82-5d1ad498aeb5>: train shape (2593669, 120), test shape (1141683, 119)

# %%
# count编码
count_fea = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
for feat in count_fea:
    col_name = '{}_count'.format(feat)
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data.loc[data[col_name] < 2, feat] = -1
    data[feat] += 1
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data[col_name] = (data[col_name] - data[col_name].min()) / (data[col_name].max() - data[col_name].min())

# %%
# 压缩数据
t = data.dtypes
for x in t[t == 'int64'].index:
    data[x] = data[x].astype('int32')

for x in t[t == 'float64'].index:
    data[x] = data[x].astype('float32')

data['wk'] = data['day'] % 7

feature_cols = [x for x in data.columns if x not in ('label', 'uid', 'qid', 'dt', 'day')]

# %%
train_label = train[(train['day'] > train_label_feature_end)]

# %%
# target编码
logging.info("feature size %s", len(feature_cols))

X_train_all = data.iloc[:len(train_label)][feature_cols]
y_train_all = data.iloc[:len(train_label)]['label']
test = data.iloc[len(train_label):]
del data
assert len(test) == sub_size

logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for index, (train_idx, val_idx) in enumerate(fold.split(X=X_train_all, y=y_train_all)):
    break

X_train, X_val, y_train, y_val = X_train_all.iloc[train_idx][feature_cols], X_train_all.iloc[val_idx][feature_cols], \
                                 y_train_all.iloc[train_idx], \
                                 y_train_all.iloc[val_idx]
del X_train_all

model_lgb = LGBMClassifier(n_estimators=2000, n_jobs=-1, objective='binary', seed=1000, silent=True)
model_lgb.fit(X_train, y_train,
              eval_metric=['logloss', 'auc'],
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=50)

sub['label'] = model_lgb.predict_proba(test[feature_cols])[:, 1]
# Out:
# [2019-11-27 07:18:50,580] INFO in <ipython-input-86-20048b165b8f>: feature size 126
# [2019-11-27 07:18:50,899] INFO in <ipython-input-86-20048b165b8f>: train shape (2593669, 5), test shape (1141683, 130)
# [1]	valid_0's auc: 0.758209	valid_0's binary_logloss: 0.426574
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.775093	valid_0's binary_logloss: 0.416574
# [3]	valid_0's auc: 0.780504	valid_0's binary_logloss: 0.408526
# [4]	valid_0's auc: 0.784522	valid_0's binary_logloss: 0.401732
# [5]	valid_0's auc: 0.785633	valid_0's binary_logloss: 0.396236
# [6]	valid_0's auc: 0.788326	valid_0's binary_logloss: 0.391159
# [7]	valid_0's auc: 0.790373	valid_0's binary_logloss: 0.38688
# [8]	valid_0's auc: 0.792092	valid_0's binary_logloss: 0.383054
# [9]	valid_0's auc: 0.794116	valid_0's binary_logloss: 0.379763
# [10]	valid_0's auc: 0.796005	valid_0's binary_logloss: 0.376867
# [11]	valid_0's auc: 0.797395	valid_0's binary_logloss: 0.374089
# [12]	valid_0's auc: 0.798549	valid_0's binary_logloss: 0.371696
# [13]	valid_0's auc: 0.799592	valid_0's binary_logloss: 0.369706
# [14]	valid_0's auc: 0.800246	valid_0's binary_logloss: 0.36779
# [15]	valid_0's auc: 0.801392	valid_0's binary_logloss: 0.366041
# [16]	valid_0's auc: 0.802802	valid_0's binary_logloss: 0.364409
# [17]	valid_0's auc: 0.804358	valid_0's binary_logloss: 0.362613
# [18]	valid_0's auc: 0.8055	valid_0's binary_logloss: 0.361241
# [19]	valid_0's auc: 0.806655	valid_0's binary_logloss: 0.359826
# [20]	valid_0's auc: 0.807491	valid_0's binary_logloss: 0.358791
# [21]	valid_0's auc: 0.808368	valid_0's binary_logloss: 0.357722
# [22]	valid_0's auc: 0.809269	valid_0's binary_logloss: 0.35662
# [23]	valid_0's auc: 0.809948	valid_0's binary_logloss: 0.355738
# [24]	valid_0's auc: 0.810833	valid_0's binary_logloss: 0.354751
# [25]	valid_0's auc: 0.811543	valid_0's binary_logloss: 0.353976
# [26]	valid_0's auc: 0.811999	valid_0's binary_logloss: 0.353311
# [27]	valid_0's auc: 0.812574	valid_0's binary_logloss: 0.35261
# [28]	valid_0's auc: 0.813066	valid_0's binary_logloss: 0.351956
# [29]	valid_0's auc: 0.813606	valid_0's binary_logloss: 0.351304
# [30]	valid_0's auc: 0.814068	valid_0's binary_logloss: 0.350721
# [31]	valid_0's auc: 0.814374	valid_0's binary_logloss: 0.350266
# [32]	valid_0's auc: 0.814953	valid_0's binary_logloss: 0.349632
# [33]	valid_0's auc: 0.815282	valid_0's binary_logloss: 0.349225
# [34]	valid_0's auc: 0.8157	valid_0's binary_logloss: 0.348749
# [35]	valid_0's auc: 0.816047	valid_0's binary_logloss: 0.348368
# [36]	valid_0's auc: 0.816332	valid_0's binary_logloss: 0.348034
# [37]	valid_0's auc: 0.816643	valid_0's binary_logloss: 0.347661
# [38]	valid_0's auc: 0.816909	valid_0's binary_logloss: 0.347338
# [39]	valid_0's auc: 0.817242	valid_0's binary_logloss: 0.346922
# [40]	valid_0's auc: 0.817509	valid_0's binary_logloss: 0.346623
# [41]	valid_0's auc: 0.817762	valid_0's binary_logloss: 0.346347
# [42]	valid_0's auc: 0.818057	valid_0's binary_logloss: 0.346009
# [43]	valid_0's auc: 0.818332	valid_0's binary_logloss: 0.345743
# [44]	valid_0's auc: 0.818553	valid_0's binary_logloss: 0.345516
# [45]	valid_0's auc: 0.818837	valid_0's binary_logloss: 0.345228
# [46]	valid_0's auc: 0.819072	valid_0's binary_logloss: 0.344983
# [47]	valid_0's auc: 0.819268	valid_0's binary_logloss: 0.34479
# [48]	valid_0's auc: 0.819467	valid_0's binary_logloss: 0.344582
# [49]	valid_0's auc: 0.819645	valid_0's binary_logloss: 0.344374
# [50]	valid_0's auc: 0.819848	valid_0's binary_logloss: 0.344192
# [51]	valid_0's auc: 0.82017	valid_0's binary_logloss: 0.343887
# [52]	valid_0's auc: 0.820327	valid_0's binary_logloss: 0.343709
# [53]	valid_0's auc: 0.820523	valid_0's binary_logloss: 0.343504
# [54]	valid_0's auc: 0.820711	valid_0's binary_logloss: 0.343332
# [55]	valid_0's auc: 0.820923	valid_0's binary_logloss: 0.343096
# [56]	valid_0's auc: 0.821136	valid_0's binary_logloss: 0.342911
# [57]	valid_0's auc: 0.821245	valid_0's binary_logloss: 0.342796
# [58]	valid_0's auc: 0.821554	valid_0's binary_logloss: 0.342492
# [59]	valid_0's auc: 0.821769	valid_0's binary_logloss: 0.34226
# [60]	valid_0's auc: 0.821938	valid_0's binary_logloss: 0.342116
# [61]	valid_0's auc: 0.822169	valid_0's binary_logloss: 0.341889
# [62]	valid_0's auc: 0.822302	valid_0's binary_logloss: 0.341764
# [63]	valid_0's auc: 0.822427	valid_0's binary_logloss: 0.34165
# [64]	valid_0's auc: 0.822565	valid_0's binary_logloss: 0.34153
# [65]	valid_0's auc: 0.822712	valid_0's binary_logloss: 0.341418
# [66]	valid_0's auc: 0.822839	valid_0's binary_logloss: 0.34128
# [67]	valid_0's auc: 0.822978	valid_0's binary_logloss: 0.341163
# [68]	valid_0's auc: 0.823216	valid_0's binary_logloss: 0.340936
# [69]	valid_0's auc: 0.823349	valid_0's binary_logloss: 0.340791
# [70]	valid_0's auc: 0.823481	valid_0's binary_logloss: 0.340679
# [71]	valid_0's auc: 0.823698	valid_0's binary_logloss: 0.340503
# [72]	valid_0's auc: 0.823797	valid_0's binary_logloss: 0.340411
# [73]	valid_0's auc: 0.823931	valid_0's binary_logloss: 0.340305
# [74]	valid_0's auc: 0.824155	valid_0's binary_logloss: 0.340117
# [75]	valid_0's auc: 0.824245	valid_0's binary_logloss: 0.340033
# [76]	valid_0's auc: 0.82439	valid_0's binary_logloss: 0.339922
# [77]	valid_0's auc: 0.82453	valid_0's binary_logloss: 0.339789
# [78]	valid_0's auc: 0.824657	valid_0's binary_logloss: 0.339677
# [79]	valid_0's auc: 0.824745	valid_0's binary_logloss: 0.339608
# [80]	valid_0's auc: 0.824876	valid_0's binary_logloss: 0.339497
# [81]	valid_0's auc: 0.824954	valid_0's binary_logloss: 0.339424
# [82]	valid_0's auc: 0.825084	valid_0's binary_logloss: 0.339289
# [83]	valid_0's auc: 0.825161	valid_0's binary_logloss: 0.339221
# [84]	valid_0's auc: 0.825262	valid_0's binary_logloss: 0.339141
# [85]	valid_0's auc: 0.825365	valid_0's binary_logloss: 0.339061
# [86]	valid_0's auc: 0.825424	valid_0's binary_logloss: 0.339008
# [87]	valid_0's auc: 0.825504	valid_0's binary_logloss: 0.338935
# [88]	valid_0's auc: 0.825589	valid_0's binary_logloss: 0.338854
# [89]	valid_0's auc: 0.82572	valid_0's binary_logloss: 0.338741
# [90]	valid_0's auc: 0.825842	valid_0's binary_logloss: 0.33865
# [91]	valid_0's auc: 0.825969	valid_0's binary_logloss: 0.338546
# [92]	valid_0's auc: 0.82604	valid_0's binary_logloss: 0.338491
# [93]	valid_0's auc: 0.826104	valid_0's binary_logloss: 0.338436
# [94]	valid_0's auc: 0.82622	valid_0's binary_logloss: 0.338317
# [95]	valid_0's auc: 0.826295	valid_0's binary_logloss: 0.338259
# [96]	valid_0's auc: 0.826356	valid_0's binary_logloss: 0.338208
# [97]	valid_0's auc: 0.826463	valid_0's binary_logloss: 0.338109
# [98]	valid_0's auc: 0.82651	valid_0's binary_logloss: 0.338072
# [99]	valid_0's auc: 0.826592	valid_0's binary_logloss: 0.338003
# [100]	valid_0's auc: 0.826645	valid_0's binary_logloss: 0.337948
# [101]	valid_0's auc: 0.826724	valid_0's binary_logloss: 0.337889
# [102]	valid_0's auc: 0.826818	valid_0's binary_logloss: 0.337818
# [103]	valid_0's auc: 0.826897	valid_0's binary_logloss: 0.337749
# [104]	valid_0's auc: 0.826984	valid_0's binary_logloss: 0.337679
# [105]	valid_0's auc: 0.827077	valid_0's binary_logloss: 0.337587
# [106]	valid_0's auc: 0.827183	valid_0's binary_logloss: 0.337499
# [107]	valid_0's auc: 0.827214	valid_0's binary_logloss: 0.33747
# [108]	valid_0's auc: 0.8273	valid_0's binary_logloss: 0.337405
# [109]	valid_0's auc: 0.827367	valid_0's binary_logloss: 0.337347
# [110]	valid_0's auc: 0.827419	valid_0's binary_logloss: 0.337295
# [111]	valid_0's auc: 0.827479	valid_0's binary_logloss: 0.33725
# [112]	valid_0's auc: 0.827569	valid_0's binary_logloss: 0.337176
# [113]	valid_0's auc: 0.827649	valid_0's binary_logloss: 0.337111
# [114]	valid_0's auc: 0.827726	valid_0's binary_logloss: 0.337051
# [115]	valid_0's auc: 0.827788	valid_0's binary_logloss: 0.336999
# [116]	valid_0's auc: 0.827844	valid_0's binary_logloss: 0.336949
# [117]	valid_0's auc: 0.827914	valid_0's binary_logloss: 0.336886
# [118]	valid_0's auc: 0.827957	valid_0's binary_logloss: 0.336848
# [119]	valid_0's auc: 0.828004	valid_0's binary_logloss: 0.336816
# [120]	valid_0's auc: 0.828051	valid_0's binary_logloss: 0.336778
# [121]	valid_0's auc: 0.828098	valid_0's binary_logloss: 0.336734
# [122]	valid_0's auc: 0.828149	valid_0's binary_logloss: 0.336697
# [123]	valid_0's auc: 0.828238	valid_0's binary_logloss: 0.33662
# [124]	valid_0's auc: 0.828264	valid_0's binary_logloss: 0.336595
# [125]	valid_0's auc: 0.828307	valid_0's binary_logloss: 0.33656
# [126]	valid_0's auc: 0.828391	valid_0's binary_logloss: 0.336488
# [127]	valid_0's auc: 0.828444	valid_0's binary_logloss: 0.336447
# [128]	valid_0's auc: 0.828486	valid_0's binary_logloss: 0.336419
# [129]	valid_0's auc: 0.828529	valid_0's binary_logloss: 0.336377
# [130]	valid_0's auc: 0.828577	valid_0's binary_logloss: 0.336336
# [131]	valid_0's auc: 0.828612	valid_0's binary_logloss: 0.336304
# [132]	valid_0's auc: 0.828626	valid_0's binary_logloss: 0.336293
# [133]	valid_0's auc: 0.828716	valid_0's binary_logloss: 0.33621
# [134]	valid_0's auc: 0.828731	valid_0's binary_logloss: 0.336198
# [135]	valid_0's auc: 0.828764	valid_0's binary_logloss: 0.336166
# [136]	valid_0's auc: 0.828796	valid_0's binary_logloss: 0.33614
# [137]	valid_0's auc: 0.828802	valid_0's binary_logloss: 0.336135
# [138]	valid_0's auc: 0.828815	valid_0's binary_logloss: 0.336127
# [139]	valid_0's auc: 0.828859	valid_0's binary_logloss: 0.336091
# [140]	valid_0's auc: 0.828889	valid_0's binary_logloss: 0.336064
# [141]	valid_0's auc: 0.828919	valid_0's binary_logloss: 0.336039
# [142]	valid_0's auc: 0.828976	valid_0's binary_logloss: 0.335984
# [143]	valid_0's auc: 0.829004	valid_0's binary_logloss: 0.33596
# [144]	valid_0's auc: 0.829026	valid_0's binary_logloss: 0.335945
# [145]	valid_0's auc: 0.829109	valid_0's binary_logloss: 0.335868
# [146]	valid_0's auc: 0.829171	valid_0's binary_logloss: 0.335819
# [147]	valid_0's auc: 0.829192	valid_0's binary_logloss: 0.335802
# [148]	valid_0's auc: 0.829242	valid_0's binary_logloss: 0.335759
# [149]	valid_0's auc: 0.82925	valid_0's binary_logloss: 0.335754
# [150]	valid_0's auc: 0.829259	valid_0's binary_logloss: 0.335746
# [151]	valid_0's auc: 0.829331	valid_0's binary_logloss: 0.335692
# [152]	valid_0's auc: 0.829348	valid_0's binary_logloss: 0.335678
# [153]	valid_0's auc: 0.829354	valid_0's binary_logloss: 0.335672
# [154]	valid_0's auc: 0.829399	valid_0's binary_logloss: 0.335626
# [155]	valid_0's auc: 0.82945	valid_0's binary_logloss: 0.335581
# [156]	valid_0's auc: 0.82951	valid_0's binary_logloss: 0.335543
# [157]	valid_0's auc: 0.829533	valid_0's binary_logloss: 0.335528
# [158]	valid_0's auc: 0.829553	valid_0's binary_logloss: 0.335514
# [159]	valid_0's auc: 0.829572	valid_0's binary_logloss: 0.335495
# [160]	valid_0's auc: 0.829611	valid_0's binary_logloss: 0.335465
# [161]	valid_0's auc: 0.829664	valid_0's binary_logloss: 0.335424
# [162]	valid_0's auc: 0.829681	valid_0's binary_logloss: 0.33541
# [163]	valid_0's auc: 0.829759	valid_0's binary_logloss: 0.335334
# [164]	valid_0's auc: 0.829793	valid_0's binary_logloss: 0.335303
# [165]	valid_0's auc: 0.829799	valid_0's binary_logloss: 0.335298
# [166]	valid_0's auc: 0.829825	valid_0's binary_logloss: 0.335276
# [167]	valid_0's auc: 0.82986	valid_0's binary_logloss: 0.335247
# [168]	valid_0's auc: 0.829887	valid_0's binary_logloss: 0.335226
# [169]	valid_0's auc: 0.829917	valid_0's binary_logloss: 0.335199
# [170]	valid_0's auc: 0.82993	valid_0's binary_logloss: 0.33519
# [171]	valid_0's auc: 0.829929	valid_0's binary_logloss: 0.33519
# [172]	valid_0's auc: 0.829951	valid_0's binary_logloss: 0.335171
# [173]	valid_0's auc: 0.829961	valid_0's binary_logloss: 0.335165
# [174]	valid_0's auc: 0.829997	valid_0's binary_logloss: 0.335131
# [175]	valid_0's auc: 0.830036	valid_0's binary_logloss: 0.3351
# [176]	valid_0's auc: 0.830087	valid_0's binary_logloss: 0.335056
# [177]	valid_0's auc: 0.830126	valid_0's binary_logloss: 0.335026
# [178]	valid_0's auc: 0.830169	valid_0's binary_logloss: 0.334988
# [179]	valid_0's auc: 0.830221	valid_0's binary_logloss: 0.334943
# [180]	valid_0's auc: 0.830229	valid_0's binary_logloss: 0.334934
# [181]	valid_0's auc: 0.830234	valid_0's binary_logloss: 0.334926
# [182]	valid_0's auc: 0.830241	valid_0's binary_logloss: 0.334922
# [183]	valid_0's auc: 0.830256	valid_0's binary_logloss: 0.334912
# [184]	valid_0's auc: 0.830271	valid_0's binary_logloss: 0.3349
# [185]	valid_0's auc: 0.830303	valid_0's binary_logloss: 0.334874
# [186]	valid_0's auc: 0.830327	valid_0's binary_logloss: 0.334856
# [187]	valid_0's auc: 0.830386	valid_0's binary_logloss: 0.334807
# [188]	valid_0's auc: 0.83039	valid_0's binary_logloss: 0.334804
# [189]	valid_0's auc: 0.830409	valid_0's binary_logloss: 0.334789
# [190]	valid_0's auc: 0.830444	valid_0's binary_logloss: 0.334755
# [191]	valid_0's auc: 0.830466	valid_0's binary_logloss: 0.334739
# [192]	valid_0's auc: 0.830484	valid_0's binary_logloss: 0.334723
# [193]	valid_0's auc: 0.830509	valid_0's binary_logloss: 0.334697
# [194]	valid_0's auc: 0.830514	valid_0's binary_logloss: 0.334693
# [195]	valid_0's auc: 0.83052	valid_0's binary_logloss: 0.334686
# [196]	valid_0's auc: 0.830523	valid_0's binary_logloss: 0.334682
# [197]	valid_0's auc: 0.830533	valid_0's binary_logloss: 0.334674
# [198]	valid_0's auc: 0.830545	valid_0's binary_logloss: 0.334667
# [199]	valid_0's auc: 0.83055	valid_0's binary_logloss: 0.334664
# [200]	valid_0's auc: 0.830548	valid_0's binary_logloss: 0.334664
# [201]	valid_0's auc: 0.830564	valid_0's binary_logloss: 0.334653
# [202]	valid_0's auc: 0.830659	valid_0's binary_logloss: 0.334554
# [203]	valid_0's auc: 0.830689	valid_0's binary_logloss: 0.334528
# [204]	valid_0's auc: 0.830714	valid_0's binary_logloss: 0.334506
# [205]	valid_0's auc: 0.830741	valid_0's binary_logloss: 0.334482
# [206]	valid_0's auc: 0.830755	valid_0's binary_logloss: 0.33447
# [207]	valid_0's auc: 0.830758	valid_0's binary_logloss: 0.334464
# [208]	valid_0's auc: 0.830765	valid_0's binary_logloss: 0.33446
# [209]	valid_0's auc: 0.830816	valid_0's binary_logloss: 0.334415
# [210]	valid_0's auc: 0.830828	valid_0's binary_logloss: 0.334405
# [211]	valid_0's auc: 0.830837	valid_0's binary_logloss: 0.334397
# [212]	valid_0's auc: 0.830886	valid_0's binary_logloss: 0.334349
# [213]	valid_0's auc: 0.830886	valid_0's binary_logloss: 0.334349
# [214]	valid_0's auc: 0.830907	valid_0's binary_logloss: 0.334336
# [215]	valid_0's auc: 0.830926	valid_0's binary_logloss: 0.334321
# [216]	valid_0's auc: 0.830954	valid_0's binary_logloss: 0.334297
# [217]	valid_0's auc: 0.830987	valid_0's binary_logloss: 0.334265
# [218]	valid_0's auc: 0.830992	valid_0's binary_logloss: 0.334263
# [219]	valid_0's auc: 0.831027	valid_0's binary_logloss: 0.334233
# [220]	valid_0's auc: 0.831053	valid_0's binary_logloss: 0.334214
# [221]	valid_0's auc: 0.831061	valid_0's binary_logloss: 0.334209
# [222]	valid_0's auc: 0.831074	valid_0's binary_logloss: 0.334198
# [223]	valid_0's auc: 0.831082	valid_0's binary_logloss: 0.334191
# [224]	valid_0's auc: 0.831083	valid_0's binary_logloss: 0.33419
# [225]	valid_0's auc: 0.831091	valid_0's binary_logloss: 0.334183
# [226]	valid_0's auc: 0.831106	valid_0's binary_logloss: 0.334169
# [227]	valid_0's auc: 0.831136	valid_0's binary_logloss: 0.334148
# [228]	valid_0's auc: 0.831155	valid_0's binary_logloss: 0.334135
# [229]	valid_0's auc: 0.831177	valid_0's binary_logloss: 0.334114
# [230]	valid_0's auc: 0.831189	valid_0's binary_logloss: 0.334106
# [231]	valid_0's auc: 0.8312	valid_0's binary_logloss: 0.334096
# [232]	valid_0's auc: 0.831244	valid_0's binary_logloss: 0.334065
# [233]	valid_0's auc: 0.831254	valid_0's binary_logloss: 0.334058
# [234]	valid_0's auc: 0.831267	valid_0's binary_logloss: 0.334048
# [235]	valid_0's auc: 0.831274	valid_0's binary_logloss: 0.334043
# [236]	valid_0's auc: 0.831277	valid_0's binary_logloss: 0.334041
# [237]	valid_0's auc: 0.831305	valid_0's binary_logloss: 0.334021
# [238]	valid_0's auc: 0.831305	valid_0's binary_logloss: 0.33402
# [239]	valid_0's auc: 0.831327	valid_0's binary_logloss: 0.333999
# [240]	valid_0's auc: 0.831338	valid_0's binary_logloss: 0.333991
# [241]	valid_0's auc: 0.831336	valid_0's binary_logloss: 0.333992
# [242]	valid_0's auc: 0.831339	valid_0's binary_logloss: 0.333989
# [243]	valid_0's auc: 0.831374	valid_0's binary_logloss: 0.33396
# [244]	valid_0's auc: 0.831374	valid_0's binary_logloss: 0.333959
# [245]	valid_0's auc: 0.831377	valid_0's binary_logloss: 0.333957
# [246]	valid_0's auc: 0.831402	valid_0's binary_logloss: 0.333937
# [247]	valid_0's auc: 0.831415	valid_0's binary_logloss: 0.333925
# [248]	valid_0's auc: 0.831418	valid_0's binary_logloss: 0.333919
# [249]	valid_0's auc: 0.83142	valid_0's binary_logloss: 0.333915
# [250]	valid_0's auc: 0.831421	valid_0's binary_logloss: 0.333912
# [251]	valid_0's auc: 0.831424	valid_0's binary_logloss: 0.333908
# [252]	valid_0's auc: 0.831465	valid_0's binary_logloss: 0.333875
# [253]	valid_0's auc: 0.831469	valid_0's binary_logloss: 0.333871
# [254]	valid_0's auc: 0.83147	valid_0's binary_logloss: 0.333869
# [255]	valid_0's auc: 0.831482	valid_0's binary_logloss: 0.333861
# [256]	valid_0's auc: 0.831482	valid_0's binary_logloss: 0.333861
# [257]	valid_0's auc: 0.831492	valid_0's binary_logloss: 0.333854
# [258]	valid_0's auc: 0.831499	valid_0's binary_logloss: 0.333848
# [259]	valid_0's auc: 0.831524	valid_0's binary_logloss: 0.333828
# [260]	valid_0's auc: 0.831528	valid_0's binary_logloss: 0.333826
# [261]	valid_0's auc: 0.831575	valid_0's binary_logloss: 0.33379
# [262]	valid_0's auc: 0.831604	valid_0's binary_logloss: 0.333764
# [263]	valid_0's auc: 0.831636	valid_0's binary_logloss: 0.333732
# [264]	valid_0's auc: 0.831676	valid_0's binary_logloss: 0.333697
# [265]	valid_0's auc: 0.8317	valid_0's binary_logloss: 0.333678
# [266]	valid_0's auc: 0.831709	valid_0's binary_logloss: 0.333671
# [267]	valid_0's auc: 0.831712	valid_0's binary_logloss: 0.333668
# [268]	valid_0's auc: 0.83176	valid_0's binary_logloss: 0.333622
# [269]	valid_0's auc: 0.831787	valid_0's binary_logloss: 0.333598
# [270]	valid_0's auc: 0.831812	valid_0's binary_logloss: 0.333576
# [271]	valid_0's auc: 0.831859	valid_0's binary_logloss: 0.333543
# [272]	valid_0's auc: 0.831872	valid_0's binary_logloss: 0.333534
# [273]	valid_0's auc: 0.831895	valid_0's binary_logloss: 0.333515
# [274]	valid_0's auc: 0.831916	valid_0's binary_logloss: 0.333494
# [275]	valid_0's auc: 0.831922	valid_0's binary_logloss: 0.33349
# [276]	valid_0's auc: 0.831937	valid_0's binary_logloss: 0.333477
# [277]	valid_0's auc: 0.831965	valid_0's binary_logloss: 0.333454
# [278]	valid_0's auc: 0.831999	valid_0's binary_logloss: 0.33343
# [279]	valid_0's auc: 0.832012	valid_0's binary_logloss: 0.333421
# [280]	valid_0's auc: 0.832025	valid_0's binary_logloss: 0.333408
# [281]	valid_0's auc: 0.832036	valid_0's binary_logloss: 0.333399
# [282]	valid_0's auc: 0.832039	valid_0's binary_logloss: 0.333397
# [283]	valid_0's auc: 0.832041	valid_0's binary_logloss: 0.333396
# [284]	valid_0's auc: 0.832042	valid_0's binary_logloss: 0.333394
# [285]	valid_0's auc: 0.832042	valid_0's binary_logloss: 0.333394
# [286]	valid_0's auc: 0.832075	valid_0's binary_logloss: 0.33337
# [287]	valid_0's auc: 0.832086	valid_0's binary_logloss: 0.333362
# [288]	valid_0's auc: 0.832135	valid_0's binary_logloss: 0.333324
# [289]	valid_0's auc: 0.832173	valid_0's binary_logloss: 0.333292
# [290]	valid_0's auc: 0.832176	valid_0's binary_logloss: 0.333291
# [291]	valid_0's auc: 0.832188	valid_0's binary_logloss: 0.333282
# [292]	valid_0's auc: 0.83219	valid_0's binary_logloss: 0.33328
# [293]	valid_0's auc: 0.832197	valid_0's binary_logloss: 0.333273
# [294]	valid_0's auc: 0.832197	valid_0's binary_logloss: 0.333273
# [295]	valid_0's auc: 0.832201	valid_0's binary_logloss: 0.333271
# [296]	valid_0's auc: 0.832219	valid_0's binary_logloss: 0.333258
# [297]	valid_0's auc: 0.832232	valid_0's binary_logloss: 0.333248
# [298]	valid_0's auc: 0.832238	valid_0's binary_logloss: 0.333243
# [299]	valid_0's auc: 0.832241	valid_0's binary_logloss: 0.33324
# [300]	valid_0's auc: 0.832246	valid_0's binary_logloss: 0.333237
# [301]	valid_0's auc: 0.832281	valid_0's binary_logloss: 0.333208
# [302]	valid_0's auc: 0.832284	valid_0's binary_logloss: 0.333205
# [303]	valid_0's auc: 0.832283	valid_0's binary_logloss: 0.333206
# [304]	valid_0's auc: 0.832317	valid_0's binary_logloss: 0.333181
# [305]	valid_0's auc: 0.83232	valid_0's binary_logloss: 0.333178
# [306]	valid_0's auc: 0.832325	valid_0's binary_logloss: 0.333173
# [307]	valid_0's auc: 0.832325	valid_0's binary_logloss: 0.333171
# [308]	valid_0's auc: 0.832324	valid_0's binary_logloss: 0.333172
# [309]	valid_0's auc: 0.832338	valid_0's binary_logloss: 0.333161
# [310]	valid_0's auc: 0.832345	valid_0's binary_logloss: 0.333157
# [311]	valid_0's auc: 0.832353	valid_0's binary_logloss: 0.333151
# [312]	valid_0's auc: 0.832368	valid_0's binary_logloss: 0.333136
# [313]	valid_0's auc: 0.832376	valid_0's binary_logloss: 0.333128
# [314]	valid_0's auc: 0.832377	valid_0's binary_logloss: 0.333127
# [315]	valid_0's auc: 0.832395	valid_0's binary_logloss: 0.333113
# [316]	valid_0's auc: 0.832423	valid_0's binary_logloss: 0.333091
# [317]	valid_0's auc: 0.832443	valid_0's binary_logloss: 0.333073
# [318]	valid_0's auc: 0.832456	valid_0's binary_logloss: 0.333064
# [319]	valid_0's auc: 0.832459	valid_0's binary_logloss: 0.333061
# [320]	valid_0's auc: 0.832493	valid_0's binary_logloss: 0.333038
# [321]	valid_0's auc: 0.832495	valid_0's binary_logloss: 0.333037
# [322]	valid_0's auc: 0.832537	valid_0's binary_logloss: 0.333002
# [323]	valid_0's auc: 0.83255	valid_0's binary_logloss: 0.332993
# [324]	valid_0's auc: 0.832553	valid_0's binary_logloss: 0.332991
# [325]	valid_0's auc: 0.832558	valid_0's binary_logloss: 0.332986
# [326]	valid_0's auc: 0.832567	valid_0's binary_logloss: 0.332979
# [327]	valid_0's auc: 0.832602	valid_0's binary_logloss: 0.332949
# [328]	valid_0's auc: 0.832628	valid_0's binary_logloss: 0.332931
# [329]	valid_0's auc: 0.832637	valid_0's binary_logloss: 0.332925
# [330]	valid_0's auc: 0.832656	valid_0's binary_logloss: 0.33291
# [331]	valid_0's auc: 0.832662	valid_0's binary_logloss: 0.332906
# [332]	valid_0's auc: 0.832671	valid_0's binary_logloss: 0.332895
# [333]	valid_0's auc: 0.832669	valid_0's binary_logloss: 0.332897
# [334]	valid_0's auc: 0.832677	valid_0's binary_logloss: 0.332888
# [335]	valid_0's auc: 0.832676	valid_0's binary_logloss: 0.332888
# [336]	valid_0's auc: 0.832677	valid_0's binary_logloss: 0.332888
# [337]	valid_0's auc: 0.832683	valid_0's binary_logloss: 0.332885
# [338]	valid_0's auc: 0.832685	valid_0's binary_logloss: 0.332883
# [339]	valid_0's auc: 0.832703	valid_0's binary_logloss: 0.332864
# [340]	valid_0's auc: 0.832703	valid_0's binary_logloss: 0.332865
# [341]	valid_0's auc: 0.8327	valid_0's binary_logloss: 0.332867
# [342]	valid_0's auc: 0.832707	valid_0's binary_logloss: 0.332862
# [343]	valid_0's auc: 0.832716	valid_0's binary_logloss: 0.332855
# [344]	valid_0's auc: 0.832734	valid_0's binary_logloss: 0.332841
# [345]	valid_0's auc: 0.832739	valid_0's binary_logloss: 0.332833
# [346]	valid_0's auc: 0.832744	valid_0's binary_logloss: 0.332826
# [347]	valid_0's auc: 0.832768	valid_0's binary_logloss: 0.332811
# [348]	valid_0's auc: 0.83279	valid_0's binary_logloss: 0.332791
# [349]	valid_0's auc: 0.832799	valid_0's binary_logloss: 0.332782
# [350]	valid_0's auc: 0.832807	valid_0's binary_logloss: 0.332774
# [351]	valid_0's auc: 0.832815	valid_0's binary_logloss: 0.332767
# [352]	valid_0's auc: 0.832816	valid_0's binary_logloss: 0.332766
# [353]	valid_0's auc: 0.832857	valid_0's binary_logloss: 0.332716
# [354]	valid_0's auc: 0.832851	valid_0's binary_logloss: 0.33272
# [355]	valid_0's auc: 0.832865	valid_0's binary_logloss: 0.332711
# [356]	valid_0's auc: 0.832865	valid_0's binary_logloss: 0.332711
# [357]	valid_0's auc: 0.832874	valid_0's binary_logloss: 0.332704
# [358]	valid_0's auc: 0.832893	valid_0's binary_logloss: 0.332689
# [359]	valid_0's auc: 0.832924	valid_0's binary_logloss: 0.332663
# [360]	valid_0's auc: 0.832937	valid_0's binary_logloss: 0.332654
# [361]	valid_0's auc: 0.832951	valid_0's binary_logloss: 0.332638
# [362]	valid_0's auc: 0.832956	valid_0's binary_logloss: 0.332635
# [363]	valid_0's auc: 0.83296	valid_0's binary_logloss: 0.332632
# [364]	valid_0's auc: 0.832965	valid_0's binary_logloss: 0.332628
# [365]	valid_0's auc: 0.832972	valid_0's binary_logloss: 0.332623
# [366]	valid_0's auc: 0.832978	valid_0's binary_logloss: 0.332618
# [367]	valid_0's auc: 0.833001	valid_0's binary_logloss: 0.332602
# [368]	valid_0's auc: 0.833013	valid_0's binary_logloss: 0.332593
# [369]	valid_0's auc: 0.833038	valid_0's binary_logloss: 0.332573
# [370]	valid_0's auc: 0.833051	valid_0's binary_logloss: 0.332562
# [371]	valid_0's auc: 0.833051	valid_0's binary_logloss: 0.332562
# [372]	valid_0's auc: 0.83305	valid_0's binary_logloss: 0.332562
# [373]	valid_0's auc: 0.833053	valid_0's binary_logloss: 0.332558
# [374]	valid_0's auc: 0.833059	valid_0's binary_logloss: 0.332553
# [375]	valid_0's auc: 0.833059	valid_0's binary_logloss: 0.332553
# [376]	valid_0's auc: 0.833063	valid_0's binary_logloss: 0.332551
# [377]	valid_0's auc: 0.833078	valid_0's binary_logloss: 0.332541
# [378]	valid_0's auc: 0.833086	valid_0's binary_logloss: 0.332533
# [379]	valid_0's auc: 0.833084	valid_0's binary_logloss: 0.332533
# [380]	valid_0's auc: 0.833104	valid_0's binary_logloss: 0.332516
# [381]	valid_0's auc: 0.833121	valid_0's binary_logloss: 0.332502
# [382]	valid_0's auc: 0.833121	valid_0's binary_logloss: 0.332501
# [383]	valid_0's auc: 0.833122	valid_0's binary_logloss: 0.332501
# [384]	valid_0's auc: 0.83312	valid_0's binary_logloss: 0.332503
# [385]	valid_0's auc: 0.833141	valid_0's binary_logloss: 0.332489
# [386]	valid_0's auc: 0.833155	valid_0's binary_logloss: 0.332479
# [387]	valid_0's auc: 0.833166	valid_0's binary_logloss: 0.33247
# [388]	valid_0's auc: 0.833177	valid_0's binary_logloss: 0.33246
# [389]	valid_0's auc: 0.833182	valid_0's binary_logloss: 0.332456
# [390]	valid_0's auc: 0.833186	valid_0's binary_logloss: 0.332452
# [391]	valid_0's auc: 0.833185	valid_0's binary_logloss: 0.332453
# [392]	valid_0's auc: 0.83319	valid_0's binary_logloss: 0.33245
# [393]	valid_0's auc: 0.833198	valid_0's binary_logloss: 0.332444
# [394]	valid_0's auc: 0.833214	valid_0's binary_logloss: 0.332418
# [395]	valid_0's auc: 0.833245	valid_0's binary_logloss: 0.332395
# [396]	valid_0's auc: 0.83325	valid_0's binary_logloss: 0.332391
# [397]	valid_0's auc: 0.833251	valid_0's binary_logloss: 0.332389
# [398]	valid_0's auc: 0.833259	valid_0's binary_logloss: 0.332382
# [399]	valid_0's auc: 0.833261	valid_0's binary_logloss: 0.332381
# [400]	valid_0's auc: 0.833259	valid_0's binary_logloss: 0.332381
# [401]	valid_0's auc: 0.833264	valid_0's binary_logloss: 0.332377
# [402]	valid_0's auc: 0.833267	valid_0's binary_logloss: 0.332375
# [403]	valid_0's auc: 0.833264	valid_0's binary_logloss: 0.332376
# [404]	valid_0's auc: 0.833274	valid_0's binary_logloss: 0.332366
# [405]	valid_0's auc: 0.83329	valid_0's binary_logloss: 0.332355
# [406]	valid_0's auc: 0.833306	valid_0's binary_logloss: 0.332343
# [407]	valid_0's auc: 0.833312	valid_0's binary_logloss: 0.332339
# [408]	valid_0's auc: 0.833325	valid_0's binary_logloss: 0.332326
# [409]	valid_0's auc: 0.833329	valid_0's binary_logloss: 0.332322
# [410]	valid_0's auc: 0.833336	valid_0's binary_logloss: 0.332316
# [411]	valid_0's auc: 0.833336	valid_0's binary_logloss: 0.332316
# [412]	valid_0's auc: 0.833332	valid_0's binary_logloss: 0.332317
# [413]	valid_0's auc: 0.833346	valid_0's binary_logloss: 0.332306
# [414]	valid_0's auc: 0.833367	valid_0's binary_logloss: 0.332285
# [415]	valid_0's auc: 0.833388	valid_0's binary_logloss: 0.332267
# [416]	valid_0's auc: 0.833418	valid_0's binary_logloss: 0.332245
# [417]	valid_0's auc: 0.833429	valid_0's binary_logloss: 0.332234
# [418]	valid_0's auc: 0.833451	valid_0's binary_logloss: 0.332214
# [419]	valid_0's auc: 0.833462	valid_0's binary_logloss: 0.332202
# [420]	valid_0's auc: 0.833476	valid_0's binary_logloss: 0.332193
# [421]	valid_0's auc: 0.833499	valid_0's binary_logloss: 0.332174
# [422]	valid_0's auc: 0.833508	valid_0's binary_logloss: 0.332167
# [423]	valid_0's auc: 0.833507	valid_0's binary_logloss: 0.332167
# [424]	valid_0's auc: 0.833515	valid_0's binary_logloss: 0.33216
# [425]	valid_0's auc: 0.833528	valid_0's binary_logloss: 0.332149
# [426]	valid_0's auc: 0.833543	valid_0's binary_logloss: 0.332139
# [427]	valid_0's auc: 0.833553	valid_0's binary_logloss: 0.332129
# [428]	valid_0's auc: 0.833565	valid_0's binary_logloss: 0.332118
# [429]	valid_0's auc: 0.833613	valid_0's binary_logloss: 0.332077
# [430]	valid_0's auc: 0.833626	valid_0's binary_logloss: 0.332065
# [431]	valid_0's auc: 0.833635	valid_0's binary_logloss: 0.332058
# [432]	valid_0's auc: 0.833652	valid_0's binary_logloss: 0.332046
# [433]	valid_0's auc: 0.833663	valid_0's binary_logloss: 0.332034
# [434]	valid_0's auc: 0.833671	valid_0's binary_logloss: 0.33203
# [435]	valid_0's auc: 0.833676	valid_0's binary_logloss: 0.332026
# [436]	valid_0's auc: 0.833678	valid_0's binary_logloss: 0.332027
# [437]	valid_0's auc: 0.833696	valid_0's binary_logloss: 0.332013
# [438]	valid_0's auc: 0.833698	valid_0's binary_logloss: 0.33201
# [439]	valid_0's auc: 0.833695	valid_0's binary_logloss: 0.332012
# [440]	valid_0's auc: 0.83371	valid_0's binary_logloss: 0.332001
# [441]	valid_0's auc: 0.833742	valid_0's binary_logloss: 0.331975
# [442]	valid_0's auc: 0.833765	valid_0's binary_logloss: 0.331955
# [443]	valid_0's auc: 0.833776	valid_0's binary_logloss: 0.331948
# [444]	valid_0's auc: 0.833809	valid_0's binary_logloss: 0.331919
# [445]	valid_0's auc: 0.833811	valid_0's binary_logloss: 0.331917
# [446]	valid_0's auc: 0.833825	valid_0's binary_logloss: 0.331906
# [447]	valid_0's auc: 0.833855	valid_0's binary_logloss: 0.33187
# [448]	valid_0's auc: 0.833861	valid_0's binary_logloss: 0.331865
# [449]	valid_0's auc: 0.83387	valid_0's binary_logloss: 0.33186
# [450]	valid_0's auc: 0.833874	valid_0's binary_logloss: 0.331855
# [451]	valid_0's auc: 0.833879	valid_0's binary_logloss: 0.331851
# [452]	valid_0's auc: 0.833891	valid_0's binary_logloss: 0.331839
# [453]	valid_0's auc: 0.833902	valid_0's binary_logloss: 0.331831
# [454]	valid_0's auc: 0.83391	valid_0's binary_logloss: 0.331825
# [455]	valid_0's auc: 0.833919	valid_0's binary_logloss: 0.331817
# [456]	valid_0's auc: 0.833929	valid_0's binary_logloss: 0.331809
# [457]	valid_0's auc: 0.833934	valid_0's binary_logloss: 0.331806
# [458]	valid_0's auc: 0.833938	valid_0's binary_logloss: 0.331804
# [459]	valid_0's auc: 0.83394	valid_0's binary_logloss: 0.331801
# [460]	valid_0's auc: 0.833946	valid_0's binary_logloss: 0.331798
# [461]	valid_0's auc: 0.833948	valid_0's binary_logloss: 0.331796
# [462]	valid_0's auc: 0.83396	valid_0's binary_logloss: 0.331782
# [463]	valid_0's auc: 0.833972	valid_0's binary_logloss: 0.331771
# [464]	valid_0's auc: 0.833972	valid_0's binary_logloss: 0.331771
# [465]	valid_0's auc: 0.833976	valid_0's binary_logloss: 0.331768
# [466]	valid_0's auc: 0.834008	valid_0's binary_logloss: 0.331743
# [467]	valid_0's auc: 0.834011	valid_0's binary_logloss: 0.331741
# [468]	valid_0's auc: 0.834009	valid_0's binary_logloss: 0.331741
# [469]	valid_0's auc: 0.834008	valid_0's binary_logloss: 0.331742
# [470]	valid_0's auc: 0.834005	valid_0's binary_logloss: 0.331744
# [471]	valid_0's auc: 0.834011	valid_0's binary_logloss: 0.331738
# [472]	valid_0's auc: 0.834027	valid_0's binary_logloss: 0.331726
# [473]	valid_0's auc: 0.834027	valid_0's binary_logloss: 0.331725
# [474]	valid_0's auc: 0.834033	valid_0's binary_logloss: 0.33172
# [475]	valid_0's auc: 0.834039	valid_0's binary_logloss: 0.331714
# [476]	valid_0's auc: 0.83404	valid_0's binary_logloss: 0.331713
# [477]	valid_0's auc: 0.834045	valid_0's binary_logloss: 0.331708
# [478]	valid_0's auc: 0.834053	valid_0's binary_logloss: 0.331701
# [479]	valid_0's auc: 0.834057	valid_0's binary_logloss: 0.331697
# [480]	valid_0's auc: 0.834061	valid_0's binary_logloss: 0.331693
# [481]	valid_0's auc: 0.834064	valid_0's binary_logloss: 0.331691
# [482]	valid_0's auc: 0.834067	valid_0's binary_logloss: 0.331687
# [483]	valid_0's auc: 0.834083	valid_0's binary_logloss: 0.331675
# [484]	valid_0's auc: 0.834099	valid_0's binary_logloss: 0.331659
# [485]	valid_0's auc: 0.83411	valid_0's binary_logloss: 0.331652
# [486]	valid_0's auc: 0.834114	valid_0's binary_logloss: 0.33165
# [487]	valid_0's auc: 0.834116	valid_0's binary_logloss: 0.331648
# [488]	valid_0's auc: 0.834121	valid_0's binary_logloss: 0.331644
# [489]	valid_0's auc: 0.834132	valid_0's binary_logloss: 0.331636
# [490]	valid_0's auc: 0.834135	valid_0's binary_logloss: 0.331634
# [491]	valid_0's auc: 0.834134	valid_0's binary_logloss: 0.331633
# [492]	valid_0's auc: 0.834143	valid_0's binary_logloss: 0.331625
# [493]	valid_0's auc: 0.834145	valid_0's binary_logloss: 0.331624
# [494]	valid_0's auc: 0.834158	valid_0's binary_logloss: 0.331615
# [495]	valid_0's auc: 0.834177	valid_0's binary_logloss: 0.331602
# [496]	valid_0's auc: 0.834182	valid_0's binary_logloss: 0.331598
# [497]	valid_0's auc: 0.834185	valid_0's binary_logloss: 0.331595
# [498]	valid_0's auc: 0.834186	valid_0's binary_logloss: 0.331594
# [499]	valid_0's auc: 0.834189	valid_0's binary_logloss: 0.331592
# [500]	valid_0's auc: 0.834191	valid_0's binary_logloss: 0.331591
# [501]	valid_0's auc: 0.834194	valid_0's binary_logloss: 0.331589
# [502]	valid_0's auc: 0.834191	valid_0's binary_logloss: 0.331591
# [503]	valid_0's auc: 0.834197	valid_0's binary_logloss: 0.331586
# [504]	valid_0's auc: 0.834202	valid_0's binary_logloss: 0.331583
# [505]	valid_0's auc: 0.834204	valid_0's binary_logloss: 0.331582
# [506]	valid_0's auc: 0.834216	valid_0's binary_logloss: 0.331573
# [507]	valid_0's auc: 0.83422	valid_0's binary_logloss: 0.331569
# [508]	valid_0's auc: 0.834221	valid_0's binary_logloss: 0.331567
# [509]	valid_0's auc: 0.834222	valid_0's binary_logloss: 0.331564
# [510]	valid_0's auc: 0.834254	valid_0's binary_logloss: 0.331536
# [511]	valid_0's auc: 0.834262	valid_0's binary_logloss: 0.331531
# [512]	valid_0's auc: 0.834286	valid_0's binary_logloss: 0.331516
# [513]	valid_0's auc: 0.83429	valid_0's binary_logloss: 0.331511
# [514]	valid_0's auc: 0.834293	valid_0's binary_logloss: 0.33151
# [515]	valid_0's auc: 0.834299	valid_0's binary_logloss: 0.331506
# [516]	valid_0's auc: 0.8343	valid_0's binary_logloss: 0.331505
# [517]	valid_0's auc: 0.834306	valid_0's binary_logloss: 0.331499
# [518]	valid_0's auc: 0.834308	valid_0's binary_logloss: 0.331497
# [519]	valid_0's auc: 0.834308	valid_0's binary_logloss: 0.331494
# [520]	valid_0's auc: 0.834324	valid_0's binary_logloss: 0.331483
# [521]	valid_0's auc: 0.834329	valid_0's binary_logloss: 0.331477
# [522]	valid_0's auc: 0.834334	valid_0's binary_logloss: 0.33147
# [523]	valid_0's auc: 0.834344	valid_0's binary_logloss: 0.331462
# [524]	valid_0's auc: 0.834344	valid_0's binary_logloss: 0.331462
# [525]	valid_0's auc: 0.83435	valid_0's binary_logloss: 0.331457
# [526]	valid_0's auc: 0.834371	valid_0's binary_logloss: 0.331441
# [527]	valid_0's auc: 0.834373	valid_0's binary_logloss: 0.331441
# [528]	valid_0's auc: 0.834374	valid_0's binary_logloss: 0.331439
# [529]	valid_0's auc: 0.834394	valid_0's binary_logloss: 0.331424
# [530]	valid_0's auc: 0.834401	valid_0's binary_logloss: 0.331418
# [531]	valid_0's auc: 0.834407	valid_0's binary_logloss: 0.331413
# [532]	valid_0's auc: 0.834407	valid_0's binary_logloss: 0.331412
# [533]	valid_0's auc: 0.834405	valid_0's binary_logloss: 0.331414
# [534]	valid_0's auc: 0.834412	valid_0's binary_logloss: 0.331406
# [535]	valid_0's auc: 0.834418	valid_0's binary_logloss: 0.3314
# [536]	valid_0's auc: 0.834424	valid_0's binary_logloss: 0.331395
# [537]	valid_0's auc: 0.834426	valid_0's binary_logloss: 0.331393
# [538]	valid_0's auc: 0.834424	valid_0's binary_logloss: 0.331394
# [539]	valid_0's auc: 0.834436	valid_0's binary_logloss: 0.331383
# [540]	valid_0's auc: 0.834461	valid_0's binary_logloss: 0.331362
# [541]	valid_0's auc: 0.834472	valid_0's binary_logloss: 0.331354
# [542]	valid_0's auc: 0.834478	valid_0's binary_logloss: 0.331349
# [543]	valid_0's auc: 0.83448	valid_0's binary_logloss: 0.331346
# [544]	valid_0's auc: 0.834482	valid_0's binary_logloss: 0.331345
# [545]	valid_0's auc: 0.83448	valid_0's binary_logloss: 0.331346
# [546]	valid_0's auc: 0.834487	valid_0's binary_logloss: 0.33134
# [547]	valid_0's auc: 0.834501	valid_0's binary_logloss: 0.331328
# [548]	valid_0's auc: 0.834516	valid_0's binary_logloss: 0.331316
# [549]	valid_0's auc: 0.834519	valid_0's binary_logloss: 0.331314
# [550]	valid_0's auc: 0.834518	valid_0's binary_logloss: 0.331314
# [551]	valid_0's auc: 0.834522	valid_0's binary_logloss: 0.33131
# [552]	valid_0's auc: 0.834523	valid_0's binary_logloss: 0.331307
# [553]	valid_0's auc: 0.834528	valid_0's binary_logloss: 0.331305
# [554]	valid_0's auc: 0.834529	valid_0's binary_logloss: 0.331303
# [555]	valid_0's auc: 0.83453	valid_0's binary_logloss: 0.331301
# [556]	valid_0's auc: 0.834541	valid_0's binary_logloss: 0.331292
# [557]	valid_0's auc: 0.834549	valid_0's binary_logloss: 0.331284
# [558]	valid_0's auc: 0.834553	valid_0's binary_logloss: 0.331282
# [559]	valid_0's auc: 0.834555	valid_0's binary_logloss: 0.331281
# [560]	valid_0's auc: 0.834555	valid_0's binary_logloss: 0.331281
# [561]	valid_0's auc: 0.834555	valid_0's binary_logloss: 0.331281
# [562]	valid_0's auc: 0.834557	valid_0's binary_logloss: 0.33128
# [563]	valid_0's auc: 0.834555	valid_0's binary_logloss: 0.331281
# [564]	valid_0's auc: 0.834553	valid_0's binary_logloss: 0.331282
# [565]	valid_0's auc: 0.834553	valid_0's binary_logloss: 0.331281
# [566]	valid_0's auc: 0.83456	valid_0's binary_logloss: 0.331277
# [567]	valid_0's auc: 0.834559	valid_0's binary_logloss: 0.331278
# [568]	valid_0's auc: 0.834559	valid_0's binary_logloss: 0.331278
# [569]	valid_0's auc: 0.834564	valid_0's binary_logloss: 0.331275
# [570]	valid_0's auc: 0.834574	valid_0's binary_logloss: 0.331267
# [571]	valid_0's auc: 0.834578	valid_0's binary_logloss: 0.331263
# [572]	valid_0's auc: 0.834578	valid_0's binary_logloss: 0.331263
# [573]	valid_0's auc: 0.83458	valid_0's binary_logloss: 0.331262
# [574]	valid_0's auc: 0.834582	valid_0's binary_logloss: 0.331261
# [575]	valid_0's auc: 0.834592	valid_0's binary_logloss: 0.331252
# [576]	valid_0's auc: 0.834598	valid_0's binary_logloss: 0.331249
# [577]	valid_0's auc: 0.83461	valid_0's binary_logloss: 0.331238
# [578]	valid_0's auc: 0.834607	valid_0's binary_logloss: 0.33124
# [579]	valid_0's auc: 0.834611	valid_0's binary_logloss: 0.331236
# [580]	valid_0's auc: 0.834619	valid_0's binary_logloss: 0.331229
# [581]	valid_0's auc: 0.834634	valid_0's binary_logloss: 0.331214
# [582]	valid_0's auc: 0.834633	valid_0's binary_logloss: 0.331215
# [583]	valid_0's auc: 0.834643	valid_0's binary_logloss: 0.331206
# [584]	valid_0's auc: 0.83465	valid_0's binary_logloss: 0.3312
# [585]	valid_0's auc: 0.834648	valid_0's binary_logloss: 0.331202
# [586]	valid_0's auc: 0.834647	valid_0's binary_logloss: 0.331203
# [587]	valid_0's auc: 0.83465	valid_0's binary_logloss: 0.331202
# [588]	valid_0's auc: 0.834666	valid_0's binary_logloss: 0.331188
# [589]	valid_0's auc: 0.834682	valid_0's binary_logloss: 0.331178
# [590]	valid_0's auc: 0.834691	valid_0's binary_logloss: 0.331169
# [591]	valid_0's auc: 0.834699	valid_0's binary_logloss: 0.331163
# [592]	valid_0's auc: 0.8347	valid_0's binary_logloss: 0.331163
# [593]	valid_0's auc: 0.834701	valid_0's binary_logloss: 0.331162
# [594]	valid_0's auc: 0.834707	valid_0's binary_logloss: 0.331157
# [595]	valid_0's auc: 0.834714	valid_0's binary_logloss: 0.331152
# [596]	valid_0's auc: 0.834717	valid_0's binary_logloss: 0.331148
# [597]	valid_0's auc: 0.834718	valid_0's binary_logloss: 0.331148
# [598]	valid_0's auc: 0.834725	valid_0's binary_logloss: 0.331142
# [599]	valid_0's auc: 0.834736	valid_0's binary_logloss: 0.331135
# [600]	valid_0's auc: 0.83474	valid_0's binary_logloss: 0.33113
# [601]	valid_0's auc: 0.834746	valid_0's binary_logloss: 0.331126
# [602]	valid_0's auc: 0.834752	valid_0's binary_logloss: 0.331121
# [603]	valid_0's auc: 0.834759	valid_0's binary_logloss: 0.331114
# [604]	valid_0's auc: 0.834767	valid_0's binary_logloss: 0.331106
# [605]	valid_0's auc: 0.834771	valid_0's binary_logloss: 0.331102
# [606]	valid_0's auc: 0.834783	valid_0's binary_logloss: 0.331092
# [607]	valid_0's auc: 0.834781	valid_0's binary_logloss: 0.331094
# [608]	valid_0's auc: 0.834782	valid_0's binary_logloss: 0.331093
# [609]	valid_0's auc: 0.83478	valid_0's binary_logloss: 0.331094
# [610]	valid_0's auc: 0.834782	valid_0's binary_logloss: 0.331092
# [611]	valid_0's auc: 0.834784	valid_0's binary_logloss: 0.331091
# [612]	valid_0's auc: 0.834786	valid_0's binary_logloss: 0.331088
# [613]	valid_0's auc: 0.8348	valid_0's binary_logloss: 0.331078
# [614]	valid_0's auc: 0.834802	valid_0's binary_logloss: 0.331076
# [615]	valid_0's auc: 0.834806	valid_0's binary_logloss: 0.331072
# [616]	valid_0's auc: 0.834804	valid_0's binary_logloss: 0.331073
# [617]	valid_0's auc: 0.834805	valid_0's binary_logloss: 0.331073
# [618]	valid_0's auc: 0.834809	valid_0's binary_logloss: 0.33107
# [619]	valid_0's auc: 0.83481	valid_0's binary_logloss: 0.331069
# [620]	valid_0's auc: 0.834816	valid_0's binary_logloss: 0.331066
# [621]	valid_0's auc: 0.834812	valid_0's binary_logloss: 0.331067
# [622]	valid_0's auc: 0.834815	valid_0's binary_logloss: 0.331065
# [623]	valid_0's auc: 0.83482	valid_0's binary_logloss: 0.331061
# [624]	valid_0's auc: 0.834819	valid_0's binary_logloss: 0.331061
# [625]	valid_0's auc: 0.83483	valid_0's binary_logloss: 0.331053
# [626]	valid_0's auc: 0.834838	valid_0's binary_logloss: 0.331046
# [627]	valid_0's auc: 0.834862	valid_0's binary_logloss: 0.331016
# [628]	valid_0's auc: 0.834864	valid_0's binary_logloss: 0.331014
# [629]	valid_0's auc: 0.834868	valid_0's binary_logloss: 0.33101
# [630]	valid_0's auc: 0.834873	valid_0's binary_logloss: 0.331006
# [631]	valid_0's auc: 0.834883	valid_0's binary_logloss: 0.330998
# [632]	valid_0's auc: 0.834879	valid_0's binary_logloss: 0.331
# [633]	valid_0's auc: 0.834883	valid_0's binary_logloss: 0.330996
# [634]	valid_0's auc: 0.834884	valid_0's binary_logloss: 0.330996
# [635]	valid_0's auc: 0.834884	valid_0's binary_logloss: 0.330995
# [636]	valid_0's auc: 0.834888	valid_0's binary_logloss: 0.330992
# [637]	valid_0's auc: 0.834887	valid_0's binary_logloss: 0.330993
# [638]	valid_0's auc: 0.834911	valid_0's binary_logloss: 0.330966
# [639]	valid_0's auc: 0.834931	valid_0's binary_logloss: 0.33095
# [640]	valid_0's auc: 0.834945	valid_0's binary_logloss: 0.330939
# [641]	valid_0's auc: 0.834953	valid_0's binary_logloss: 0.330935
# [642]	valid_0's auc: 0.83497	valid_0's binary_logloss: 0.330922
# [643]	valid_0's auc: 0.834972	valid_0's binary_logloss: 0.330922
# [644]	valid_0's auc: 0.834982	valid_0's binary_logloss: 0.330915
# [645]	valid_0's auc: 0.834987	valid_0's binary_logloss: 0.330911
# [646]	valid_0's auc: 0.834989	valid_0's binary_logloss: 0.330909
# [647]	valid_0's auc: 0.835	valid_0's binary_logloss: 0.330903
# [648]	valid_0's auc: 0.835014	valid_0's binary_logloss: 0.33089
# [649]	valid_0's auc: 0.835013	valid_0's binary_logloss: 0.33089
# [650]	valid_0's auc: 0.835057	valid_0's binary_logloss: 0.330854
# [651]	valid_0's auc: 0.835066	valid_0's binary_logloss: 0.330847
# [652]	valid_0's auc: 0.835077	valid_0's binary_logloss: 0.330835
# [653]	valid_0's auc: 0.835087	valid_0's binary_logloss: 0.330824
# [654]	valid_0's auc: 0.835088	valid_0's binary_logloss: 0.330823
# [655]	valid_0's auc: 0.835095	valid_0's binary_logloss: 0.330819
# [656]	valid_0's auc: 0.835097	valid_0's binary_logloss: 0.330817
# [657]	valid_0's auc: 0.835097	valid_0's binary_logloss: 0.330816
# [658]	valid_0's auc: 0.835098	valid_0's binary_logloss: 0.330815
# [659]	valid_0's auc: 0.835104	valid_0's binary_logloss: 0.330811
# [660]	valid_0's auc: 0.835105	valid_0's binary_logloss: 0.330809
# [661]	valid_0's auc: 0.835108	valid_0's binary_logloss: 0.330807
# [662]	valid_0's auc: 0.83511	valid_0's binary_logloss: 0.330804
# [663]	valid_0's auc: 0.835117	valid_0's binary_logloss: 0.330797
# [664]	valid_0's auc: 0.835116	valid_0's binary_logloss: 0.330798
# [665]	valid_0's auc: 0.835129	valid_0's binary_logloss: 0.330787
# [666]	valid_0's auc: 0.835137	valid_0's binary_logloss: 0.330778
# [667]	valid_0's auc: 0.835143	valid_0's binary_logloss: 0.330774
# [668]	valid_0's auc: 0.835145	valid_0's binary_logloss: 0.330772
# [669]	valid_0's auc: 0.83515	valid_0's binary_logloss: 0.330765
# [670]	valid_0's auc: 0.835156	valid_0's binary_logloss: 0.330761
# [671]	valid_0's auc: 0.835158	valid_0's binary_logloss: 0.33076
# [672]	valid_0's auc: 0.835183	valid_0's binary_logloss: 0.330733
# [673]	valid_0's auc: 0.835195	valid_0's binary_logloss: 0.330725
# [674]	valid_0's auc: 0.835198	valid_0's binary_logloss: 0.330722
# [675]	valid_0's auc: 0.835196	valid_0's binary_logloss: 0.330722
# [676]	valid_0's auc: 0.835194	valid_0's binary_logloss: 0.330724
# [677]	valid_0's auc: 0.835192	valid_0's binary_logloss: 0.330725
# [678]	valid_0's auc: 0.835202	valid_0's binary_logloss: 0.330718
# [679]	valid_0's auc: 0.835207	valid_0's binary_logloss: 0.330714
# [680]	valid_0's auc: 0.835241	valid_0's binary_logloss: 0.330687
# [681]	valid_0's auc: 0.83524	valid_0's binary_logloss: 0.330688
# [682]	valid_0's auc: 0.835246	valid_0's binary_logloss: 0.330682
# [683]	valid_0's auc: 0.835253	valid_0's binary_logloss: 0.330674
# [684]	valid_0's auc: 0.835253	valid_0's binary_logloss: 0.330674
# [685]	valid_0's auc: 0.835254	valid_0's binary_logloss: 0.330674
# [686]	valid_0's auc: 0.835256	valid_0's binary_logloss: 0.330672
# [687]	valid_0's auc: 0.835259	valid_0's binary_logloss: 0.33067
# [688]	valid_0's auc: 0.835261	valid_0's binary_logloss: 0.330668
# [689]	valid_0's auc: 0.835266	valid_0's binary_logloss: 0.330664
# [690]	valid_0's auc: 0.835274	valid_0's binary_logloss: 0.330655
# [691]	valid_0's auc: 0.835273	valid_0's binary_logloss: 0.330656
# [692]	valid_0's auc: 0.835276	valid_0's binary_logloss: 0.330653
# [693]	valid_0's auc: 0.835276	valid_0's binary_logloss: 0.330653
# [694]	valid_0's auc: 0.835283	valid_0's binary_logloss: 0.330649
# [695]	valid_0's auc: 0.835287	valid_0's binary_logloss: 0.330645
# [696]	valid_0's auc: 0.835291	valid_0's binary_logloss: 0.33064
# [697]	valid_0's auc: 0.835295	valid_0's binary_logloss: 0.330638
# [698]	valid_0's auc: 0.835301	valid_0's binary_logloss: 0.330633
# [699]	valid_0's auc: 0.835323	valid_0's binary_logloss: 0.330617
# [700]	valid_0's auc: 0.835325	valid_0's binary_logloss: 0.330614
# [701]	valid_0's auc: 0.835329	valid_0's binary_logloss: 0.33061
# [702]	valid_0's auc: 0.83534	valid_0's binary_logloss: 0.330602
# [703]	valid_0's auc: 0.835351	valid_0's binary_logloss: 0.330593
# [704]	valid_0's auc: 0.835354	valid_0's binary_logloss: 0.330591
# [705]	valid_0's auc: 0.835354	valid_0's binary_logloss: 0.330591
# [706]	valid_0's auc: 0.835359	valid_0's binary_logloss: 0.330587
# [707]	valid_0's auc: 0.835358	valid_0's binary_logloss: 0.330586
# [708]	valid_0's auc: 0.835356	valid_0's binary_logloss: 0.330589
# [709]	valid_0's auc: 0.835363	valid_0's binary_logloss: 0.330579
# [710]	valid_0's auc: 0.835375	valid_0's binary_logloss: 0.330568
# [711]	valid_0's auc: 0.835373	valid_0's binary_logloss: 0.330569
# [712]	valid_0's auc: 0.835374	valid_0's binary_logloss: 0.330566
# [713]	valid_0's auc: 0.835373	valid_0's binary_logloss: 0.330567
# [714]	valid_0's auc: 0.835376	valid_0's binary_logloss: 0.330564
# [715]	valid_0's auc: 0.835384	valid_0's binary_logloss: 0.330558
# [716]	valid_0's auc: 0.835382	valid_0's binary_logloss: 0.33056
# [717]	valid_0's auc: 0.83539	valid_0's binary_logloss: 0.330555
# [718]	valid_0's auc: 0.835392	valid_0's binary_logloss: 0.330552
# [719]	valid_0's auc: 0.835395	valid_0's binary_logloss: 0.33055
# [720]	valid_0's auc: 0.835408	valid_0's binary_logloss: 0.330538
# [721]	valid_0's auc: 0.835416	valid_0's binary_logloss: 0.330533
# [722]	valid_0's auc: 0.835422	valid_0's binary_logloss: 0.330526
# [723]	valid_0's auc: 0.83542	valid_0's binary_logloss: 0.330527
# [724]	valid_0's auc: 0.835418	valid_0's binary_logloss: 0.330528
# [725]	valid_0's auc: 0.835418	valid_0's binary_logloss: 0.330528
# [726]	valid_0's auc: 0.83542	valid_0's binary_logloss: 0.330525
# [727]	valid_0's auc: 0.835425	valid_0's binary_logloss: 0.330522
# [728]	valid_0's auc: 0.835427	valid_0's binary_logloss: 0.330518
# [729]	valid_0's auc: 0.835432	valid_0's binary_logloss: 0.330514
# [730]	valid_0's auc: 0.835433	valid_0's binary_logloss: 0.330514
# [731]	valid_0's auc: 0.835432	valid_0's binary_logloss: 0.330513
# [732]	valid_0's auc: 0.835432	valid_0's binary_logloss: 0.330515
# [733]	valid_0's auc: 0.835431	valid_0's binary_logloss: 0.330514
# [734]	valid_0's auc: 0.835442	valid_0's binary_logloss: 0.330508
# [735]	valid_0's auc: 0.835449	valid_0's binary_logloss: 0.330502
# [736]	valid_0's auc: 0.835454	valid_0's binary_logloss: 0.330498
# [737]	valid_0's auc: 0.835464	valid_0's binary_logloss: 0.33049
# [738]	valid_0's auc: 0.835466	valid_0's binary_logloss: 0.330488
# ...
# [1760]	valid_0's auc: 0.838598	valid_0's binary_logloss: 0.32783
# [1761]	valid_0's auc: 0.838602	valid_0's binary_logloss: 0.327827
# [1762]	valid_0's auc: 0.838599	valid_0's binary_logloss: 0.327829
# [1763]	valid_0's auc: 0.838604	valid_0's binary_logloss: 0.327825
# [1764]	valid_0's auc: 0.838605	valid_0's binary_logloss: 0.327824
# [1765]	valid_0's auc: 0.838607	valid_0's binary_logloss: 0.327822
# [1766]	valid_0's auc: 0.838609	valid_0's binary_logloss: 0.327821
# [1767]	valid_0's auc: 0.838609	valid_0's binary_logloss: 0.327821
# [1768]	valid_0's auc: 0.838611	valid_0's binary_logloss: 0.327818
# [1769]	valid_0's auc: 0.838612	valid_0's binary_logloss: 0.327817
# [1770]	valid_0's auc: 0.838612	valid_0's binary_logloss: 0.327818
# [1771]	valid_0's auc: 0.83861	valid_0's binary_logloss: 0.327818
# [1772]	valid_0's auc: 0.838608	valid_0's binary_logloss: 0.327819
# [1773]	valid_0's auc: 0.838611	valid_0's binary_logloss: 0.327817
# [1774]	valid_0's auc: 0.838611	valid_0's binary_logloss: 0.327817
# [1775]	valid_0's auc: 0.838609	valid_0's binary_logloss: 0.327818
# [1776]	valid_0's auc: 0.838606	valid_0's binary_logloss: 0.32782
# [1777]	valid_0's auc: 0.838613	valid_0's binary_logloss: 0.327815
# [1778]	valid_0's auc: 0.838617	valid_0's binary_logloss: 0.327812
# [1779]	valid_0's auc: 0.838624	valid_0's binary_logloss: 0.327807
# [1780]	valid_0's auc: 0.838623	valid_0's binary_logloss: 0.327808
# [1781]	valid_0's auc: 0.838625	valid_0's binary_logloss: 0.327807
# [1782]	valid_0's auc: 0.838629	valid_0's binary_logloss: 0.327803
# [1783]	valid_0's auc: 0.83863	valid_0's binary_logloss: 0.327802
# [1784]	valid_0's auc: 0.838632	valid_0's binary_logloss: 0.3278
# [1785]	valid_0's auc: 0.838635	valid_0's binary_logloss: 0.327797
# [1786]	valid_0's auc: 0.838637	valid_0's binary_logloss: 0.327796
# [1787]	valid_0's auc: 0.838637	valid_0's binary_logloss: 0.327796
# [1788]	valid_0's auc: 0.838638	valid_0's binary_logloss: 0.327794
# [1789]	valid_0's auc: 0.83864	valid_0's binary_logloss: 0.327793
# [1790]	valid_0's auc: 0.838643	valid_0's binary_logloss: 0.327791
# [1791]	valid_0's auc: 0.838648	valid_0's binary_logloss: 0.327787
# [1792]	valid_0's auc: 0.838649	valid_0's binary_logloss: 0.327786
# [1793]	valid_0's auc: 0.838649	valid_0's binary_logloss: 0.327786
# [1794]	valid_0's auc: 0.838648	valid_0's binary_logloss: 0.327786
# [1795]	valid_0's auc: 0.83866	valid_0's binary_logloss: 0.327778
# [1796]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.327781
# [1797]	valid_0's auc: 0.838657	valid_0's binary_logloss: 0.32778
# [1798]	valid_0's auc: 0.838658	valid_0's binary_logloss: 0.327778
# [1799]	valid_0's auc: 0.838656	valid_0's binary_logloss: 0.327781
# [1800]	valid_0's auc: 0.838654	valid_0's binary_logloss: 0.327781
# [1801]	valid_0's auc: 0.838653	valid_0's binary_logloss: 0.327782
# [1802]	valid_0's auc: 0.838654	valid_0's binary_logloss: 0.327781
# [1803]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.32778
# [1804]	valid_0's auc: 0.838653	valid_0's binary_logloss: 0.327781
# [1805]	valid_0's auc: 0.838648	valid_0's binary_logloss: 0.327784
# [1806]	valid_0's auc: 0.838649	valid_0's binary_logloss: 0.327784
# [1807]	valid_0's auc: 0.838651	valid_0's binary_logloss: 0.327784
# [1808]	valid_0's auc: 0.838652	valid_0's binary_logloss: 0.327784
# [1809]	valid_0's auc: 0.838652	valid_0's binary_logloss: 0.327784
# [1810]	valid_0's auc: 0.838649	valid_0's binary_logloss: 0.327785
# [1811]	valid_0's auc: 0.838649	valid_0's binary_logloss: 0.327785
# [1812]	valid_0's auc: 0.838651	valid_0's binary_logloss: 0.327785
# [1813]	valid_0's auc: 0.838653	valid_0's binary_logloss: 0.327784
# [1814]	valid_0's auc: 0.838657	valid_0's binary_logloss: 0.327782
# [1815]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.327783
# [1816]	valid_0's auc: 0.838657	valid_0's binary_logloss: 0.327782
# [1817]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.327783
# [1818]	valid_0's auc: 0.838653	valid_0's binary_logloss: 0.327785
# [1819]	valid_0's auc: 0.838651	valid_0's binary_logloss: 0.327787
# [1820]	valid_0's auc: 0.83865	valid_0's binary_logloss: 0.327788
# [1821]	valid_0's auc: 0.838654	valid_0's binary_logloss: 0.327784
# [1822]	valid_0's auc: 0.838656	valid_0's binary_logloss: 0.327782
# [1823]	valid_0's auc: 0.838654	valid_0's binary_logloss: 0.327783
# [1824]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.327783
# [1825]	valid_0's auc: 0.838656	valid_0's binary_logloss: 0.327782
# [1826]	valid_0's auc: 0.838655	valid_0's binary_logloss: 0.327784
# [1827]	valid_0's auc: 0.838657	valid_0's binary_logloss: 0.327782
# [1828]	valid_0's auc: 0.838656	valid_0's binary_logloss: 0.327782
# [1829]	valid_0's auc: 0.838658	valid_0's binary_logloss: 0.327781
# [1830]	valid_0's auc: 0.83866	valid_0's binary_logloss: 0.327779
# [1831]	valid_0's auc: 0.838695	valid_0's binary_logloss: 0.327746
# [1832]	valid_0's auc: 0.838699	valid_0's binary_logloss: 0.327741
# [1833]	valid_0's auc: 0.838702	valid_0's binary_logloss: 0.327738
# [1834]	valid_0's auc: 0.838703	valid_0's binary_logloss: 0.327737
# [1835]	valid_0's auc: 0.838709	valid_0's binary_logloss: 0.327729
# [1836]	valid_0's auc: 0.838711	valid_0's binary_logloss: 0.327726
# [1837]	valid_0's auc: 0.838711	valid_0's binary_logloss: 0.327725
# [1838]	valid_0's auc: 0.83871	valid_0's binary_logloss: 0.327726
# [1839]	valid_0's auc: 0.838712	valid_0's binary_logloss: 0.327724
# [1840]	valid_0's auc: 0.838712	valid_0's binary_logloss: 0.327725
# [1841]	valid_0's auc: 0.838715	valid_0's binary_logloss: 0.327722
# [1842]	valid_0's auc: 0.838718	valid_0's binary_logloss: 0.32772
# [1843]	valid_0's auc: 0.83872	valid_0's binary_logloss: 0.327719
# [1844]	valid_0's auc: 0.838719	valid_0's binary_logloss: 0.32772
# [1845]	valid_0's auc: 0.838723	valid_0's binary_logloss: 0.327717
# [1846]	valid_0's auc: 0.838723	valid_0's binary_logloss: 0.327716
# [1847]	valid_0's auc: 0.838724	valid_0's binary_logloss: 0.327716
# [1848]	valid_0's auc: 0.838725	valid_0's binary_logloss: 0.327716
# [1849]	valid_0's auc: 0.838725	valid_0's binary_logloss: 0.327716
# [1850]	valid_0's auc: 0.838727	valid_0's binary_logloss: 0.327715
# [1851]	valid_0's auc: 0.838727	valid_0's binary_logloss: 0.327715
# [1852]	valid_0's auc: 0.838734	valid_0's binary_logloss: 0.32771
# [1853]	valid_0's auc: 0.838734	valid_0's binary_logloss: 0.32771
# [1854]	valid_0's auc: 0.838734	valid_0's binary_logloss: 0.327709
# [1855]	valid_0's auc: 0.838734	valid_0's binary_logloss: 0.327709
# [1856]	valid_0's auc: 0.83874	valid_0's binary_logloss: 0.327704
# [1857]	valid_0's auc: 0.838741	valid_0's binary_logloss: 0.327703
# [1858]	valid_0's auc: 0.838741	valid_0's binary_logloss: 0.327704
# [1859]	valid_0's auc: 0.838742	valid_0's binary_logloss: 0.327702
# [1860]	valid_0's auc: 0.838743	valid_0's binary_logloss: 0.327702
# [1861]	valid_0's auc: 0.838742	valid_0's binary_logloss: 0.327701
# [1862]	valid_0's auc: 0.83874	valid_0's binary_logloss: 0.327702
# [1863]	valid_0's auc: 0.838741	valid_0's binary_logloss: 0.327701
# [1864]	valid_0's auc: 0.838744	valid_0's binary_logloss: 0.3277
# [1865]	valid_0's auc: 0.838748	valid_0's binary_logloss: 0.327697
# [1866]	valid_0's auc: 0.838749	valid_0's binary_logloss: 0.327698
# [1867]	valid_0's auc: 0.838748	valid_0's binary_logloss: 0.327699
# [1868]	valid_0's auc: 0.838752	valid_0's binary_logloss: 0.327695
# [1869]	valid_0's auc: 0.838752	valid_0's binary_logloss: 0.327694
# [1870]	valid_0's auc: 0.838754	valid_0's binary_logloss: 0.327692
# [1871]	valid_0's auc: 0.838753	valid_0's binary_logloss: 0.327692
# [1872]	valid_0's auc: 0.838756	valid_0's binary_logloss: 0.32769
# [1873]	valid_0's auc: 0.838756	valid_0's binary_logloss: 0.32769
# [1874]	valid_0's auc: 0.838759	valid_0's binary_logloss: 0.327687
# [1875]	valid_0's auc: 0.83876	valid_0's binary_logloss: 0.327687
# [1876]	valid_0's auc: 0.83876	valid_0's binary_logloss: 0.327687
# [1877]	valid_0's auc: 0.838762	valid_0's binary_logloss: 0.327685
# [1878]	valid_0's auc: 0.838765	valid_0's binary_logloss: 0.327683
# [1879]	valid_0's auc: 0.838763	valid_0's binary_logloss: 0.327683
# [1880]	valid_0's auc: 0.838764	valid_0's binary_logloss: 0.327684
# [1881]	valid_0's auc: 0.838766	valid_0's binary_logloss: 0.327682
# [1882]	valid_0's auc: 0.83877	valid_0's binary_logloss: 0.327679
# [1883]	valid_0's auc: 0.838771	valid_0's binary_logloss: 0.327678
# [1884]	valid_0's auc: 0.83877	valid_0's binary_logloss: 0.327678
# [1885]	valid_0's auc: 0.838772	valid_0's binary_logloss: 0.327676
# [1886]	valid_0's auc: 0.838769	valid_0's binary_logloss: 0.327678
# [1887]	valid_0's auc: 0.838772	valid_0's binary_logloss: 0.327676
# [1888]	valid_0's auc: 0.838772	valid_0's binary_logloss: 0.327675
# [1889]	valid_0's auc: 0.838776	valid_0's binary_logloss: 0.327672
# [1890]	valid_0's auc: 0.838777	valid_0's binary_logloss: 0.327671
# [1891]	valid_0's auc: 0.838778	valid_0's binary_logloss: 0.327671
# [1892]	valid_0's auc: 0.83878	valid_0's binary_logloss: 0.32767
# [1893]	valid_0's auc: 0.838783	valid_0's binary_logloss: 0.327667
# [1894]	valid_0's auc: 0.838788	valid_0's binary_logloss: 0.327664
# [1895]	valid_0's auc: 0.838787	valid_0's binary_logloss: 0.327664
# [1896]	valid_0's auc: 0.838791	valid_0's binary_logloss: 0.327662
# [1897]	valid_0's auc: 0.838793	valid_0's binary_logloss: 0.327659
# [1898]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327657
# [1899]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327656
# [1900]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327657
# [1901]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327658
# [1902]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327657
# [1903]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327657
# [1904]	valid_0's auc: 0.838797	valid_0's binary_logloss: 0.327656
# [1905]	valid_0's auc: 0.838797	valid_0's binary_logloss: 0.327655
# [1906]	valid_0's auc: 0.838802	valid_0's binary_logloss: 0.32765
# [1907]	valid_0's auc: 0.8388	valid_0's binary_logloss: 0.327651
# [1908]	valid_0's auc: 0.838801	valid_0's binary_logloss: 0.327651
# [1909]	valid_0's auc: 0.838797	valid_0's binary_logloss: 0.327653
# [1910]	valid_0's auc: 0.838797	valid_0's binary_logloss: 0.327652
# [1911]	valid_0's auc: 0.8388	valid_0's binary_logloss: 0.327652
# [1912]	valid_0's auc: 0.838804	valid_0's binary_logloss: 0.327649
# [1913]	valid_0's auc: 0.838804	valid_0's binary_logloss: 0.327648
# [1914]	valid_0's auc: 0.838807	valid_0's binary_logloss: 0.327646
# [1915]	valid_0's auc: 0.838807	valid_0's binary_logloss: 0.327647
# [1916]	valid_0's auc: 0.838809	valid_0's binary_logloss: 0.327646
# [1917]	valid_0's auc: 0.83881	valid_0's binary_logloss: 0.327645
# [1918]	valid_0's auc: 0.83881	valid_0's binary_logloss: 0.327645
# [1919]	valid_0's auc: 0.838808	valid_0's binary_logloss: 0.327647
# [1920]	valid_0's auc: 0.838806	valid_0's binary_logloss: 0.327647
# [1921]	valid_0's auc: 0.838809	valid_0's binary_logloss: 0.327646
# [1922]	valid_0's auc: 0.838808	valid_0's binary_logloss: 0.327645
# [1923]	valid_0's auc: 0.838809	valid_0's binary_logloss: 0.327645
# [1924]	valid_0's auc: 0.838807	valid_0's binary_logloss: 0.327647
# [1925]	valid_0's auc: 0.83881	valid_0's binary_logloss: 0.327645
# [1926]	valid_0's auc: 0.838811	valid_0's binary_logloss: 0.32764
# [1927]	valid_0's auc: 0.838812	valid_0's binary_logloss: 0.327639
# [1928]	valid_0's auc: 0.838812	valid_0's binary_logloss: 0.327638
# [1929]	valid_0's auc: 0.838816	valid_0's binary_logloss: 0.327637
# [1930]	valid_0's auc: 0.838815	valid_0's binary_logloss: 0.327636
# [1931]	valid_0's auc: 0.838818	valid_0's binary_logloss: 0.327634
# [1932]	valid_0's auc: 0.838818	valid_0's binary_logloss: 0.327634
# [1933]	valid_0's auc: 0.838821	valid_0's binary_logloss: 0.327632
# [1934]	valid_0's auc: 0.838818	valid_0's binary_logloss: 0.327633
# [1935]	valid_0's auc: 0.83882	valid_0's binary_logloss: 0.327633
# [1936]	valid_0's auc: 0.838829	valid_0's binary_logloss: 0.327627
# [1937]	valid_0's auc: 0.838833	valid_0's binary_logloss: 0.327624
# [1938]	valid_0's auc: 0.838835	valid_0's binary_logloss: 0.327623
# [1939]	valid_0's auc: 0.838834	valid_0's binary_logloss: 0.327623
# [1940]	valid_0's auc: 0.838834	valid_0's binary_logloss: 0.327623
# [1941]	valid_0's auc: 0.838833	valid_0's binary_logloss: 0.327623
# [1942]	valid_0's auc: 0.838837	valid_0's binary_logloss: 0.32762
# [1943]	valid_0's auc: 0.838844	valid_0's binary_logloss: 0.327615
# [1944]	valid_0's auc: 0.838846	valid_0's binary_logloss: 0.327613
# [1945]	valid_0's auc: 0.838846	valid_0's binary_logloss: 0.327613
# [1946]	valid_0's auc: 0.838845	valid_0's binary_logloss: 0.327614
# [1947]	valid_0's auc: 0.838845	valid_0's binary_logloss: 0.327614
# [1948]	valid_0's auc: 0.838849	valid_0's binary_logloss: 0.327611
# [1949]	valid_0's auc: 0.838846	valid_0's binary_logloss: 0.327612
# [1950]	valid_0's auc: 0.838848	valid_0's binary_logloss: 0.327611
# [1951]	valid_0's auc: 0.838846	valid_0's binary_logloss: 0.327612
# [1952]	valid_0's auc: 0.838848	valid_0's binary_logloss: 0.32761
# [1953]	valid_0's auc: 0.83885	valid_0's binary_logloss: 0.327609
# [1954]	valid_0's auc: 0.838855	valid_0's binary_logloss: 0.327606
# [1955]	valid_0's auc: 0.838863	valid_0's binary_logloss: 0.3276
# [1956]	valid_0's auc: 0.838864	valid_0's binary_logloss: 0.327599
# [1957]	valid_0's auc: 0.838866	valid_0's binary_logloss: 0.327596
# [1958]	valid_0's auc: 0.838867	valid_0's binary_logloss: 0.327595
# [1959]	valid_0's auc: 0.838869	valid_0's binary_logloss: 0.327594
# [1960]	valid_0's auc: 0.838869	valid_0's binary_logloss: 0.327595
# [1961]	valid_0's auc: 0.838878	valid_0's binary_logloss: 0.327588
# [1962]	valid_0's auc: 0.838883	valid_0's binary_logloss: 0.327585
# [1963]	valid_0's auc: 0.83889	valid_0's binary_logloss: 0.327578
# [1964]	valid_0's auc: 0.838893	valid_0's binary_logloss: 0.327575
# [1965]	valid_0's auc: 0.838892	valid_0's binary_logloss: 0.327577
# [1966]	valid_0's auc: 0.838893	valid_0's binary_logloss: 0.327576
# [1967]	valid_0's auc: 0.838899	valid_0's binary_logloss: 0.327571
# [1968]	valid_0's auc: 0.838903	valid_0's binary_logloss: 0.327567
# [1969]	valid_0's auc: 0.838903	valid_0's binary_logloss: 0.327566
# [1970]	valid_0's auc: 0.838905	valid_0's binary_logloss: 0.327565
# [1971]	valid_0's auc: 0.838908	valid_0's binary_logloss: 0.327563
# [1972]	valid_0's auc: 0.838912	valid_0's binary_logloss: 0.327559
# [1973]	valid_0's auc: 0.838917	valid_0's binary_logloss: 0.327555
# [1974]	valid_0's auc: 0.838921	valid_0's binary_logloss: 0.327553
# [1975]	valid_0's auc: 0.838918	valid_0's binary_logloss: 0.327555
# [1976]	valid_0's auc: 0.83892	valid_0's binary_logloss: 0.327551
# [1977]	valid_0's auc: 0.838921	valid_0's binary_logloss: 0.32755
# [1978]	valid_0's auc: 0.838921	valid_0's binary_logloss: 0.327549
# [1979]	valid_0's auc: 0.838925	valid_0's binary_logloss: 0.327546
# [1980]	valid_0's auc: 0.838926	valid_0's binary_logloss: 0.327546
# [1981]	valid_0's auc: 0.838927	valid_0's binary_logloss: 0.327545
# [1982]	valid_0's auc: 0.83893	valid_0's binary_logloss: 0.327543
# [1983]	valid_0's auc: 0.838928	valid_0's binary_logloss: 0.327545
# [1984]	valid_0's auc: 0.838931	valid_0's binary_logloss: 0.327544
# [1985]	valid_0's auc: 0.838938	valid_0's binary_logloss: 0.32754
# [1986]	valid_0's auc: 0.83894	valid_0's binary_logloss: 0.327539
# [1987]	valid_0's auc: 0.838936	valid_0's binary_logloss: 0.327541
# [1988]	valid_0's auc: 0.838935	valid_0's binary_logloss: 0.327541
# [1989]	valid_0's auc: 0.838935	valid_0's binary_logloss: 0.327542
# [1990]	valid_0's auc: 0.838936	valid_0's binary_logloss: 0.327541
# [1991]	valid_0's auc: 0.838934	valid_0's binary_logloss: 0.327542
# [1992]	valid_0's auc: 0.838932	valid_0's binary_logloss: 0.327543
# [1993]	valid_0's auc: 0.838927	valid_0's binary_logloss: 0.327546
# [1994]	valid_0's auc: 0.838928	valid_0's binary_logloss: 0.327546
# [1995]	valid_0's auc: 0.838925	valid_0's binary_logloss: 0.327547
# [1996]	valid_0's auc: 0.838923	valid_0's binary_logloss: 0.327549
# [1997]	valid_0's auc: 0.838919	valid_0's binary_logloss: 0.327552
# [1998]	valid_0's auc: 0.838924	valid_0's binary_logloss: 0.327545
# [1999]	valid_0's auc: 0.83893	valid_0's binary_logloss: 0.32754
# [2000]	valid_0's auc: 0.838933	valid_0's binary_logloss: 0.327539
# Did not meet early stopping. Best iteration is:
# [1986]	valid_0's auc: 0.83894	valid_0's binary_logloss: 0.327539

# %%
sub.to_csv('./result/2000_0.838811.txt', index=None, header=None, sep='\t')

# %%
fi = pd.DataFrame({'feature': feature_cols, 'imp': model_lgb.feature_importances_})
fi['rate'] = fi['imp'] / fi['imp'].sum()

# %%
fi
# Out:
#                 feature   imp      rate
# 0                  freq   397  0.006663
# 1                gender   331  0.005556
# 2                  hour  2433  0.040836
# 3           q_ans_count   351  0.005891
# 4    q_diff_qa_days_max   454  0.007620
# ..                  ...   ...       ...
# 121         uf_c2_count   386  0.006479
# 122         uf_c3_count  1258  0.021114
# 123         uf_c4_count  1228  0.020611
# 124         uf_c5_count     0  0.000000
# 125                  wk  1348  0.022625
#
# [126 rows x 3 columns]

# %%
fi.sort_values(by='rate', ascending=False)[:60]
# Out:
#                  feature   imp      rate
# 54                 score  3442  0.057771
# 117        qid_enc_count  3064  0.051427
# 2                   hour  2433  0.040836
# 53               qid_enc  2239  0.037580
# 115              uid_enc  2191  0.036774
# 116        uid_enc_count  1966  0.032998
# 66            u_inv_mean  1674  0.028097
# 65           u_inv_count  1580  0.026519
# 57   u_diff_qa_days_mean  1447  0.024287
# 125                   wk  1348  0.022625
# 103    u_word_count_mean  1331  0.022340
# 113                uf_c4  1305  0.021903
# 104     u_word_count_sum  1292  0.021685
# 67             u_inv_std  1259  0.021131
# 122          uf_c3_count  1258  0.021114
# 123          uf_c4_count  1228  0.020611
# 112                uf_c3  1203  0.020191
# 110                uf_c1  1169  0.019621
# 102     u_word_count_max  1158  0.019436
# 56    u_diff_qa_days_max  1070  0.017959
# 55           u_ans_count  1070  0.017959
# 58    u_diff_qa_days_sum   943  0.015827
# 120          uf_c1_count   917  0.015391
# 13           q_inv_count   914  0.015341
# 14            q_inv_mean   905  0.015190
# 79     u_reci_cheer_mean   803  0.013478
# 51     q_word_count_mean   785  0.013176
# 15             q_inv_std   753  0.012638
# 82   u_reci_comment_mean   736  0.012353
# 68             u_inv_sum   670  0.011245
# 94       u_reci_tks_mean   651  0.010926
# 50      q_word_count_max   636  0.010675
# 85       u_reci_dis_mean   573  0.009617
# 5    q_diff_qa_days_mean   557  0.009349
# 60        u_has_img_mean   527  0.008845
# 111                uf_c2   513  0.008610
# 52      q_word_count_sum   513  0.008610
# 81    u_reci_comment_max   502  0.008426
# 88      u_reci_mark_mean   490  0.008224
# 27     q_reci_cheer_mean   469  0.007872
# 80      u_reci_cheer_sum   468  0.007855
# 83    u_reci_comment_sum   456  0.007654
# 4     q_diff_qa_days_max   454  0.007620
# 119           freq_count   444  0.007452
# 16             q_inv_sum   428  0.007184
# 30   q_reci_comment_mean   422  0.007083
# 78      u_reci_cheer_max   403  0.006764
# 0                   freq   397  0.006663
# 6     q_diff_qa_days_sum   397  0.006663
# 121          uf_c2_count   386  0.006479
# 100      u_reci_xxx_mean   378  0.006344
# 42       q_reci_tks_mean   375  0.006294
# 8         q_has_img_mean   363  0.006093
# 3            q_ans_count   351  0.005891
# 1                 gender   331  0.005556
# 36      q_reci_mark_mean   307  0.005153
# 95        u_reci_tks_sum   280  0.004700
# 87       u_reci_mark_max   274  0.004599
# 86        u_reci_dis_sum   261  0.004381
# 89       u_reci_mark_sum   256  0.004297

# %%
feature_cols
# Out:
# ['freq',
#  'gender',
#  'hour',
#  'q_ans_count',
#  'q_diff_qa_days_max',
#  'q_diff_qa_days_mean',
#  'q_diff_qa_days_sum',
#  'q_has_img_max',
#  'q_has_img_mean',
#  'q_has_img_sum',
#  'q_has_video_max',
#  'q_has_video_mean',
#  'q_has_video_sum',
#  'q_inv_count',
#  'q_inv_mean',
#  'q_inv_std',
#  'q_inv_sum',
#  'q_is_dest_max',
#  'q_is_dest_mean',
#  'q_is_dest_sum',
#  'q_is_good_max',
#  'q_is_good_mean',
#  'q_is_good_sum',
#  'q_is_rec_max',
#  'q_is_rec_mean',
#  'q_is_rec_sum',
#  'q_reci_cheer_max',
#  'q_reci_cheer_mean',
#  'q_reci_cheer_sum',
#  'q_reci_comment_max',
#  'q_reci_comment_mean',
#  'q_reci_comment_sum',
#  'q_reci_dis_max',
#  'q_reci_dis_mean',
#  'q_reci_dis_sum',
#  'q_reci_mark_max',
#  'q_reci_mark_mean',
#  'q_reci_mark_sum',
#  'q_reci_no_help_max',
#  'q_reci_no_help_mean',
#  'q_reci_no_help_sum',
#  'q_reci_tks_max',
#  'q_reci_tks_mean',
#  'q_reci_tks_sum',
#  'q_reci_uncheer_max',
#  'q_reci_uncheer_mean',
#  'q_reci_uncheer_sum',
#  'q_reci_xxx_max',
#  'q_reci_xxx_mean',
#  'q_reci_xxx_sum',
#  'q_word_count_max',
#  'q_word_count_mean',
#  'q_word_count_sum',
#  'qid_enc',
#  'score',
#  'u_ans_count',
#  'u_diff_qa_days_max',
#  'u_diff_qa_days_mean',
#  'u_diff_qa_days_sum',
#  'u_has_img_max',
#  'u_has_img_mean',
#  'u_has_img_sum',
#  'u_has_video_max',
#  'u_has_video_mean',
#  'u_has_video_sum',
#  'u_inv_count',
#  'u_inv_mean',
#  'u_inv_std',
#  'u_inv_sum',
#  'u_is_dest_max',
#  'u_is_dest_mean',
#  'u_is_dest_sum',
#  'u_is_good_max',
#  'u_is_good_mean',
#  'u_is_good_sum',
#  'u_is_rec_max',
#  'u_is_rec_mean',
#  'u_is_rec_sum',
#  'u_reci_cheer_max',
#  'u_reci_cheer_mean',
#  'u_reci_cheer_sum',
#  'u_reci_comment_max',
#  'u_reci_comment_mean',
#  'u_reci_comment_sum',
#  'u_reci_dis_max',
#  'u_reci_dis_mean',
#  'u_reci_dis_sum',
#  'u_reci_mark_max',
#  'u_reci_mark_mean',
#  'u_reci_mark_sum',
#  'u_reci_no_help_max',
#  'u_reci_no_help_mean',
#  'u_reci_no_help_sum',
#  'u_reci_tks_max',
#  'u_reci_tks_mean',
#  'u_reci_tks_sum',
#  'u_reci_uncheer_max',
#  'u_reci_uncheer_mean',
#  'u_reci_uncheer_sum',
#  'u_reci_xxx_max',
#  'u_reci_xxx_mean',
#  'u_reci_xxx_sum',
#  'u_word_count_max',
#  'u_word_count_mean',
#  'u_word_count_sum',
#  'uf_b1',
#  'uf_b2',
#  'uf_b3',
#  'uf_b4',
#  'uf_b5',
#  'uf_c1',
#  'uf_c2',
#  'uf_c3',
#  'uf_c4',
#  'uf_c5',
#  'uid_enc',
#  'uid_enc_count',
#  'qid_enc_count',
#  'gender_count',
#  'freq_count',
#  'uf_c1_count',
#  'uf_c2_count',
#  'uf_c3_count',
#  'uf_c4_count',
#  'uf_c5_count',
#  'wk']
