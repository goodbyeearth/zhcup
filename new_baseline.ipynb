# %%
# -*- coding: utf-8 -*-


import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
import logging

# %%
log_fmt = "[%(asctime)s] %(levelname)s in %(module)s: %(message)s"
logging.basicConfig(format=log_fmt, level=logging.INFO)

import warnings
warnings.filterwarnings('ignore')


def extract_day(s):
    return s.apply(lambda x: int(x.split('-')[0][1:]))


def extract_hour(s):
    return s.apply(lambda x: int(x.split('-')[1][1:]))

# %%
base_path = './data'

# %%
# 加载邀请回答数据

train = pd.read_csv(f'{base_path}/invite_info_0926.txt', sep='\t', header=None)
train.columns = ['qid', 'uid', 'dt', 'label']
logging.info("invite %s", train.shape)

test = pd.read_csv(f'{base_path}/invite_info_evaluate_0926.txt', sep='\t', header=None)
test.columns = ['qid', 'uid', 'dt']
logging.info("test %s", test.shape)

sub = test.copy()

sub_size = len(sub)

train['day'] = extract_day(train['dt'])
train['hour'] = extract_hour(train['dt'])

test['day'] = extract_day(test['dt'])
test['hour'] = extract_hour(test['dt'])

del train['dt'], test['dt']
# Out:
# [2019-11-25 07:06:53,893] INFO in <ipython-input-7-d8d667ebe145>: invite (9489162, 4)
# [2019-11-25 07:06:55,284] INFO in <ipython-input-7-d8d667ebe145>: test (1141683, 3)

# %%
# 加载问题
ques = pd.read_csv(f'{base_path}/question_info_0926.txt', header=None, sep='\t')
ques.columns = ['qid', 'q_dt', 'title_t1', 'title_t2', 'desc_t1', 'desc_t2', 'topic']
del ques['title_t1'], ques['title_t2'], ques['desc_t1'], ques['desc_t2']
logging.info("ques %s", ques.shape)

ques['q_day'] = extract_day(ques['q_dt'])
ques['q_hour'] = extract_hour(ques['q_dt'])

del ques['q_dt']
# Out:
# [2019-11-25 07:08:12,286] INFO in <ipython-input-8-1bb9e9c15e2e>: ques (1829900, 3)

# %%
# 加载回答
ans = pd.read_csv(f'{base_path}/answer_info_0926.txt', header=None, sep='\t')
ans.columns = ['aid', 'qid', 'uid', 'ans_dt', 'ans_t1', 'ans_t2', 'is_good', 'is_rec', 'is_dest', 'has_img',
               'has_video', 'word_count', 'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
               'reci_xxx', 'reci_no_help', 'reci_dis']
del ans['ans_t1'], ans['ans_t2']
logging.info("ans %s", ans.shape)

ans['a_day'] = extract_day(ans['ans_dt'])
ans['a_hour'] = extract_hour(ans['ans_dt'])
del ans['ans_dt']

ans = pd.merge(ans, ques, on='qid')
del ques
# Out:
# [2019-11-25 07:09:45,518] INFO in <ipython-input-10-0f04b531e5be>: ans (4513735, 18)

# %%
# 回答距提问的天数
ans['diff_qa_days'] = ans['a_day'] - ans['q_day']

# %%
# 时间窗口划分
train_start = 3838
train_end = 3867

val_start = 3868
val_end = 3874

label_end = 3867
label_start = label_end - 6

train_label_feature_end = label_end - 7
train_label_feature_start = train_label_feature_end - 22

train_ans_feature_end = label_end - 7
train_ans_feature_start = train_ans_feature_end - 50

val_label_feature_end = val_start - 1
val_label_feature_start = val_label_feature_end - 22

val_ans_feature_end = val_start - 1
val_ans_feature_start = val_ans_feature_end - 50

# 3838~3860
train_label_feature = train[(train['day'] >= train_label_feature_start) & (train['day'] <= train_label_feature_end)]
logging.info("train_label_feature %s", train_label_feature.shape)

# 3845~3867
val_label_feature = train[(train['day'] >= val_label_feature_start) & (train['day'] <= val_label_feature_end)]
logging.info("val_label_feature %s", val_label_feature.shape)

# 3861~3867
train_label = train[(train['day'] > train_label_feature_end)]

logging.info("train feature start %s end %s, label start %s end %s", train_label_feature['day'].min(),
             train_label_feature['day'].max(), train_label['day'].min(), train_label['day'].max())

logging.info("test feature start %s end %s, label start %s end %s", val_label_feature['day'].min(),
             val_label_feature['day'].max(), test['day'].min(), test['day'].max())
# Out:
#   File "<ipython-input-27-10c3d59857a1>", line 22
#     ＃
#     ^
# SyntaxError: invalid character in identifier

# %%
# 确定ans的时间范围
# 3807~3874

# 3810~3860
train_ans_feature = ans[(ans['a_day'] >= train_ans_feature_start) & (ans['a_day'] <= train_ans_feature_end)]

# 3817~3867
val_ans_feature = ans[(ans['a_day'] >= val_ans_feature_start) & (ans['a_day'] <= val_ans_feature_end)]

logging.info("train ans feature %s, start %s end %s", train_ans_feature.shape, train_ans_feature['a_day'].min(),
             train_ans_feature['a_day'].max())

logging.info("val ans feature %s, start %s end %s", val_ans_feature.shape, val_ans_feature['a_day'].min(),
             val_ans_feature['a_day'].max())

fea_cols = ['is_good', 'is_rec', 'is_dest', 'has_img', 'has_video', 'word_count',
            'reci_cheer', 'reci_uncheer', 'reci_comment', 'reci_mark', 'reci_tks',
            'reci_xxx', 'reci_no_help', 'reci_dis', 'diff_qa_days']
# Out:
# [2019-11-25 07:10:35,967] INFO in <ipython-input-13-aa15f72a2344>: train ans feature (3700178, 23), start 3810 end 3860
# [2019-11-25 07:10:35,984] INFO in <ipython-input-13-aa15f72a2344>: val ans feature (3992334, 23), start 3817 end 3867

# %%
def extract_feature1(target, label_feature, ans_feature):
    # 问题特征
    t1 = label_feature.groupby('qid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['qid', 'q_inv_mean', 'q_inv_sum', 'q_inv_std', 'q_inv_count']
    target = pd.merge(target, t1, on='qid', how='left')

    # 用户特征
    t1 = label_feature.groupby('uid')['label'].agg(['mean', 'sum', 'std', 'count']).reset_index()
    t1.columns = ['uid', 'u_inv_mean', 'u_inv_sum', 'u_inv_std', 'u_inv_count']
    target = pd.merge(target, t1, on='uid', how='left')
    #
    # train_size = len(train)
    # data = pd.concat((train, test), sort=True)

    # 回答部分特征

    t1 = ans_feature.groupby('qid')['aid'].count().reset_index()
    t1.columns = ['qid', 'q_ans_count']
    target = pd.merge(target, t1, on='qid', how='left')

    t1 = ans_feature.groupby('uid')['aid'].count().reset_index()
    t1.columns = ['uid', 'u_ans_count']
    target = pd.merge(target, t1, on='uid', how='left')

    for col in fea_cols:
        t1 = ans_feature.groupby('uid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['uid', f'u_{col}_sum', f'u_{col}_max', f'u_{col}_mean']
        target = pd.merge(target, t1, on='uid', how='left')

        t1 = ans_feature.groupby('qid')[col].agg(['sum', 'max', 'mean']).reset_index()
        t1.columns = ['qid', f'q_{col}_sum', f'q_{col}_max', f'q_{col}_mean']
        target = pd.merge(target, t1, on='qid', how='left')
        logging.info("extract %s", col)
    return target

# %%
train_label = extract_feature1(train_label, train_label_feature, train_ans_feature)
test = extract_feature1(test, val_label_feature, val_ans_feature)
# Out:
# [2019-11-25 07:11:40,500] INFO in <ipython-input-14-0fafb00ac390>: extract is_good
# [2019-11-25 07:12:04,879] INFO in <ipython-input-14-0fafb00ac390>: extract is_rec
# [2019-11-25 07:12:33,370] INFO in <ipython-input-14-0fafb00ac390>: extract is_dest
# [2019-11-25 07:13:01,602] INFO in <ipython-input-14-0fafb00ac390>: extract has_img
# [2019-11-25 07:13:30,159] INFO in <ipython-input-14-0fafb00ac390>: extract has_video
# [2019-11-25 07:13:56,802] INFO in <ipython-input-14-0fafb00ac390>: extract word_count
# [2019-11-25 07:14:23,174] INFO in <ipython-input-14-0fafb00ac390>: extract reci_cheer
# [2019-11-25 07:14:49,895] INFO in <ipython-input-14-0fafb00ac390>: extract reci_uncheer
# [2019-11-25 07:15:16,324] INFO in <ipython-input-14-0fafb00ac390>: extract reci_comment
# [2019-11-25 07:15:43,431] INFO in <ipython-input-14-0fafb00ac390>: extract reci_mark
# [2019-11-25 07:16:10,044] INFO in <ipython-input-14-0fafb00ac390>: extract reci_tks
# [2019-11-25 07:16:34,616] INFO in <ipython-input-14-0fafb00ac390>: extract reci_xxx
# [2019-11-25 07:16:49,514] INFO in <ipython-input-14-0fafb00ac390>: extract reci_no_help
# [2019-11-25 07:17:03,551] INFO in <ipython-input-14-0fafb00ac390>: extract reci_dis
# [2019-11-25 07:17:17,774] INFO in <ipython-input-14-0fafb00ac390>: extract diff_qa_days
# [2019-11-25 07:17:53,983] INFO in <ipython-input-14-0fafb00ac390>: extract is_good
# [2019-11-25 07:18:05,899] INFO in <ipython-input-14-0fafb00ac390>: extract is_rec
# [2019-11-25 07:18:17,222] INFO in <ipython-input-14-0fafb00ac390>: extract is_dest
# [2019-11-25 07:18:29,548] INFO in <ipython-input-14-0fafb00ac390>: extract has_img
# [2019-11-25 07:18:52,699] INFO in <ipython-input-14-0fafb00ac390>: extract has_video
# [2019-11-25 07:19:15,913] INFO in <ipython-input-14-0fafb00ac390>: extract word_count
# [2019-11-25 07:19:39,541] INFO in <ipython-input-14-0fafb00ac390>: extract reci_cheer
# [2019-11-25 07:20:03,518] INFO in <ipython-input-14-0fafb00ac390>: extract reci_uncheer
# [2019-11-25 07:20:27,456] INFO in <ipython-input-14-0fafb00ac390>: extract reci_comment
# [2019-11-25 07:20:51,130] INFO in <ipython-input-14-0fafb00ac390>: extract reci_mark
# [2019-11-25 07:21:15,295] INFO in <ipython-input-14-0fafb00ac390>: extract reci_tks
# [2019-11-25 07:21:39,067] INFO in <ipython-input-14-0fafb00ac390>: extract reci_xxx
# [2019-11-25 07:22:02,659] INFO in <ipython-input-14-0fafb00ac390>: extract reci_no_help
# [2019-11-25 07:22:26,806] INFO in <ipython-input-14-0fafb00ac390>: extract reci_dis
# [2019-11-25 07:22:51,026] INFO in <ipython-input-14-0fafb00ac390>: extract diff_qa_days

# %%
# 特征提取结束
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)
assert len(test) == sub_size
# Out:
# [2019-11-25 07:22:51,139] INFO in <ipython-input-16-464c91a59cf8>: train shape (2593669, 105), test shape (1141683, 104)

# %%
# 加载用户
user = pd.read_csv(f'{base_path}/member_info_0926.txt', header=None, sep='\t')
user.columns = ['uid', 'gender', 'freq', 'uf_b1', 'uf_b2',
                'uf_b3', 'uf_b4', 'uf_b5', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5', 'score', 'follow_topic',
                'inter_topic']

del user['follow_topic'], user['inter_topic']
logging.info("user %s", user.shape)

unq = user.nunique()
logging.info("user unq %s", unq)

for x in unq[unq == 1].index:
    del user[x]
    logging.info('del unq==1 %s', x)

t = user.dtypes
cats = [x for x in t[t == 'object'].index if x not in ['follow_topic', 'inter_topic', 'uid']]
logging.info("user cat %s", cats)

for d in cats:
    lb = LabelEncoder()
    user[d] = lb.fit_transform(user[d])
    logging.info('encode %s', d)

q_lb = LabelEncoder()
q_lb.fit(list(train_label['qid'].astype(str).values) + list(test['qid'].astype(str).values))
train_label['qid_enc'] = q_lb.transform(train_label['qid'])
test['qid_enc'] = q_lb.transform(test['qid'])

u_lb = LabelEncoder()
u_lb.fit(user['uid'])
train_label['uid_enc'] = u_lb.transform(train_label['uid'])
test['uid_enc'] = u_lb.transform(test['uid'])
# Out:
# [2019-11-25 07:27:01,172] INFO in <ipython-input-18-7cebf38ed8f9>: user (1931654, 14)
# [2019-11-25 07:27:08,012] INFO in <ipython-input-18-7cebf38ed8f9>: user unq uid       1931654
# gender          3
# freq            5
# uf_b1           2
# uf_b2           2
# uf_b3           2
# uf_b4           2
# uf_b5           2
# uf_c1        2561
# uf_c2         291
# uf_c3         428
# uf_c4        1556
# uf_c5           2
# score         732
# dtype: int64
# [2019-11-25 07:27:08,020] INFO in <ipython-input-18-7cebf38ed8f9>: user cat ['gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
# [2019-11-25 07:27:09,867] INFO in <ipython-input-18-7cebf38ed8f9>: encode gender
# [2019-11-25 07:27:11,683] INFO in <ipython-input-18-7cebf38ed8f9>: encode freq
# [2019-11-25 07:27:13,432] INFO in <ipython-input-18-7cebf38ed8f9>: encode uf_c1
# [2019-11-25 07:27:15,086] INFO in <ipython-input-18-7cebf38ed8f9>: encode uf_c2
# [2019-11-25 07:27:16,652] INFO in <ipython-input-18-7cebf38ed8f9>: encode uf_c3
# [2019-11-25 07:27:18,258] INFO in <ipython-input-18-7cebf38ed8f9>: encode uf_c4
# [2019-11-25 07:27:19,834] INFO in <ipython-input-18-7cebf38ed8f9>: encode uf_c5

# %%
# merge user
train_label = pd.merge(train_label, user, on='uid', how='left')
test = pd.merge(test, user, on='uid', how='left')
logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

data = pd.concat((train_label, test), axis=0, sort=True)
del train_label, test
# Out:
# [2019-11-25 07:28:03,321] INFO in <ipython-input-19-5d1ad498aeb5>: train shape (2593669, 120), test shape (1141683, 119)

# %%
# count编码
count_fea = ['uid_enc', 'qid_enc', 'gender', 'freq', 'uf_c1', 'uf_c2', 'uf_c3', 'uf_c4', 'uf_c5']
for feat in count_fea:
    col_name = '{}_count'.format(feat)
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data.loc[data[col_name] < 2, feat] = -1
    data[feat] += 1
    data[col_name] = data[feat].map(data[feat].value_counts().astype(int))
    data[col_name] = (data[col_name] - data[col_name].min()) / (data[col_name].max() - data[col_name].min())

# %%
# 压缩数据
t = data.dtypes
for x in t[t == 'int64'].index:
    data[x] = data[x].astype('int32')

for x in t[t == 'float64'].index:
    data[x] = data[x].astype('float32')

data['wk'] = data['day'] % 7

feature_cols = [x for x in data.columns if x not in ('label', 'uid', 'qid', 'dt', 'day')]

# %%
train_label = train[(train['day'] > train_label_feature_end)]

# %%
# target编码
logging.info("feature size %s", len(feature_cols))

X_train_all = data.iloc[:len(train_label)][feature_cols]
y_train_all = data.iloc[:len(train_label)]['label']
test = data.iloc[len(train_label):]
del data
assert len(test) == sub_size

logging.info("train shape %s, test shape %s", train_label.shape, test.shape)

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for index, (train_idx, val_idx) in enumerate(fold.split(X=X_train_all, y=y_train_all)):
    break

X_train, X_val, y_train, y_val = X_train_all.iloc[train_idx][feature_cols], X_train_all.iloc[val_idx][feature_cols], \
                                 y_train_all.iloc[train_idx], \
                                 y_train_all.iloc[val_idx]
del X_train_all

model_lgb = LGBMClassifier(n_estimators=2000, n_jobs=-1, objective='binary', seed=1000, silent=True)
model_lgb.fit(X_train, y_train,
              eval_metric=['logloss', 'auc'],
              eval_set=[(X_val, y_val)],
              early_stopping_rounds=50)

sub['label'] = model_lgb.predict_proba(test[feature_cols])[:, 1]
# Out:
# [2019-11-25 07:35:38,630] INFO in <ipython-input-25-20048b165b8f>: feature size 126
# [2019-11-25 07:35:39,301] INFO in <ipython-input-25-20048b165b8f>: train shape (2593669, 5), test shape (1141683, 130)
# [1]	valid_0's auc: 0.7582	valid_0's binary_logloss: 0.426574
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.775326	valid_0's binary_logloss: 0.416562
# [3]	valid_0's auc: 0.78073	valid_0's binary_logloss: 0.408496
# [4]	valid_0's auc: 0.784492	valid_0's binary_logloss: 0.401698
# [5]	valid_0's auc: 0.785532	valid_0's binary_logloss: 0.39619
# [6]	valid_0's auc: 0.787347	valid_0's binary_logloss: 0.391481
# [7]	valid_0's auc: 0.78993	valid_0's binary_logloss: 0.387075
# [8]	valid_0's auc: 0.79221	valid_0's binary_logloss: 0.383291
# [9]	valid_0's auc: 0.793956	valid_0's binary_logloss: 0.379851
# [10]	valid_0's auc: 0.795762	valid_0's binary_logloss: 0.377004
# [11]	valid_0's auc: 0.797256	valid_0's binary_logloss: 0.374117
# [12]	valid_0's auc: 0.798762	valid_0's binary_logloss: 0.371673
# [13]	valid_0's auc: 0.799829	valid_0's binary_logloss: 0.369623
# [14]	valid_0's auc: 0.800952	valid_0's binary_logloss: 0.367658
# [15]	valid_0's auc: 0.802123	valid_0's binary_logloss: 0.365946
# [16]	valid_0's auc: 0.803743	valid_0's binary_logloss: 0.364028
# [17]	valid_0's auc: 0.804985	valid_0's binary_logloss: 0.362522
# [18]	valid_0's auc: 0.806391	valid_0's binary_logloss: 0.361041
# [19]	valid_0's auc: 0.807331	valid_0's binary_logloss: 0.359788
# [20]	valid_0's auc: 0.808306	valid_0's binary_logloss: 0.358529
# [21]	valid_0's auc: 0.808999	valid_0's binary_logloss: 0.357525
# [22]	valid_0's auc: 0.809724	valid_0's binary_logloss: 0.356485
# [23]	valid_0's auc: 0.810504	valid_0's binary_logloss: 0.355525
# [24]	valid_0's auc: 0.811092	valid_0's binary_logloss: 0.354757
# [25]	valid_0's auc: 0.811775	valid_0's binary_logloss: 0.353823
# [26]	valid_0's auc: 0.812457	valid_0's binary_logloss: 0.353024
# [27]	valid_0's auc: 0.81302	valid_0's binary_logloss: 0.35234
# [28]	valid_0's auc: 0.813481	valid_0's binary_logloss: 0.351738
# [29]	valid_0's auc: 0.813929	valid_0's binary_logloss: 0.351125
# [30]	valid_0's auc: 0.814356	valid_0's binary_logloss: 0.350598
# [31]	valid_0's auc: 0.814834	valid_0's binary_logloss: 0.35004
# [32]	valid_0's auc: 0.815301	valid_0's binary_logloss: 0.349484
# [33]	valid_0's auc: 0.815685	valid_0's binary_logloss: 0.349077
# [34]	valid_0's auc: 0.81604	valid_0's binary_logloss: 0.348617
# [35]	valid_0's auc: 0.816346	valid_0's binary_logloss: 0.348167
# [36]	valid_0's auc: 0.816633	valid_0's binary_logloss: 0.347798
# [37]	valid_0's auc: 0.816986	valid_0's binary_logloss: 0.347422
# [38]	valid_0's auc: 0.817337	valid_0's binary_logloss: 0.347093
# [39]	valid_0's auc: 0.81769	valid_0's binary_logloss: 0.346739
# [40]	valid_0's auc: 0.817918	valid_0's binary_logloss: 0.346462
# [41]	valid_0's auc: 0.818239	valid_0's binary_logloss: 0.346084
# [42]	valid_0's auc: 0.818521	valid_0's binary_logloss: 0.345781
# [43]	valid_0's auc: 0.818806	valid_0's binary_logloss: 0.345454
# [44]	valid_0's auc: 0.819025	valid_0's binary_logloss: 0.345235
# [45]	valid_0's auc: 0.819229	valid_0's binary_logloss: 0.345026
# [46]	valid_0's auc: 0.81944	valid_0's binary_logloss: 0.344814
# [47]	valid_0's auc: 0.819656	valid_0's binary_logloss: 0.344575
# [48]	valid_0's auc: 0.819932	valid_0's binary_logloss: 0.344314
# [49]	valid_0's auc: 0.820113	valid_0's binary_logloss: 0.344112
# [50]	valid_0's auc: 0.82042	valid_0's binary_logloss: 0.343778
# [51]	valid_0's auc: 0.820573	valid_0's binary_logloss: 0.343605
# [52]	valid_0's auc: 0.82075	valid_0's binary_logloss: 0.343431
# [53]	valid_0's auc: 0.820911	valid_0's binary_logloss: 0.343258
# [54]	valid_0's auc: 0.821099	valid_0's binary_logloss: 0.343019
# [55]	valid_0's auc: 0.821273	valid_0's binary_logloss: 0.342836
# [56]	valid_0's auc: 0.82141	valid_0's binary_logloss: 0.342678
# [57]	valid_0's auc: 0.82157	valid_0's binary_logloss: 0.342535
# [58]	valid_0's auc: 0.821804	valid_0's binary_logloss: 0.342279
# [59]	valid_0's auc: 0.821918	valid_0's binary_logloss: 0.342159
# [60]	valid_0's auc: 0.822022	valid_0's binary_logloss: 0.34203
# [61]	valid_0's auc: 0.82213	valid_0's binary_logloss: 0.341912
# [62]	valid_0's auc: 0.822286	valid_0's binary_logloss: 0.341771
# [63]	valid_0's auc: 0.822567	valid_0's binary_logloss: 0.341495
# [64]	valid_0's auc: 0.822744	valid_0's binary_logloss: 0.341339
# [65]	valid_0's auc: 0.822972	valid_0's binary_logloss: 0.341105
# [66]	valid_0's auc: 0.823114	valid_0's binary_logloss: 0.340979
# [67]	valid_0's auc: 0.823251	valid_0's binary_logloss: 0.340855
# [68]	valid_0's auc: 0.823394	valid_0's binary_logloss: 0.340734
# [69]	valid_0's auc: 0.823574	valid_0's binary_logloss: 0.340571
# [70]	valid_0's auc: 0.823689	valid_0's binary_logloss: 0.340477
# [71]	valid_0's auc: 0.823868	valid_0's binary_logloss: 0.340307
# [72]	valid_0's auc: 0.823981	valid_0's binary_logloss: 0.340185
# [73]	valid_0's auc: 0.824143	valid_0's binary_logloss: 0.340038
# [74]	valid_0's auc: 0.824253	valid_0's binary_logloss: 0.339952
# [75]	valid_0's auc: 0.82436	valid_0's binary_logloss: 0.339864
# [76]	valid_0's auc: 0.824464	valid_0's binary_logloss: 0.339786
# [77]	valid_0's auc: 0.824587	valid_0's binary_logloss: 0.339684
# [78]	valid_0's auc: 0.824701	valid_0's binary_logloss: 0.339593
# [79]	valid_0's auc: 0.824835	valid_0's binary_logloss: 0.339484
# [80]	valid_0's auc: 0.824917	valid_0's binary_logloss: 0.33941
# [81]	valid_0's auc: 0.825011	valid_0's binary_logloss: 0.339326
# [82]	valid_0's auc: 0.825175	valid_0's binary_logloss: 0.339177
# [83]	valid_0's auc: 0.825295	valid_0's binary_logloss: 0.339083
# [84]	valid_0's auc: 0.825397	valid_0's binary_logloss: 0.338997
# [85]	valid_0's auc: 0.825488	valid_0's binary_logloss: 0.338928
# [86]	valid_0's auc: 0.82556	valid_0's binary_logloss: 0.338865
# [87]	valid_0's auc: 0.825657	valid_0's binary_logloss: 0.338782
# [88]	valid_0's auc: 0.825748	valid_0's binary_logloss: 0.338712
# [89]	valid_0's auc: 0.82585	valid_0's binary_logloss: 0.338624
# [90]	valid_0's auc: 0.825909	valid_0's binary_logloss: 0.33857
# [91]	valid_0's auc: 0.825975	valid_0's binary_logloss: 0.338516
# [92]	valid_0's auc: 0.826115	valid_0's binary_logloss: 0.338409
# [93]	valid_0's auc: 0.826186	valid_0's binary_logloss: 0.33835
# [94]	valid_0's auc: 0.826275	valid_0's binary_logloss: 0.338269
# [95]	valid_0's auc: 0.82638	valid_0's binary_logloss: 0.338177
# [96]	valid_0's auc: 0.82644	valid_0's binary_logloss: 0.338123
# [97]	valid_0's auc: 0.826502	valid_0's binary_logloss: 0.338078
# [98]	valid_0's auc: 0.826618	valid_0's binary_logloss: 0.337976
# [99]	valid_0's auc: 0.826681	valid_0's binary_logloss: 0.337925
# [100]	valid_0's auc: 0.82674	valid_0's binary_logloss: 0.337872
# [101]	valid_0's auc: 0.826813	valid_0's binary_logloss: 0.337805
# [102]	valid_0's auc: 0.826917	valid_0's binary_logloss: 0.337708
# [103]	valid_0's auc: 0.826962	valid_0's binary_logloss: 0.337671
# [104]	valid_0's auc: 0.827049	valid_0's binary_logloss: 0.337588
# [105]	valid_0's auc: 0.827124	valid_0's binary_logloss: 0.337528
# [106]	valid_0's auc: 0.827184	valid_0's binary_logloss: 0.337478
# [107]	valid_0's auc: 0.827245	valid_0's binary_logloss: 0.33743
# [108]	valid_0's auc: 0.827326	valid_0's binary_logloss: 0.337365
# [109]	valid_0's auc: 0.827432	valid_0's binary_logloss: 0.337276
# [110]	valid_0's auc: 0.827497	valid_0's binary_logloss: 0.337225
# [111]	valid_0's auc: 0.827581	valid_0's binary_logloss: 0.337154
# [112]	valid_0's auc: 0.82763	valid_0's binary_logloss: 0.337111
# [113]	valid_0's auc: 0.827689	valid_0's binary_logloss: 0.337058
# [114]	valid_0's auc: 0.827779	valid_0's binary_logloss: 0.336984
# [115]	valid_0's auc: 0.827813	valid_0's binary_logloss: 0.336954
# [116]	valid_0's auc: 0.827886	valid_0's binary_logloss: 0.336896
# [117]	valid_0's auc: 0.827926	valid_0's binary_logloss: 0.336862
# [118]	valid_0's auc: 0.827973	valid_0's binary_logloss: 0.336826
# [119]	valid_0's auc: 0.828049	valid_0's binary_logloss: 0.336765
# [120]	valid_0's auc: 0.828093	valid_0's binary_logloss: 0.336722
# [121]	valid_0's auc: 0.828141	valid_0's binary_logloss: 0.33668
# [122]	valid_0's auc: 0.828219	valid_0's binary_logloss: 0.336619
# [123]	valid_0's auc: 0.828285	valid_0's binary_logloss: 0.336565
# [124]	valid_0's auc: 0.828332	valid_0's binary_logloss: 0.336503
# [125]	valid_0's auc: 0.828388	valid_0's binary_logloss: 0.336453
# [126]	valid_0's auc: 0.828434	valid_0's binary_logloss: 0.336414
# [127]	valid_0's auc: 0.828469	valid_0's binary_logloss: 0.336383
# [128]	valid_0's auc: 0.828495	valid_0's binary_logloss: 0.336362
# [129]	valid_0's auc: 0.828533	valid_0's binary_logloss: 0.336331
# [130]	valid_0's auc: 0.828574	valid_0's binary_logloss: 0.336286
# [131]	valid_0's auc: 0.828627	valid_0's binary_logloss: 0.336235
# [132]	valid_0's auc: 0.828685	valid_0's binary_logloss: 0.336175
# [133]	valid_0's auc: 0.828767	valid_0's binary_logloss: 0.336114
# [134]	valid_0's auc: 0.828835	valid_0's binary_logloss: 0.336061
# [135]	valid_0's auc: 0.828889	valid_0's binary_logloss: 0.336019
# [136]	valid_0's auc: 0.828917	valid_0's binary_logloss: 0.33599
# [137]	valid_0's auc: 0.828973	valid_0's binary_logloss: 0.335952
# [138]	valid_0's auc: 0.829	valid_0's binary_logloss: 0.33593
# [139]	valid_0's auc: 0.82906	valid_0's binary_logloss: 0.335884
# [140]	valid_0's auc: 0.829072	valid_0's binary_logloss: 0.335872
# [141]	valid_0's auc: 0.829121	valid_0's binary_logloss: 0.33582
# [142]	valid_0's auc: 0.829164	valid_0's binary_logloss: 0.335785
# [143]	valid_0's auc: 0.829192	valid_0's binary_logloss: 0.335764
# [144]	valid_0's auc: 0.829242	valid_0's binary_logloss: 0.335722
# [145]	valid_0's auc: 0.829306	valid_0's binary_logloss: 0.335672
# [146]	valid_0's auc: 0.829375	valid_0's binary_logloss: 0.335617
# [147]	valid_0's auc: 0.82942	valid_0's binary_logloss: 0.335588
# [148]	valid_0's auc: 0.829482	valid_0's binary_logloss: 0.335526
# [149]	valid_0's auc: 0.829495	valid_0's binary_logloss: 0.335511
# [150]	valid_0's auc: 0.829516	valid_0's binary_logloss: 0.335495
# [151]	valid_0's auc: 0.829524	valid_0's binary_logloss: 0.335488
# [152]	valid_0's auc: 0.829562	valid_0's binary_logloss: 0.335463
# [153]	valid_0's auc: 0.829577	valid_0's binary_logloss: 0.335453
# [154]	valid_0's auc: 0.829589	valid_0's binary_logloss: 0.335445
# [155]	valid_0's auc: 0.829594	valid_0's binary_logloss: 0.335441
# [156]	valid_0's auc: 0.829611	valid_0's binary_logloss: 0.335426
# [157]	valid_0's auc: 0.829652	valid_0's binary_logloss: 0.335388
# [158]	valid_0's auc: 0.829684	valid_0's binary_logloss: 0.335358
# [159]	valid_0's auc: 0.829708	valid_0's binary_logloss: 0.335335
# [160]	valid_0's auc: 0.829718	valid_0's binary_logloss: 0.335324
# [161]	valid_0's auc: 0.829739	valid_0's binary_logloss: 0.335304
# [162]	valid_0's auc: 0.829776	valid_0's binary_logloss: 0.335268
# [163]	valid_0's auc: 0.829823	valid_0's binary_logloss: 0.335229
# [164]	valid_0's auc: 0.829841	valid_0's binary_logloss: 0.335215
# [165]	valid_0's auc: 0.829898	valid_0's binary_logloss: 0.33517
# [166]	valid_0's auc: 0.82991	valid_0's binary_logloss: 0.33516
# [167]	valid_0's auc: 0.829944	valid_0's binary_logloss: 0.335133
# [168]	valid_0's auc: 0.829972	valid_0's binary_logloss: 0.335111
# [169]	valid_0's auc: 0.830029	valid_0's binary_logloss: 0.335065
# [170]	valid_0's auc: 0.83005	valid_0's binary_logloss: 0.335046
# [171]	valid_0's auc: 0.830059	valid_0's binary_logloss: 0.335039
# [172]	valid_0's auc: 0.830068	valid_0's binary_logloss: 0.335033
# [173]	valid_0's auc: 0.830084	valid_0's binary_logloss: 0.335022
# [174]	valid_0's auc: 0.830104	valid_0's binary_logloss: 0.335003
# [175]	valid_0's auc: 0.830112	valid_0's binary_logloss: 0.334997
# [176]	valid_0's auc: 0.830121	valid_0's binary_logloss: 0.33499
# [177]	valid_0's auc: 0.83013	valid_0's binary_logloss: 0.334977
# [178]	valid_0's auc: 0.830159	valid_0's binary_logloss: 0.334954
# [179]	valid_0's auc: 0.830179	valid_0's binary_logloss: 0.334938
# [180]	valid_0's auc: 0.830221	valid_0's binary_logloss: 0.334899
# [181]	valid_0's auc: 0.830237	valid_0's binary_logloss: 0.334889
# [182]	valid_0's auc: 0.830253	valid_0's binary_logloss: 0.334876
# [183]	valid_0's auc: 0.830257	valid_0's binary_logloss: 0.334872
# [184]	valid_0's auc: 0.830327	valid_0's binary_logloss: 0.334821
# [185]	valid_0's auc: 0.830362	valid_0's binary_logloss: 0.334787
# [186]	valid_0's auc: 0.830368	valid_0's binary_logloss: 0.334782
# [187]	valid_0's auc: 0.830383	valid_0's binary_logloss: 0.33477
# [188]	valid_0's auc: 0.830417	valid_0's binary_logloss: 0.334744
# [189]	valid_0's auc: 0.83047	valid_0's binary_logloss: 0.334701
# [190]	valid_0's auc: 0.830481	valid_0's binary_logloss: 0.334692
# [191]	valid_0's auc: 0.830506	valid_0's binary_logloss: 0.334668
# [192]	valid_0's auc: 0.830534	valid_0's binary_logloss: 0.334642
# [193]	valid_0's auc: 0.830542	valid_0's binary_logloss: 0.334633
# [194]	valid_0's auc: 0.83055	valid_0's binary_logloss: 0.334628
# [195]	valid_0's auc: 0.830557	valid_0's binary_logloss: 0.334622
# [196]	valid_0's auc: 0.83061	valid_0's binary_logloss: 0.334579
# [197]	valid_0's auc: 0.830617	valid_0's binary_logloss: 0.334575
# [198]	valid_0's auc: 0.830637	valid_0's binary_logloss: 0.334559
# [199]	valid_0's auc: 0.830671	valid_0's binary_logloss: 0.334522
# [200]	valid_0's auc: 0.83068	valid_0's binary_logloss: 0.334514
# [201]	valid_0's auc: 0.830686	valid_0's binary_logloss: 0.33451
# [202]	valid_0's auc: 0.830685	valid_0's binary_logloss: 0.33451
# [203]	valid_0's auc: 0.830686	valid_0's binary_logloss: 0.334509
# [204]	valid_0's auc: 0.83069	valid_0's binary_logloss: 0.334502
# [205]	valid_0's auc: 0.830712	valid_0's binary_logloss: 0.334485
# [206]	valid_0's auc: 0.830725	valid_0's binary_logloss: 0.334473
# [207]	valid_0's auc: 0.830747	valid_0's binary_logloss: 0.334454
# [208]	valid_0's auc: 0.83077	valid_0's binary_logloss: 0.334436
# [209]	valid_0's auc: 0.830766	valid_0's binary_logloss: 0.334439
# [210]	valid_0's auc: 0.830771	valid_0's binary_logloss: 0.334432
# [211]	valid_0's auc: 0.830812	valid_0's binary_logloss: 0.3344
# [212]	valid_0's auc: 0.830828	valid_0's binary_logloss: 0.334387
# [213]	valid_0's auc: 0.830872	valid_0's binary_logloss: 0.334348
# [214]	valid_0's auc: 0.830874	valid_0's binary_logloss: 0.334343
# [215]	valid_0's auc: 0.830879	valid_0's binary_logloss: 0.334339
# [216]	valid_0's auc: 0.830903	valid_0's binary_logloss: 0.33432
# [217]	valid_0's auc: 0.830905	valid_0's binary_logloss: 0.334319
# [218]	valid_0's auc: 0.830923	valid_0's binary_logloss: 0.334307
# [219]	valid_0's auc: 0.830924	valid_0's binary_logloss: 0.334306
# [220]	valid_0's auc: 0.830936	valid_0's binary_logloss: 0.334294
# [221]	valid_0's auc: 0.830974	valid_0's binary_logloss: 0.334266
# [222]	valid_0's auc: 0.831018	valid_0's binary_logloss: 0.334231
# [223]	valid_0's auc: 0.831039	valid_0's binary_logloss: 0.334213
# [224]	valid_0's auc: 0.831054	valid_0's binary_logloss: 0.334202
# [225]	valid_0's auc: 0.831064	valid_0's binary_logloss: 0.334195
# [226]	valid_0's auc: 0.831076	valid_0's binary_logloss: 0.334186
# [227]	valid_0's auc: 0.831085	valid_0's binary_logloss: 0.334177
# [228]	valid_0's auc: 0.831106	valid_0's binary_logloss: 0.334155
# [229]	valid_0's auc: 0.831111	valid_0's binary_logloss: 0.334151
# [230]	valid_0's auc: 0.831118	valid_0's binary_logloss: 0.334141
# [231]	valid_0's auc: 0.831127	valid_0's binary_logloss: 0.334135
# [232]	valid_0's auc: 0.8312	valid_0's binary_logloss: 0.33408
# [233]	valid_0's auc: 0.831216	valid_0's binary_logloss: 0.33407
# [234]	valid_0's auc: 0.831257	valid_0's binary_logloss: 0.334035
# [235]	valid_0's auc: 0.831282	valid_0's binary_logloss: 0.334017
# [236]	valid_0's auc: 0.8313	valid_0's binary_logloss: 0.333999
# [237]	valid_0's auc: 0.831301	valid_0's binary_logloss: 0.333999
# [238]	valid_0's auc: 0.831313	valid_0's binary_logloss: 0.333987
# [239]	valid_0's auc: 0.831316	valid_0's binary_logloss: 0.333985
# [240]	valid_0's auc: 0.831325	valid_0's binary_logloss: 0.333977
# [241]	valid_0's auc: 0.831329	valid_0's binary_logloss: 0.333974
# [242]	valid_0's auc: 0.831338	valid_0's binary_logloss: 0.333966
# [243]	valid_0's auc: 0.831337	valid_0's binary_logloss: 0.333966
# [244]	valid_0's auc: 0.831379	valid_0's binary_logloss: 0.333929
# [245]	valid_0's auc: 0.831381	valid_0's binary_logloss: 0.333927
# [246]	valid_0's auc: 0.831397	valid_0's binary_logloss: 0.333917
# [247]	valid_0's auc: 0.831419	valid_0's binary_logloss: 0.333897
# [248]	valid_0's auc: 0.831422	valid_0's binary_logloss: 0.333895
# [249]	valid_0's auc: 0.831424	valid_0's binary_logloss: 0.333894
# [250]	valid_0's auc: 0.83143	valid_0's binary_logloss: 0.333888
# [251]	valid_0's auc: 0.831426	valid_0's binary_logloss: 0.33389
# [252]	valid_0's auc: 0.831437	valid_0's binary_logloss: 0.33388
# [253]	valid_0's auc: 0.831453	valid_0's binary_logloss: 0.333868
# [254]	valid_0's auc: 0.83146	valid_0's binary_logloss: 0.33386
# [255]	valid_0's auc: 0.831466	valid_0's binary_logloss: 0.333854
# [256]	valid_0's auc: 0.831475	valid_0's binary_logloss: 0.333847
# [257]	valid_0's auc: 0.831489	valid_0's binary_logloss: 0.333837
# [258]	valid_0's auc: 0.831492	valid_0's binary_logloss: 0.333834
# [259]	valid_0's auc: 0.831496	valid_0's binary_logloss: 0.333831
# [260]	valid_0's auc: 0.831503	valid_0's binary_logloss: 0.333828
# [261]	valid_0's auc: 0.831511	valid_0's binary_logloss: 0.333818
# [262]	valid_0's auc: 0.831533	valid_0's binary_logloss: 0.333797
# [263]	valid_0's auc: 0.831539	valid_0's binary_logloss: 0.333792
# [264]	valid_0's auc: 0.831556	valid_0's binary_logloss: 0.333777
# [265]	valid_0's auc: 0.831593	valid_0's binary_logloss: 0.333752
# [266]	valid_0's auc: 0.831635	valid_0's binary_logloss: 0.333723
# [267]	valid_0's auc: 0.83165	valid_0's binary_logloss: 0.33371
# [268]	valid_0's auc: 0.831656	valid_0's binary_logloss: 0.333706
# [269]	valid_0's auc: 0.83167	valid_0's binary_logloss: 0.333695
# [270]	valid_0's auc: 0.831672	valid_0's binary_logloss: 0.333695
# [271]	valid_0's auc: 0.831689	valid_0's binary_logloss: 0.333682
# [272]	valid_0's auc: 0.831724	valid_0's binary_logloss: 0.33365
# [273]	valid_0's auc: 0.831735	valid_0's binary_logloss: 0.333642
# [274]	valid_0's auc: 0.831752	valid_0's binary_logloss: 0.333631
# [275]	valid_0's auc: 0.83176	valid_0's binary_logloss: 0.333626
# [276]	valid_0's auc: 0.831766	valid_0's binary_logloss: 0.333621
# [277]	valid_0's auc: 0.831787	valid_0's binary_logloss: 0.333605
# [278]	valid_0's auc: 0.83179	valid_0's binary_logloss: 0.333603
# [279]	valid_0's auc: 0.831799	valid_0's binary_logloss: 0.333597
# [280]	valid_0's auc: 0.831827	valid_0's binary_logloss: 0.333573
# [281]	valid_0's auc: 0.831829	valid_0's binary_logloss: 0.333572
# [282]	valid_0's auc: 0.831827	valid_0's binary_logloss: 0.333573
# [283]	valid_0's auc: 0.831848	valid_0's binary_logloss: 0.333553
# [284]	valid_0's auc: 0.831849	valid_0's binary_logloss: 0.333552
# [285]	valid_0's auc: 0.831855	valid_0's binary_logloss: 0.333548
# [286]	valid_0's auc: 0.831862	valid_0's binary_logloss: 0.333541
# [287]	valid_0's auc: 0.831874	valid_0's binary_logloss: 0.333532
# [288]	valid_0's auc: 0.831883	valid_0's binary_logloss: 0.333523
# [289]	valid_0's auc: 0.831889	valid_0's binary_logloss: 0.333518
# [290]	valid_0's auc: 0.831891	valid_0's binary_logloss: 0.333515
# [291]	valid_0's auc: 0.831899	valid_0's binary_logloss: 0.333508
# [292]	valid_0's auc: 0.831912	valid_0's binary_logloss: 0.333499
# [293]	valid_0's auc: 0.831913	valid_0's binary_logloss: 0.333497
# [294]	valid_0's auc: 0.831918	valid_0's binary_logloss: 0.333494
# [295]	valid_0's auc: 0.831921	valid_0's binary_logloss: 0.333492
# [296]	valid_0's auc: 0.83193	valid_0's binary_logloss: 0.333483
# [297]	valid_0's auc: 0.831933	valid_0's binary_logloss: 0.333478
# [298]	valid_0's auc: 0.831943	valid_0's binary_logloss: 0.333468
# [299]	valid_0's auc: 0.831946	valid_0's binary_logloss: 0.333466
# [300]	valid_0's auc: 0.83195	valid_0's binary_logloss: 0.333463
# [301]	valid_0's auc: 0.831949	valid_0's binary_logloss: 0.333464
# [302]	valid_0's auc: 0.831952	valid_0's binary_logloss: 0.333461
# [303]	valid_0's auc: 0.831964	valid_0's binary_logloss: 0.33345
# [304]	valid_0's auc: 0.831969	valid_0's binary_logloss: 0.333446
# [305]	valid_0's auc: 0.831974	valid_0's binary_logloss: 0.333441
# [306]	valid_0's auc: 0.831982	valid_0's binary_logloss: 0.333435
# [307]	valid_0's auc: 0.831982	valid_0's binary_logloss: 0.333434
# [308]	valid_0's auc: 0.831984	valid_0's binary_logloss: 0.333433
# [309]	valid_0's auc: 0.831988	valid_0's binary_logloss: 0.333431
# [310]	valid_0's auc: 0.832	valid_0's binary_logloss: 0.333422
# [311]	valid_0's auc: 0.832007	valid_0's binary_logloss: 0.333418
# [312]	valid_0's auc: 0.832012	valid_0's binary_logloss: 0.333412
# [313]	valid_0's auc: 0.83205	valid_0's binary_logloss: 0.333381
# [314]	valid_0's auc: 0.832099	valid_0's binary_logloss: 0.333342
# [315]	valid_0's auc: 0.832111	valid_0's binary_logloss: 0.333334
# [316]	valid_0's auc: 0.832123	valid_0's binary_logloss: 0.333319
# [317]	valid_0's auc: 0.832134	valid_0's binary_logloss: 0.33331
# [318]	valid_0's auc: 0.83216	valid_0's binary_logloss: 0.333288
# [319]	valid_0's auc: 0.83217	valid_0's binary_logloss: 0.33328
# [320]	valid_0's auc: 0.832196	valid_0's binary_logloss: 0.33326
# [321]	valid_0's auc: 0.832208	valid_0's binary_logloss: 0.333251
# [322]	valid_0's auc: 0.832214	valid_0's binary_logloss: 0.333247
# [323]	valid_0's auc: 0.832217	valid_0's binary_logloss: 0.333246
# [324]	valid_0's auc: 0.832217	valid_0's binary_logloss: 0.333245
# [325]	valid_0's auc: 0.832217	valid_0's binary_logloss: 0.333245
# [326]	valid_0's auc: 0.832221	valid_0's binary_logloss: 0.333241
# [327]	valid_0's auc: 0.832224	valid_0's binary_logloss: 0.333239
# [328]	valid_0's auc: 0.832252	valid_0's binary_logloss: 0.333213
# [329]	valid_0's auc: 0.832261	valid_0's binary_logloss: 0.333201
# [330]	valid_0's auc: 0.832265	valid_0's binary_logloss: 0.333194
# [331]	valid_0's auc: 0.832265	valid_0's binary_logloss: 0.333195
# [332]	valid_0's auc: 0.832262	valid_0's binary_logloss: 0.333195
# [333]	valid_0's auc: 0.832268	valid_0's binary_logloss: 0.333192
# [334]	valid_0's auc: 0.832297	valid_0's binary_logloss: 0.333171
# [335]	valid_0's auc: 0.832301	valid_0's binary_logloss: 0.333166
# [336]	valid_0's auc: 0.832323	valid_0's binary_logloss: 0.33315
# [337]	valid_0's auc: 0.832328	valid_0's binary_logloss: 0.333145
# [338]	valid_0's auc: 0.832367	valid_0's binary_logloss: 0.333113
# [339]	valid_0's auc: 0.832396	valid_0's binary_logloss: 0.333077
# [340]	valid_0's auc: 0.832404	valid_0's binary_logloss: 0.333065
# [341]	valid_0's auc: 0.83242	valid_0's binary_logloss: 0.333053
# [342]	valid_0's auc: 0.83242	valid_0's binary_logloss: 0.33305
# [343]	valid_0's auc: 0.832428	valid_0's binary_logloss: 0.333041
# [344]	valid_0's auc: 0.832467	valid_0's binary_logloss: 0.333009
# [345]	valid_0's auc: 0.832482	valid_0's binary_logloss: 0.332994
# [346]	valid_0's auc: 0.832489	valid_0's binary_logloss: 0.332986
# [347]	valid_0's auc: 0.832499	valid_0's binary_logloss: 0.332979
# [348]	valid_0's auc: 0.832503	valid_0's binary_logloss: 0.332974
# [349]	valid_0's auc: 0.832509	valid_0's binary_logloss: 0.33297
# [350]	valid_0's auc: 0.832526	valid_0's binary_logloss: 0.332957
# [351]	valid_0's auc: 0.832554	valid_0's binary_logloss: 0.332931
# [352]	valid_0's auc: 0.832566	valid_0's binary_logloss: 0.33292
# [353]	valid_0's auc: 0.832595	valid_0's binary_logloss: 0.332895
# [354]	valid_0's auc: 0.832603	valid_0's binary_logloss: 0.332887
# [355]	valid_0's auc: 0.832607	valid_0's binary_logloss: 0.332884
# [356]	valid_0's auc: 0.83262	valid_0's binary_logloss: 0.332876
# [357]	valid_0's auc: 0.832618	valid_0's binary_logloss: 0.332875
# [358]	valid_0's auc: 0.832621	valid_0's binary_logloss: 0.332873
# [359]	valid_0's auc: 0.832636	valid_0's binary_logloss: 0.332863
# [360]	valid_0's auc: 0.83266	valid_0's binary_logloss: 0.332845
# [361]	valid_0's auc: 0.832667	valid_0's binary_logloss: 0.332839
# [362]	valid_0's auc: 0.832684	valid_0's binary_logloss: 0.332827
# [363]	valid_0's auc: 0.832708	valid_0's binary_logloss: 0.332805
# [364]	valid_0's auc: 0.832706	valid_0's binary_logloss: 0.332806
# [365]	valid_0's auc: 0.832708	valid_0's binary_logloss: 0.332804
# [366]	valid_0's auc: 0.832709	valid_0's binary_logloss: 0.332803
# [367]	valid_0's auc: 0.832713	valid_0's binary_logloss: 0.332801
# [368]	valid_0's auc: 0.832717	valid_0's binary_logloss: 0.332798
# [369]	valid_0's auc: 0.832714	valid_0's binary_logloss: 0.332799
# [370]	valid_0's auc: 0.832712	valid_0's binary_logloss: 0.332801
# [371]	valid_0's auc: 0.832727	valid_0's binary_logloss: 0.332789
# [372]	valid_0's auc: 0.832759	valid_0's binary_logloss: 0.332762
# [373]	valid_0's auc: 0.832766	valid_0's binary_logloss: 0.332758
# [374]	valid_0's auc: 0.832764	valid_0's binary_logloss: 0.332758
# [375]	valid_0's auc: 0.832771	valid_0's binary_logloss: 0.332751
# [376]	valid_0's auc: 0.832773	valid_0's binary_logloss: 0.332748
# [377]	valid_0's auc: 0.832783	valid_0's binary_logloss: 0.332742
# [378]	valid_0's auc: 0.832793	valid_0's binary_logloss: 0.332732
# [379]	valid_0's auc: 0.832805	valid_0's binary_logloss: 0.33272
# [380]	valid_0's auc: 0.832809	valid_0's binary_logloss: 0.332717
# [381]	valid_0's auc: 0.832815	valid_0's binary_logloss: 0.332714
# [382]	valid_0's auc: 0.832818	valid_0's binary_logloss: 0.332711
# [383]	valid_0's auc: 0.832828	valid_0's binary_logloss: 0.332704
# [384]	valid_0's auc: 0.832846	valid_0's binary_logloss: 0.332689
# [385]	valid_0's auc: 0.832853	valid_0's binary_logloss: 0.332684
# [386]	valid_0's auc: 0.832863	valid_0's binary_logloss: 0.332673
# [387]	valid_0's auc: 0.83286	valid_0's binary_logloss: 0.332675
# [388]	valid_0's auc: 0.832897	valid_0's binary_logloss: 0.33264
# [389]	valid_0's auc: 0.832903	valid_0's binary_logloss: 0.332637
# [390]	valid_0's auc: 0.832908	valid_0's binary_logloss: 0.332631
# [391]	valid_0's auc: 0.832921	valid_0's binary_logloss: 0.332621
# [392]	valid_0's auc: 0.832929	valid_0's binary_logloss: 0.332616
# [393]	valid_0's auc: 0.832937	valid_0's binary_logloss: 0.33261
# [394]	valid_0's auc: 0.832937	valid_0's binary_logloss: 0.332609
# [395]	valid_0's auc: 0.832939	valid_0's binary_logloss: 0.332607
# [396]	valid_0's auc: 0.832959	valid_0's binary_logloss: 0.332592
# [397]	valid_0's auc: 0.832958	valid_0's binary_logloss: 0.332594
# [398]	valid_0's auc: 0.832958	valid_0's binary_logloss: 0.332593
# [399]	valid_0's auc: 0.832982	valid_0's binary_logloss: 0.332575
# [400]	valid_0's auc: 0.833006	valid_0's binary_logloss: 0.33254
# [401]	valid_0's auc: 0.833008	valid_0's binary_logloss: 0.332539
# [402]	valid_0's auc: 0.83301	valid_0's binary_logloss: 0.332538
# [403]	valid_0's auc: 0.833015	valid_0's binary_logloss: 0.332534
# [404]	valid_0's auc: 0.833015	valid_0's binary_logloss: 0.332534
# [405]	valid_0's auc: 0.833019	valid_0's binary_logloss: 0.33253
# [406]	valid_0's auc: 0.833027	valid_0's binary_logloss: 0.332524
# [407]	valid_0's auc: 0.833055	valid_0's binary_logloss: 0.3325
# [408]	valid_0's auc: 0.833065	valid_0's binary_logloss: 0.332493
# [409]	valid_0's auc: 0.833072	valid_0's binary_logloss: 0.332486
# [410]	valid_0's auc: 0.833087	valid_0's binary_logloss: 0.332475
# [411]	valid_0's auc: 0.83309	valid_0's binary_logloss: 0.332473
# [412]	valid_0's auc: 0.833089	valid_0's binary_logloss: 0.332474
# [413]	valid_0's auc: 0.833097	valid_0's binary_logloss: 0.332467
# [414]	valid_0's auc: 0.833101	valid_0's binary_logloss: 0.332463
# [415]	valid_0's auc: 0.833109	valid_0's binary_logloss: 0.332456
# [416]	valid_0's auc: 0.833109	valid_0's binary_logloss: 0.332456
# [417]	valid_0's auc: 0.833111	valid_0's binary_logloss: 0.332455
# [418]	valid_0's auc: 0.833113	valid_0's binary_logloss: 0.332454
# [419]	valid_0's auc: 0.833119	valid_0's binary_logloss: 0.332451
# [420]	valid_0's auc: 0.833121	valid_0's binary_logloss: 0.33245
# [421]	valid_0's auc: 0.833121	valid_0's binary_logloss: 0.332449
# [422]	valid_0's auc: 0.833124	valid_0's binary_logloss: 0.332447
# [423]	valid_0's auc: 0.833129	valid_0's binary_logloss: 0.332444
# [424]	valid_0's auc: 0.833136	valid_0's binary_logloss: 0.332438
# [425]	valid_0's auc: 0.833136	valid_0's binary_logloss: 0.332438
# [426]	valid_0's auc: 0.833137	valid_0's binary_logloss: 0.332437
# [427]	valid_0's auc: 0.83315	valid_0's binary_logloss: 0.332428
# [428]	valid_0's auc: 0.83315	valid_0's binary_logloss: 0.332428
# [429]	valid_0's auc: 0.833148	valid_0's binary_logloss: 0.332429
# [430]	valid_0's auc: 0.833148	valid_0's binary_logloss: 0.33243
# [431]	valid_0's auc: 0.833153	valid_0's binary_logloss: 0.332424
# [432]	valid_0's auc: 0.833159	valid_0's binary_logloss: 0.332419
# [433]	valid_0's auc: 0.833161	valid_0's binary_logloss: 0.332417
# [434]	valid_0's auc: 0.833161	valid_0's binary_logloss: 0.332416
# [435]	valid_0's auc: 0.833168	valid_0's binary_logloss: 0.332411
# [436]	valid_0's auc: 0.833185	valid_0's binary_logloss: 0.3324
# [437]	valid_0's auc: 0.833193	valid_0's binary_logloss: 0.332392
# [438]	valid_0's auc: 0.833209	valid_0's binary_logloss: 0.33238
# [439]	valid_0's auc: 0.833215	valid_0's binary_logloss: 0.332376
# [440]	valid_0's auc: 0.833252	valid_0's binary_logloss: 0.332344
# [441]	valid_0's auc: 0.833274	valid_0's binary_logloss: 0.332325
# [442]	valid_0's auc: 0.833281	valid_0's binary_logloss: 0.332319
# [443]	valid_0's auc: 0.833285	valid_0's binary_logloss: 0.332317
# [444]	valid_0's auc: 0.833303	valid_0's binary_logloss: 0.332303
# [445]	valid_0's auc: 0.833315	valid_0's binary_logloss: 0.332294
# [446]	valid_0's auc: 0.833313	valid_0's binary_logloss: 0.332295
# [447]	valid_0's auc: 0.833315	valid_0's binary_logloss: 0.332294
# [448]	valid_0's auc: 0.833335	valid_0's binary_logloss: 0.332278
# [449]	valid_0's auc: 0.833354	valid_0's binary_logloss: 0.332263
# [450]	valid_0's auc: 0.833379	valid_0's binary_logloss: 0.332243
# [451]	valid_0's auc: 0.833403	valid_0's binary_logloss: 0.332207
# [452]	valid_0's auc: 0.833409	valid_0's binary_logloss: 0.332203
# [453]	valid_0's auc: 0.833462	valid_0's binary_logloss: 0.332159
# [454]	valid_0's auc: 0.833495	valid_0's binary_logloss: 0.332119
# [455]	valid_0's auc: 0.833507	valid_0's binary_logloss: 0.332106
# [456]	valid_0's auc: 0.833502	valid_0's binary_logloss: 0.332107
# [457]	valid_0's auc: 0.833515	valid_0's binary_logloss: 0.332097
# [458]	valid_0's auc: 0.833529	valid_0's binary_logloss: 0.332087
# [459]	valid_0's auc: 0.833543	valid_0's binary_logloss: 0.332074
# [460]	valid_0's auc: 0.833555	valid_0's binary_logloss: 0.332062
# [461]	valid_0's auc: 0.833556	valid_0's binary_logloss: 0.332062
# [462]	valid_0's auc: 0.833567	valid_0's binary_logloss: 0.332055
# [463]	valid_0's auc: 0.833569	valid_0's binary_logloss: 0.332054
# [464]	valid_0's auc: 0.833574	valid_0's binary_logloss: 0.332049
# [465]	valid_0's auc: 0.833602	valid_0's binary_logloss: 0.332031
# [466]	valid_0's auc: 0.833617	valid_0's binary_logloss: 0.33202
# [467]	valid_0's auc: 0.83365	valid_0's binary_logloss: 0.331996
# [468]	valid_0's auc: 0.833647	valid_0's binary_logloss: 0.331997
# [469]	valid_0's auc: 0.83365	valid_0's binary_logloss: 0.331994
# [470]	valid_0's auc: 0.833652	valid_0's binary_logloss: 0.331992
# [471]	valid_0's auc: 0.833653	valid_0's binary_logloss: 0.331991
# [472]	valid_0's auc: 0.83366	valid_0's binary_logloss: 0.331986
# [473]	valid_0's auc: 0.833663	valid_0's binary_logloss: 0.331983
# [474]	valid_0's auc: 0.833673	valid_0's binary_logloss: 0.331976
# [475]	valid_0's auc: 0.83368	valid_0's binary_logloss: 0.331968
# [476]	valid_0's auc: 0.833701	valid_0's binary_logloss: 0.331954
# [477]	valid_0's auc: 0.833725	valid_0's binary_logloss: 0.331931
# [478]	valid_0's auc: 0.833729	valid_0's binary_logloss: 0.331927
# [479]	valid_0's auc: 0.833745	valid_0's binary_logloss: 0.331916
# [480]	valid_0's auc: 0.833764	valid_0's binary_logloss: 0.33189
# [481]	valid_0's auc: 0.83377	valid_0's binary_logloss: 0.331886
# [482]	valid_0's auc: 0.833765	valid_0's binary_logloss: 0.331889
# [483]	valid_0's auc: 0.833765	valid_0's binary_logloss: 0.331889
# [484]	valid_0's auc: 0.833794	valid_0's binary_logloss: 0.331866
# [485]	valid_0's auc: 0.833795	valid_0's binary_logloss: 0.331865
# [486]	valid_0's auc: 0.8338	valid_0's binary_logloss: 0.331863
# [487]	valid_0's auc: 0.833812	valid_0's binary_logloss: 0.331856
# [488]	valid_0's auc: 0.833811	valid_0's binary_logloss: 0.331856
# [489]	valid_0's auc: 0.833815	valid_0's binary_logloss: 0.331852
# [490]	valid_0's auc: 0.833817	valid_0's binary_logloss: 0.33185
# [491]	valid_0's auc: 0.833817	valid_0's binary_logloss: 0.33185
# [492]	valid_0's auc: 0.833821	valid_0's binary_logloss: 0.331847
# [493]	valid_0's auc: 0.833823	valid_0's binary_logloss: 0.331845
# [494]	valid_0's auc: 0.833838	valid_0's binary_logloss: 0.331837
# [495]	valid_0's auc: 0.833855	valid_0's binary_logloss: 0.331823
# [496]	valid_0's auc: 0.833855	valid_0's binary_logloss: 0.331822
# [497]	valid_0's auc: 0.833862	valid_0's binary_logloss: 0.331818
# [498]	valid_0's auc: 0.833903	valid_0's binary_logloss: 0.331774
# [499]	valid_0's auc: 0.833923	valid_0's binary_logloss: 0.331747
# [500]	valid_0's auc: 0.833937	valid_0's binary_logloss: 0.33173
# [501]	valid_0's auc: 0.833939	valid_0's binary_logloss: 0.331726
# [502]	valid_0's auc: 0.833936	valid_0's binary_logloss: 0.331728
# [503]	valid_0's auc: 0.833935	valid_0's binary_logloss: 0.331727
# [504]	valid_0's auc: 0.833936	valid_0's binary_logloss: 0.331726
# [505]	valid_0's auc: 0.83394	valid_0's binary_logloss: 0.331723
# [506]	valid_0's auc: 0.833989	valid_0's binary_logloss: 0.331682
# [507]	valid_0's auc: 0.833991	valid_0's binary_logloss: 0.331679
# [508]	valid_0's auc: 0.833993	valid_0's binary_logloss: 0.331677
# [509]	valid_0's auc: 0.834004	valid_0's binary_logloss: 0.331669
# [510]	valid_0's auc: 0.834011	valid_0's binary_logloss: 0.331665
# [511]	valid_0's auc: 0.834016	valid_0's binary_logloss: 0.331661
# [512]	valid_0's auc: 0.834022	valid_0's binary_logloss: 0.331658
# [513]	valid_0's auc: 0.834023	valid_0's binary_logloss: 0.331658
# [514]	valid_0's auc: 0.834028	valid_0's binary_logloss: 0.331654
# [515]	valid_0's auc: 0.834029	valid_0's binary_logloss: 0.331652
# [516]	valid_0's auc: 0.834031	valid_0's binary_logloss: 0.331652
# [517]	valid_0's auc: 0.834032	valid_0's binary_logloss: 0.33165
# [518]	valid_0's auc: 0.83404	valid_0's binary_logloss: 0.331641
# [519]	valid_0's auc: 0.834055	valid_0's binary_logloss: 0.331628
# [520]	valid_0's auc: 0.834055	valid_0's binary_logloss: 0.331627
# [521]	valid_0's auc: 0.834058	valid_0's binary_logloss: 0.331625
# [522]	valid_0's auc: 0.834068	valid_0's binary_logloss: 0.331618
# [523]	valid_0's auc: 0.834069	valid_0's binary_logloss: 0.331617
# [524]	valid_0's auc: 0.834069	valid_0's binary_logloss: 0.331616
# [525]	valid_0's auc: 0.834074	valid_0's binary_logloss: 0.331613
# [526]	valid_0's auc: 0.834078	valid_0's binary_logloss: 0.33161
# [527]	valid_0's auc: 0.834086	valid_0's binary_logloss: 0.331605
# [528]	valid_0's auc: 0.834085	valid_0's binary_logloss: 0.331605
# [529]	valid_0's auc: 0.834098	valid_0's binary_logloss: 0.331595
# [530]	valid_0's auc: 0.834116	valid_0's binary_logloss: 0.331581
# [531]	valid_0's auc: 0.834126	valid_0's binary_logloss: 0.331574
# [532]	valid_0's auc: 0.834122	valid_0's binary_logloss: 0.331577
# [533]	valid_0's auc: 0.834122	valid_0's binary_logloss: 0.331577
# [534]	valid_0's auc: 0.83412	valid_0's binary_logloss: 0.331579
# [535]	valid_0's auc: 0.834119	valid_0's binary_logloss: 0.33158
# [536]	valid_0's auc: 0.834118	valid_0's binary_logloss: 0.331581
# [537]	valid_0's auc: 0.83413	valid_0's binary_logloss: 0.33157
# [538]	valid_0's auc: 0.834149	valid_0's binary_logloss: 0.331555
# [539]	valid_0's auc: 0.834161	valid_0's binary_logloss: 0.331547
# [540]	valid_0's auc: 0.834162	valid_0's binary_logloss: 0.331545
# [541]	valid_0's auc: 0.834164	valid_0's binary_logloss: 0.331542
# [542]	valid_0's auc: 0.834213	valid_0's binary_logloss: 0.331509
# [543]	valid_0's auc: 0.834211	valid_0's binary_logloss: 0.33151
# [544]	valid_0's auc: 0.834207	valid_0's binary_logloss: 0.331509
# [545]	valid_0's auc: 0.834208	valid_0's binary_logloss: 0.331508
# [546]	valid_0's auc: 0.834212	valid_0's binary_logloss: 0.331506
# [547]	valid_0's auc: 0.83422	valid_0's binary_logloss: 0.331497
# [548]	valid_0's auc: 0.834266	valid_0's binary_logloss: 0.331451
# [549]	valid_0's auc: 0.83427	valid_0's binary_logloss: 0.331447
# [550]	valid_0's auc: 0.834286	valid_0's binary_logloss: 0.331436
# [551]	valid_0's auc: 0.834283	valid_0's binary_logloss: 0.331438
# [552]	valid_0's auc: 0.834285	valid_0's binary_logloss: 0.331436
# [553]	valid_0's auc: 0.834283	valid_0's binary_logloss: 0.331438
# [554]	valid_0's auc: 0.834282	valid_0's binary_logloss: 0.331438
# [555]	valid_0's auc: 0.834293	valid_0's binary_logloss: 0.331431
# [556]	valid_0's auc: 0.834304	valid_0's binary_logloss: 0.331424
# [557]	valid_0's auc: 0.834314	valid_0's binary_logloss: 0.331415
# [558]	valid_0's auc: 0.83432	valid_0's binary_logloss: 0.33141
# [559]	valid_0's auc: 0.834326	valid_0's binary_logloss: 0.331405
# [560]	valid_0's auc: 0.834332	valid_0's binary_logloss: 0.3314
# [561]	valid_0's auc: 0.83434	valid_0's binary_logloss: 0.331396
# [562]	valid_0's auc: 0.834346	valid_0's binary_logloss: 0.331391
# [563]	valid_0's auc: 0.834344	valid_0's binary_logloss: 0.331392
# [564]	valid_0's auc: 0.834347	valid_0's binary_logloss: 0.33139
# [565]	valid_0's auc: 0.834352	valid_0's binary_logloss: 0.331386
# [566]	valid_0's auc: 0.834351	valid_0's binary_logloss: 0.331386
# [567]	valid_0's auc: 0.834352	valid_0's binary_logloss: 0.331385
# [568]	valid_0's auc: 0.834356	valid_0's binary_logloss: 0.331382
# [569]	valid_0's auc: 0.834367	valid_0's binary_logloss: 0.331373
# [570]	valid_0's auc: 0.834377	valid_0's binary_logloss: 0.331367
# [571]	valid_0's auc: 0.834378	valid_0's binary_logloss: 0.331367
# [572]	valid_0's auc: 0.834381	valid_0's binary_logloss: 0.331365
# [573]	valid_0's auc: 0.834382	valid_0's binary_logloss: 0.331363
# [574]	valid_0's auc: 0.834381	valid_0's binary_logloss: 0.331364
# [575]	valid_0's auc: 0.834394	valid_0's binary_logloss: 0.331355
# [576]	valid_0's auc: 0.834395	valid_0's binary_logloss: 0.331355
# [577]	valid_0's auc: 0.834401	valid_0's binary_logloss: 0.33135
# [578]	valid_0's auc: 0.834413	valid_0's binary_logloss: 0.331339
# [579]	valid_0's auc: 0.834427	valid_0's binary_logloss: 0.331327
# [580]	valid_0's auc: 0.834434	valid_0's binary_logloss: 0.331322
# [581]	valid_0's auc: 0.834441	valid_0's binary_logloss: 0.331316
# [582]	valid_0's auc: 0.83444	valid_0's binary_logloss: 0.331316
# [583]	valid_0's auc: 0.834441	valid_0's binary_logloss: 0.331316
# [584]	valid_0's auc: 0.83445	valid_0's binary_logloss: 0.331309
# [585]	valid_0's auc: 0.834452	valid_0's binary_logloss: 0.331306
# [586]	valid_0's auc: 0.834461	valid_0's binary_logloss: 0.331301
# [587]	valid_0's auc: 0.834459	valid_0's binary_logloss: 0.331302
# [588]	valid_0's auc: 0.834461	valid_0's binary_logloss: 0.3313
# [589]	valid_0's auc: 0.83447	valid_0's binary_logloss: 0.331292
# [590]	valid_0's auc: 0.834479	valid_0's binary_logloss: 0.331282
# [591]	valid_0's auc: 0.834482	valid_0's binary_logloss: 0.33128
# [592]	valid_0's auc: 0.834483	valid_0's binary_logloss: 0.331279
# [593]	valid_0's auc: 0.834495	valid_0's binary_logloss: 0.331272
# [594]	valid_0's auc: 0.834498	valid_0's binary_logloss: 0.331271
# [595]	valid_0's auc: 0.834499	valid_0's binary_logloss: 0.331269
# [596]	valid_0's auc: 0.834501	valid_0's binary_logloss: 0.331267
# [597]	valid_0's auc: 0.834501	valid_0's binary_logloss: 0.331267
# [598]	valid_0's auc: 0.834501	valid_0's binary_logloss: 0.331266
# [599]	valid_0's auc: 0.83452	valid_0's binary_logloss: 0.331246
# [600]	valid_0's auc: 0.834527	valid_0's binary_logloss: 0.33124
# [601]	valid_0's auc: 0.834526	valid_0's binary_logloss: 0.33124
# [602]	valid_0's auc: 0.834537	valid_0's binary_logloss: 0.331231
# [603]	valid_0's auc: 0.83455	valid_0's binary_logloss: 0.331222
# [604]	valid_0's auc: 0.834558	valid_0's binary_logloss: 0.331215
# [605]	valid_0's auc: 0.834565	valid_0's binary_logloss: 0.331211
# [606]	valid_0's auc: 0.834568	valid_0's binary_logloss: 0.331208
# [607]	valid_0's auc: 0.834567	valid_0's binary_logloss: 0.331209
# [608]	valid_0's auc: 0.834577	valid_0's binary_logloss: 0.331202
# [609]	valid_0's auc: 0.834581	valid_0's binary_logloss: 0.331199
# [610]	valid_0's auc: 0.834581	valid_0's binary_logloss: 0.331199
# [611]	valid_0's auc: 0.834582	valid_0's binary_logloss: 0.331198
# [612]	valid_0's auc: 0.834591	valid_0's binary_logloss: 0.331191
# [613]	valid_0's auc: 0.834599	valid_0's binary_logloss: 0.331184
# [614]	valid_0's auc: 0.834606	valid_0's binary_logloss: 0.331178
# [615]	valid_0's auc: 0.834607	valid_0's binary_logloss: 0.331178
# [616]	valid_0's auc: 0.834611	valid_0's binary_logloss: 0.331176
# [617]	valid_0's auc: 0.834609	valid_0's binary_logloss: 0.331177
# [618]	valid_0's auc: 0.834621	valid_0's binary_logloss: 0.331169
# [619]	valid_0's auc: 0.834643	valid_0's binary_logloss: 0.331144
# [620]	valid_0's auc: 0.834652	valid_0's binary_logloss: 0.331138
# [621]	valid_0's auc: 0.834654	valid_0's binary_logloss: 0.331137
# [622]	valid_0's auc: 0.834654	valid_0's binary_logloss: 0.331136
# [623]	valid_0's auc: 0.83466	valid_0's binary_logloss: 0.331131
# [624]	valid_0's auc: 0.834669	valid_0's binary_logloss: 0.331125
# [625]	valid_0's auc: 0.834678	valid_0's binary_logloss: 0.331117
# [626]	valid_0's auc: 0.83468	valid_0's binary_logloss: 0.331114
# [627]	valid_0's auc: 0.834684	valid_0's binary_logloss: 0.331109
# [628]	valid_0's auc: 0.834684	valid_0's binary_logloss: 0.331109
# [629]	valid_0's auc: 0.834689	valid_0's binary_logloss: 0.331104
# [630]	valid_0's auc: 0.834688	valid_0's binary_logloss: 0.331104
# [631]	valid_0's auc: 0.834696	valid_0's binary_logloss: 0.331099
# [632]	valid_0's auc: 0.834698	valid_0's binary_logloss: 0.331096
# [633]	valid_0's auc: 0.834705	valid_0's binary_logloss: 0.331093
# [634]	valid_0's auc: 0.834704	valid_0's binary_logloss: 0.331093
# [635]	valid_0's auc: 0.834712	valid_0's binary_logloss: 0.331087
# [636]	valid_0's auc: 0.834721	valid_0's binary_logloss: 0.33108
# [637]	valid_0's auc: 0.834726	valid_0's binary_logloss: 0.331076
# [638]	valid_0's auc: 0.834733	valid_0's binary_logloss: 0.331072
# [639]	valid_0's auc: 0.834731	valid_0's binary_logloss: 0.331073
# [640]	valid_0's auc: 0.83475	valid_0's binary_logloss: 0.331059
# [641]	valid_0's auc: 0.834764	valid_0's binary_logloss: 0.331049
# [642]	valid_0's auc: 0.834765	valid_0's binary_logloss: 0.331048
# [643]	valid_0's auc: 0.834766	valid_0's binary_logloss: 0.331048
# [644]	valid_0's auc: 0.834776	valid_0's binary_logloss: 0.331039
# [645]	valid_0's auc: 0.834825	valid_0's binary_logloss: 0.330996
# [646]	valid_0's auc: 0.834828	valid_0's binary_logloss: 0.330994
# [647]	valid_0's auc: 0.83484	valid_0's binary_logloss: 0.330983
# [648]	valid_0's auc: 0.834843	valid_0's binary_logloss: 0.33098
# [649]	valid_0's auc: 0.834847	valid_0's binary_logloss: 0.330977
# [650]	valid_0's auc: 0.83485	valid_0's binary_logloss: 0.330975
# [651]	valid_0's auc: 0.834855	valid_0's binary_logloss: 0.330971
# [652]	valid_0's auc: 0.834854	valid_0's binary_logloss: 0.330971
# [653]	valid_0's auc: 0.834872	valid_0's binary_logloss: 0.330954
# [654]	valid_0's auc: 0.834899	valid_0's binary_logloss: 0.330926
# [655]	valid_0's auc: 0.834915	valid_0's binary_logloss: 0.330912
# [656]	valid_0's auc: 0.834922	valid_0's binary_logloss: 0.330904
# [657]	valid_0's auc: 0.834945	valid_0's binary_logloss: 0.330888
# [658]	valid_0's auc: 0.834949	valid_0's binary_logloss: 0.330884
# [659]	valid_0's auc: 0.834949	valid_0's binary_logloss: 0.330882
# [660]	valid_0's auc: 0.834956	valid_0's binary_logloss: 0.330878
# [661]	valid_0's auc: 0.834965	valid_0's binary_logloss: 0.330869
# [662]	valid_0's auc: 0.83497	valid_0's binary_logloss: 0.330865
# [663]	valid_0's auc: 0.83498	valid_0's binary_logloss: 0.330859
# [664]	valid_0's auc: 0.834981	valid_0's binary_logloss: 0.330857
# [665]	valid_0's auc: 0.834979	valid_0's binary_logloss: 0.330858
# [666]	valid_0's auc: 0.834981	valid_0's binary_logloss: 0.330857
# [667]	valid_0's auc: 0.834981	valid_0's binary_logloss: 0.330856
# [668]	valid_0's auc: 0.834984	valid_0's binary_logloss: 0.330853
# [669]	valid_0's auc: 0.834993	valid_0's binary_logloss: 0.330846
# [670]	valid_0's auc: 0.834995	valid_0's binary_logloss: 0.330845
# [671]	valid_0's auc: 0.835014	valid_0's binary_logloss: 0.330826
# [672]	valid_0's auc: 0.835023	valid_0's binary_logloss: 0.330819
# [673]	valid_0's auc: 0.835023	valid_0's binary_logloss: 0.330819
# [674]	valid_0's auc: 0.835024	valid_0's binary_logloss: 0.330818
# [675]	valid_0's auc: 0.835029	valid_0's binary_logloss: 0.330815
# [676]	valid_0's auc: 0.835042	valid_0's binary_logloss: 0.330806
# [677]	valid_0's auc: 0.835044	valid_0's binary_logloss: 0.330805
# [678]	valid_0's auc: 0.835057	valid_0's binary_logloss: 0.330794
# [679]	valid_0's auc: 0.835071	valid_0's binary_logloss: 0.330785
# [680]	valid_0's auc: 0.835086	valid_0's binary_logloss: 0.330773
# [681]	valid_0's auc: 0.83509	valid_0's binary_logloss: 0.330771
# [682]	valid_0's auc: 0.8351	valid_0's binary_logloss: 0.330763
# [683]	valid_0's auc: 0.83512	valid_0's binary_logloss: 0.330747
# [684]	valid_0's auc: 0.835131	valid_0's binary_logloss: 0.330738
# [685]	valid_0's auc: 0.835132	valid_0's binary_logloss: 0.330737
# [686]	valid_0's auc: 0.835134	valid_0's binary_logloss: 0.330734
# [687]	valid_0's auc: 0.835139	valid_0's binary_logloss: 0.33073
# [688]	valid_0's auc: 0.835147	valid_0's binary_logloss: 0.330724
# [689]	valid_0's auc: 0.835148	valid_0's binary_logloss: 0.330724
# [690]	valid_0's auc: 0.835185	valid_0's binary_logloss: 0.330697
# [691]	valid_0's auc: 0.835188	valid_0's binary_logloss: 0.330693
# [692]	valid_0's auc: 0.835194	valid_0's binary_logloss: 0.330689
# [693]	valid_0's auc: 0.835208	valid_0's binary_logloss: 0.33068
# [694]	valid_0's auc: 0.835209	valid_0's binary_logloss: 0.330679
# [695]	valid_0's auc: 0.835206	valid_0's binary_logloss: 0.330681
# [696]	valid_0's auc: 0.835219	valid_0's binary_logloss: 0.330672
# [697]	valid_0's auc: 0.835222	valid_0's binary_logloss: 0.330669
# [698]	valid_0's auc: 0.835228	valid_0's binary_logloss: 0.330664
# [699]	valid_0's auc: 0.835236	valid_0's binary_logloss: 0.330658
# [700]	valid_0's auc: 0.835239	valid_0's binary_logloss: 0.330655
# [701]	valid_0's auc: 0.835248	valid_0's binary_logloss: 0.330649
# [702]	valid_0's auc: 0.835251	valid_0's binary_logloss: 0.330647
# [703]	valid_0's auc: 0.835254	valid_0's binary_logloss: 0.330645
# [704]	valid_0's auc: 0.835255	valid_0's binary_logloss: 0.330644
# [705]	valid_0's auc: 0.835258	valid_0's binary_logloss: 0.330641
# [706]	valid_0's auc: 0.835263	valid_0's binary_logloss: 0.330636
# [707]	valid_0's auc: 0.835263	valid_0's binary_logloss: 0.330636
# [708]	valid_0's auc: 0.835267	valid_0's binary_logloss: 0.330631
# [709]	valid_0's auc: 0.835268	valid_0's binary_logloss: 0.330629
# [710]	valid_0's auc: 0.835271	valid_0's binary_logloss: 0.330625
# [711]	valid_0's auc: 0.835269	valid_0's binary_logloss: 0.330627
# [712]	valid_0's auc: 0.835272	valid_0's binary_logloss: 0.330623
# [713]	valid_0's auc: 0.835273	valid_0's binary_logloss: 0.330623
# [714]	valid_0's auc: 0.835278	valid_0's binary_logloss: 0.330619
# [715]	valid_0's auc: 0.835281	valid_0's binary_logloss: 0.330617
# [716]	valid_0's auc: 0.835286	valid_0's binary_logloss: 0.330614
# [717]	valid_0's auc: 0.835301	valid_0's binary_logloss: 0.330601
# [718]	valid_0's auc: 0.835302	valid_0's binary_logloss: 0.3306
# [719]	valid_0's auc: 0.83531	valid_0's binary_logloss: 0.330593
# [720]	valid_0's auc: 0.835312	valid_0's binary_logloss: 0.330591
# [721]	valid_0's auc: 0.835323	valid_0's binary_logloss: 0.330583
# [722]	valid_0's auc: 0.835332	valid_0's binary_logloss: 0.330574
# [723]	valid_0's auc: 0.835348	valid_0's binary_logloss: 0.330563
# [724]	valid_0's auc: 0.835357	valid_0's binary_logloss: 0.330557
# [725]	valid_0's auc: 0.83538	valid_0's binary_logloss: 0.330538
# [726]	valid_0's auc: 0.835394	valid_0's binary_logloss: 0.330524
# [727]	valid_0's auc: 0.835396	valid_0's binary_logloss: 0.330523
# [728]	valid_0's auc: 0.835411	valid_0's binary_logloss: 0.330509
# [729]	valid_0's auc: 0.835413	valid_0's binary_logloss: 0.330508
# [730]	valid_0's auc: 0.835411	valid_0's binary_logloss: 0.330509
# [731]	valid_0's auc: 0.835409	valid_0's binary_logloss: 0.330511
# [732]	valid_0's auc: 0.835415	valid_0's binary_logloss: 0.330506
# [733]	valid_0's auc: 0.835427	valid_0's binary_logloss: 0.330498
# [734]	valid_0's auc: 0.83543	valid_0's binary_logloss: 0.330494
# [735]	valid_0's auc: 0.835429	valid_0's binary_logloss: 0.330495
# [736]	valid_0's auc: 0.835431	valid_0's binary_logloss: 0.330492
# [737]	valid_0's auc: 0.835431	valid_0's binary_logloss: 0.330492
# [738]	valid_0's auc: 0.835438	valid_0's binary_logloss: 0.330487
# ...
# [1760]	valid_0's auc: 0.838469	valid_0's binary_logloss: 0.327915
# [1761]	valid_0's auc: 0.838467	valid_0's binary_logloss: 0.327919
# [1762]	valid_0's auc: 0.838468	valid_0's binary_logloss: 0.327918
# [1763]	valid_0's auc: 0.838468	valid_0's binary_logloss: 0.327919
# [1764]	valid_0's auc: 0.838475	valid_0's binary_logloss: 0.327913
# [1765]	valid_0's auc: 0.838475	valid_0's binary_logloss: 0.327912
# [1766]	valid_0's auc: 0.838479	valid_0's binary_logloss: 0.327906
# [1767]	valid_0's auc: 0.83848	valid_0's binary_logloss: 0.327906
# [1768]	valid_0's auc: 0.838481	valid_0's binary_logloss: 0.327905
# [1769]	valid_0's auc: 0.838481	valid_0's binary_logloss: 0.327905
# [1770]	valid_0's auc: 0.838478	valid_0's binary_logloss: 0.327907
# [1771]	valid_0's auc: 0.838476	valid_0's binary_logloss: 0.327909
# [1772]	valid_0's auc: 0.838477	valid_0's binary_logloss: 0.327908
# [1773]	valid_0's auc: 0.838479	valid_0's binary_logloss: 0.327907
# [1774]	valid_0's auc: 0.838481	valid_0's binary_logloss: 0.327906
# [1775]	valid_0's auc: 0.83849	valid_0's binary_logloss: 0.327899
# [1776]	valid_0's auc: 0.838486	valid_0's binary_logloss: 0.327901
# [1777]	valid_0's auc: 0.838485	valid_0's binary_logloss: 0.327902
# [1778]	valid_0's auc: 0.838484	valid_0's binary_logloss: 0.327903
# [1779]	valid_0's auc: 0.838485	valid_0's binary_logloss: 0.327902
# [1780]	valid_0's auc: 0.838487	valid_0's binary_logloss: 0.327901
# [1781]	valid_0's auc: 0.838487	valid_0's binary_logloss: 0.327899
# [1782]	valid_0's auc: 0.838487	valid_0's binary_logloss: 0.327899
# [1783]	valid_0's auc: 0.838486	valid_0's binary_logloss: 0.327902
# [1784]	valid_0's auc: 0.838483	valid_0's binary_logloss: 0.327904
# [1785]	valid_0's auc: 0.838486	valid_0's binary_logloss: 0.327903
# [1786]	valid_0's auc: 0.838486	valid_0's binary_logloss: 0.327903
# [1787]	valid_0's auc: 0.838484	valid_0's binary_logloss: 0.327905
# [1788]	valid_0's auc: 0.838487	valid_0's binary_logloss: 0.327903
# [1789]	valid_0's auc: 0.83849	valid_0's binary_logloss: 0.327902
# [1790]	valid_0's auc: 0.838489	valid_0's binary_logloss: 0.327902
# [1791]	valid_0's auc: 0.838491	valid_0's binary_logloss: 0.3279
# [1792]	valid_0's auc: 0.83849	valid_0's binary_logloss: 0.327901
# [1793]	valid_0's auc: 0.838492	valid_0's binary_logloss: 0.327899
# [1794]	valid_0's auc: 0.8385	valid_0's binary_logloss: 0.327893
# [1795]	valid_0's auc: 0.838498	valid_0's binary_logloss: 0.327894
# [1796]	valid_0's auc: 0.838496	valid_0's binary_logloss: 0.327895
# [1797]	valid_0's auc: 0.838495	valid_0's binary_logloss: 0.327896
# [1798]	valid_0's auc: 0.838493	valid_0's binary_logloss: 0.327898
# [1799]	valid_0's auc: 0.838494	valid_0's binary_logloss: 0.327898
# [1800]	valid_0's auc: 0.8385	valid_0's binary_logloss: 0.327892
# [1801]	valid_0's auc: 0.838503	valid_0's binary_logloss: 0.32789
# [1802]	valid_0's auc: 0.838502	valid_0's binary_logloss: 0.327891
# [1803]	valid_0's auc: 0.838504	valid_0's binary_logloss: 0.32789
# [1804]	valid_0's auc: 0.838504	valid_0's binary_logloss: 0.32789
# [1805]	valid_0's auc: 0.838502	valid_0's binary_logloss: 0.327892
# [1806]	valid_0's auc: 0.838502	valid_0's binary_logloss: 0.327892
# [1807]	valid_0's auc: 0.838503	valid_0's binary_logloss: 0.32789
# [1808]	valid_0's auc: 0.838511	valid_0's binary_logloss: 0.327885
# [1809]	valid_0's auc: 0.838517	valid_0's binary_logloss: 0.327879
# [1810]	valid_0's auc: 0.838529	valid_0's binary_logloss: 0.32787
# [1811]	valid_0's auc: 0.838528	valid_0's binary_logloss: 0.327871
# [1812]	valid_0's auc: 0.838531	valid_0's binary_logloss: 0.327868
# [1813]	valid_0's auc: 0.838531	valid_0's binary_logloss: 0.327868
# [1814]	valid_0's auc: 0.838532	valid_0's binary_logloss: 0.327866
# [1815]	valid_0's auc: 0.838532	valid_0's binary_logloss: 0.327866
# [1816]	valid_0's auc: 0.838533	valid_0's binary_logloss: 0.327865
# [1817]	valid_0's auc: 0.838535	valid_0's binary_logloss: 0.327864
# [1818]	valid_0's auc: 0.838535	valid_0's binary_logloss: 0.327864
# [1819]	valid_0's auc: 0.838534	valid_0's binary_logloss: 0.327865
# [1820]	valid_0's auc: 0.838531	valid_0's binary_logloss: 0.327867
# [1821]	valid_0's auc: 0.838536	valid_0's binary_logloss: 0.327862
# [1822]	valid_0's auc: 0.838543	valid_0's binary_logloss: 0.327857
# [1823]	valid_0's auc: 0.838547	valid_0's binary_logloss: 0.327854
# [1824]	valid_0's auc: 0.838548	valid_0's binary_logloss: 0.327853
# [1825]	valid_0's auc: 0.838544	valid_0's binary_logloss: 0.327856
# [1826]	valid_0's auc: 0.838547	valid_0's binary_logloss: 0.327854
# [1827]	valid_0's auc: 0.838553	valid_0's binary_logloss: 0.327849
# [1828]	valid_0's auc: 0.838568	valid_0's binary_logloss: 0.32784
# [1829]	valid_0's auc: 0.838567	valid_0's binary_logloss: 0.32784
# [1830]	valid_0's auc: 0.838565	valid_0's binary_logloss: 0.327841
# [1831]	valid_0's auc: 0.838564	valid_0's binary_logloss: 0.327842
# [1832]	valid_0's auc: 0.838562	valid_0's binary_logloss: 0.327844
# [1833]	valid_0's auc: 0.838565	valid_0's binary_logloss: 0.327842
# [1834]	valid_0's auc: 0.838566	valid_0's binary_logloss: 0.32784
# [1835]	valid_0's auc: 0.838567	valid_0's binary_logloss: 0.32784
# [1836]	valid_0's auc: 0.838571	valid_0's binary_logloss: 0.327835
# [1837]	valid_0's auc: 0.838573	valid_0's binary_logloss: 0.327834
# [1838]	valid_0's auc: 0.838574	valid_0's binary_logloss: 0.327833
# [1839]	valid_0's auc: 0.838571	valid_0's binary_logloss: 0.327834
# [1840]	valid_0's auc: 0.83857	valid_0's binary_logloss: 0.327835
# [1841]	valid_0's auc: 0.838571	valid_0's binary_logloss: 0.327833
# [1842]	valid_0's auc: 0.838572	valid_0's binary_logloss: 0.327833
# [1843]	valid_0's auc: 0.838573	valid_0's binary_logloss: 0.327832
# [1844]	valid_0's auc: 0.838573	valid_0's binary_logloss: 0.327832
# [1845]	valid_0's auc: 0.838576	valid_0's binary_logloss: 0.32783
# [1846]	valid_0's auc: 0.838578	valid_0's binary_logloss: 0.327829
# [1847]	valid_0's auc: 0.838579	valid_0's binary_logloss: 0.327828
# [1848]	valid_0's auc: 0.83858	valid_0's binary_logloss: 0.327827
# [1849]	valid_0's auc: 0.838578	valid_0's binary_logloss: 0.327829
# [1850]	valid_0's auc: 0.838577	valid_0's binary_logloss: 0.32783
# [1851]	valid_0's auc: 0.838576	valid_0's binary_logloss: 0.327831
# [1852]	valid_0's auc: 0.838574	valid_0's binary_logloss: 0.327833
# [1853]	valid_0's auc: 0.83858	valid_0's binary_logloss: 0.32783
# [1854]	valid_0's auc: 0.838578	valid_0's binary_logloss: 0.327832
# [1855]	valid_0's auc: 0.838576	valid_0's binary_logloss: 0.327833
# [1856]	valid_0's auc: 0.838574	valid_0's binary_logloss: 0.327835
# [1857]	valid_0's auc: 0.838575	valid_0's binary_logloss: 0.327836
# [1858]	valid_0's auc: 0.83858	valid_0's binary_logloss: 0.327834
# [1859]	valid_0's auc: 0.838583	valid_0's binary_logloss: 0.327832
# [1860]	valid_0's auc: 0.838587	valid_0's binary_logloss: 0.327828
# [1861]	valid_0's auc: 0.838589	valid_0's binary_logloss: 0.327826
# [1862]	valid_0's auc: 0.838588	valid_0's binary_logloss: 0.327827
# [1863]	valid_0's auc: 0.83859	valid_0's binary_logloss: 0.327825
# [1864]	valid_0's auc: 0.838587	valid_0's binary_logloss: 0.327827
# [1865]	valid_0's auc: 0.838591	valid_0's binary_logloss: 0.327823
# [1866]	valid_0's auc: 0.838597	valid_0's binary_logloss: 0.327818
# [1867]	valid_0's auc: 0.838598	valid_0's binary_logloss: 0.327817
# [1868]	valid_0's auc: 0.838599	valid_0's binary_logloss: 0.327816
# [1869]	valid_0's auc: 0.838601	valid_0's binary_logloss: 0.327814
# [1870]	valid_0's auc: 0.838602	valid_0's binary_logloss: 0.327815
# [1871]	valid_0's auc: 0.838601	valid_0's binary_logloss: 0.327815
# [1872]	valid_0's auc: 0.838598	valid_0's binary_logloss: 0.327817
# [1873]	valid_0's auc: 0.838596	valid_0's binary_logloss: 0.327819
# [1874]	valid_0's auc: 0.838595	valid_0's binary_logloss: 0.327819
# [1875]	valid_0's auc: 0.838595	valid_0's binary_logloss: 0.327819
# [1876]	valid_0's auc: 0.838596	valid_0's binary_logloss: 0.327819
# [1877]	valid_0's auc: 0.838595	valid_0's binary_logloss: 0.327819
# [1878]	valid_0's auc: 0.838599	valid_0's binary_logloss: 0.327816
# [1879]	valid_0's auc: 0.838601	valid_0's binary_logloss: 0.327814
# [1880]	valid_0's auc: 0.838605	valid_0's binary_logloss: 0.327811
# [1881]	valid_0's auc: 0.838621	valid_0's binary_logloss: 0.327796
# [1882]	valid_0's auc: 0.838622	valid_0's binary_logloss: 0.327796
# [1883]	valid_0's auc: 0.838621	valid_0's binary_logloss: 0.327796
# [1884]	valid_0's auc: 0.838626	valid_0's binary_logloss: 0.327793
# [1885]	valid_0's auc: 0.838626	valid_0's binary_logloss: 0.327793
# [1886]	valid_0's auc: 0.83863	valid_0's binary_logloss: 0.327789
# [1887]	valid_0's auc: 0.838632	valid_0's binary_logloss: 0.327788
# [1888]	valid_0's auc: 0.838631	valid_0's binary_logloss: 0.327788
# [1889]	valid_0's auc: 0.838634	valid_0's binary_logloss: 0.327784
# [1890]	valid_0's auc: 0.838633	valid_0's binary_logloss: 0.327785
# [1891]	valid_0's auc: 0.838633	valid_0's binary_logloss: 0.327785
# [1892]	valid_0's auc: 0.838633	valid_0's binary_logloss: 0.327785
# [1893]	valid_0's auc: 0.838631	valid_0's binary_logloss: 0.327785
# [1894]	valid_0's auc: 0.83863	valid_0's binary_logloss: 0.327785
# [1895]	valid_0's auc: 0.838631	valid_0's binary_logloss: 0.327785
# [1896]	valid_0's auc: 0.838636	valid_0's binary_logloss: 0.327781
# [1897]	valid_0's auc: 0.838636	valid_0's binary_logloss: 0.327779
# [1898]	valid_0's auc: 0.838642	valid_0's binary_logloss: 0.327774
# [1899]	valid_0's auc: 0.838647	valid_0's binary_logloss: 0.32777
# [1900]	valid_0's auc: 0.838648	valid_0's binary_logloss: 0.32777
# [1901]	valid_0's auc: 0.838652	valid_0's binary_logloss: 0.327767
# [1902]	valid_0's auc: 0.838656	valid_0's binary_logloss: 0.327765
# [1903]	valid_0's auc: 0.83866	valid_0's binary_logloss: 0.327759
# [1904]	valid_0's auc: 0.838659	valid_0's binary_logloss: 0.327761
# [1905]	valid_0's auc: 0.838661	valid_0's binary_logloss: 0.327757
# [1906]	valid_0's auc: 0.838659	valid_0's binary_logloss: 0.327759
# [1907]	valid_0's auc: 0.838657	valid_0's binary_logloss: 0.32776
# [1908]	valid_0's auc: 0.838658	valid_0's binary_logloss: 0.327759
# [1909]	valid_0's auc: 0.838662	valid_0's binary_logloss: 0.327755
# [1910]	valid_0's auc: 0.838664	valid_0's binary_logloss: 0.327753
# [1911]	valid_0's auc: 0.838671	valid_0's binary_logloss: 0.327747
# [1912]	valid_0's auc: 0.838679	valid_0's binary_logloss: 0.32774
# [1913]	valid_0's auc: 0.838677	valid_0's binary_logloss: 0.327741
# [1914]	valid_0's auc: 0.838677	valid_0's binary_logloss: 0.327742
# [1915]	valid_0's auc: 0.838679	valid_0's binary_logloss: 0.32774
# [1916]	valid_0's auc: 0.838678	valid_0's binary_logloss: 0.327741
# [1917]	valid_0's auc: 0.838678	valid_0's binary_logloss: 0.327741
# [1918]	valid_0's auc: 0.838678	valid_0's binary_logloss: 0.327741
# [1919]	valid_0's auc: 0.83868	valid_0's binary_logloss: 0.327739
# [1920]	valid_0's auc: 0.838683	valid_0's binary_logloss: 0.327737
# [1921]	valid_0's auc: 0.838685	valid_0's binary_logloss: 0.327735
# [1922]	valid_0's auc: 0.838689	valid_0's binary_logloss: 0.327731
# [1923]	valid_0's auc: 0.838687	valid_0's binary_logloss: 0.327733
# [1924]	valid_0's auc: 0.838686	valid_0's binary_logloss: 0.327733
# [1925]	valid_0's auc: 0.838683	valid_0's binary_logloss: 0.327735
# [1926]	valid_0's auc: 0.838683	valid_0's binary_logloss: 0.327735
# [1927]	valid_0's auc: 0.838685	valid_0's binary_logloss: 0.327734
# [1928]	valid_0's auc: 0.838685	valid_0's binary_logloss: 0.327734
# [1929]	valid_0's auc: 0.838682	valid_0's binary_logloss: 0.327736
# [1930]	valid_0's auc: 0.838681	valid_0's binary_logloss: 0.327736
# [1931]	valid_0's auc: 0.838684	valid_0's binary_logloss: 0.327734
# [1932]	valid_0's auc: 0.838692	valid_0's binary_logloss: 0.327726
# [1933]	valid_0's auc: 0.838692	valid_0's binary_logloss: 0.327727
# [1934]	valid_0's auc: 0.838694	valid_0's binary_logloss: 0.327725
# [1935]	valid_0's auc: 0.838699	valid_0's binary_logloss: 0.327721
# [1936]	valid_0's auc: 0.838697	valid_0's binary_logloss: 0.327722
# [1937]	valid_0's auc: 0.8387	valid_0's binary_logloss: 0.327719
# [1938]	valid_0's auc: 0.838703	valid_0's binary_logloss: 0.327717
# [1939]	valid_0's auc: 0.838702	valid_0's binary_logloss: 0.327718
# [1940]	valid_0's auc: 0.838711	valid_0's binary_logloss: 0.327711
# [1941]	valid_0's auc: 0.838712	valid_0's binary_logloss: 0.32771
# [1942]	valid_0's auc: 0.838715	valid_0's binary_logloss: 0.327708
# [1943]	valid_0's auc: 0.838717	valid_0's binary_logloss: 0.327705
# [1944]	valid_0's auc: 0.838718	valid_0's binary_logloss: 0.327705
# [1945]	valid_0's auc: 0.838717	valid_0's binary_logloss: 0.327705
# [1946]	valid_0's auc: 0.838724	valid_0's binary_logloss: 0.327699
# [1947]	valid_0's auc: 0.838722	valid_0's binary_logloss: 0.327699
# [1948]	valid_0's auc: 0.838722	valid_0's binary_logloss: 0.327699
# [1949]	valid_0's auc: 0.838726	valid_0's binary_logloss: 0.327697
# [1950]	valid_0's auc: 0.838733	valid_0's binary_logloss: 0.327691
# [1951]	valid_0's auc: 0.838738	valid_0's binary_logloss: 0.327687
# [1952]	valid_0's auc: 0.838741	valid_0's binary_logloss: 0.327684
# [1953]	valid_0's auc: 0.83874	valid_0's binary_logloss: 0.327685
# [1954]	valid_0's auc: 0.838741	valid_0's binary_logloss: 0.327685
# [1955]	valid_0's auc: 0.838751	valid_0's binary_logloss: 0.327677
# [1956]	valid_0's auc: 0.838753	valid_0's binary_logloss: 0.327675
# [1957]	valid_0's auc: 0.838756	valid_0's binary_logloss: 0.327674
# [1958]	valid_0's auc: 0.838757	valid_0's binary_logloss: 0.327672
# [1959]	valid_0's auc: 0.83876	valid_0's binary_logloss: 0.32767
# [1960]	valid_0's auc: 0.838765	valid_0's binary_logloss: 0.327667
# [1961]	valid_0's auc: 0.838765	valid_0's binary_logloss: 0.327666
# [1962]	valid_0's auc: 0.838769	valid_0's binary_logloss: 0.327664
# [1963]	valid_0's auc: 0.83877	valid_0's binary_logloss: 0.327661
# [1964]	valid_0's auc: 0.838771	valid_0's binary_logloss: 0.327659
# [1965]	valid_0's auc: 0.838771	valid_0's binary_logloss: 0.327659
# [1966]	valid_0's auc: 0.838772	valid_0's binary_logloss: 0.327659
# [1967]	valid_0's auc: 0.838776	valid_0's binary_logloss: 0.327656
# [1968]	valid_0's auc: 0.838778	valid_0's binary_logloss: 0.327654
# [1969]	valid_0's auc: 0.838787	valid_0's binary_logloss: 0.327646
# [1970]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327639
# [1971]	valid_0's auc: 0.838799	valid_0's binary_logloss: 0.327637
# [1972]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327638
# [1973]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327638
# [1974]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327638
# [1975]	valid_0's auc: 0.838793	valid_0's binary_logloss: 0.32764
# [1976]	valid_0's auc: 0.838797	valid_0's binary_logloss: 0.327637
# [1977]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327638
# [1978]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327637
# [1979]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327637
# [1980]	valid_0's auc: 0.838799	valid_0's binary_logloss: 0.327634
# [1981]	valid_0's auc: 0.838801	valid_0's binary_logloss: 0.327632
# [1982]	valid_0's auc: 0.8388	valid_0's binary_logloss: 0.327632
# [1983]	valid_0's auc: 0.838799	valid_0's binary_logloss: 0.327633
# [1984]	valid_0's auc: 0.838796	valid_0's binary_logloss: 0.327635
# [1985]	valid_0's auc: 0.838795	valid_0's binary_logloss: 0.327636
# [1986]	valid_0's auc: 0.838793	valid_0's binary_logloss: 0.327637
# [1987]	valid_0's auc: 0.838791	valid_0's binary_logloss: 0.327638
# [1988]	valid_0's auc: 0.838789	valid_0's binary_logloss: 0.32764
# [1989]	valid_0's auc: 0.838791	valid_0's binary_logloss: 0.327638
# [1990]	valid_0's auc: 0.838792	valid_0's binary_logloss: 0.327637
# [1991]	valid_0's auc: 0.838792	valid_0's binary_logloss: 0.327636
# [1992]	valid_0's auc: 0.838791	valid_0's binary_logloss: 0.327637
# [1993]	valid_0's auc: 0.838791	valid_0's binary_logloss: 0.327637
# [1994]	valid_0's auc: 0.83879	valid_0's binary_logloss: 0.327637
# [1995]	valid_0's auc: 0.83879	valid_0's binary_logloss: 0.327637
# [1996]	valid_0's auc: 0.838788	valid_0's binary_logloss: 0.327638
# [1997]	valid_0's auc: 0.838794	valid_0's binary_logloss: 0.327634
# [1998]	valid_0's auc: 0.838793	valid_0's binary_logloss: 0.327636
# [1999]	valid_0's auc: 0.838802	valid_0's binary_logloss: 0.327629
# [2000]	valid_0's auc: 0.838811	valid_0's binary_logloss: 0.327618
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's auc: 0.838811	valid_0's binary_logloss: 0.327618

# %%
sub.to_csv('./result/2000_0.838811.txt', index=None, header=None, sep='\t')

# %%
fi = pd.DataFrame({'feature': feature_cols, 'imp': model_lgb.feature_importances_})
fi['rate'] = fi['imp'] / fi['imp'].sum()

# %%
fi
# Out:
#                 feature   imp      rate
# 0                  freq   428  0.007133
# 1                gender   342  0.005700
# 2                  hour  2436  0.040600
# 3           q_ans_count   326  0.005433
# 4    q_diff_qa_days_max   464  0.007733
# ..                  ...   ...       ...
# 121         uf_c2_count   384  0.006400
# 122         uf_c3_count  1194  0.019900
# 123         uf_c4_count  1183  0.019717
# 124         uf_c5_count     0  0.000000
# 125                  wk  1320  0.022000
#
# [126 rows x 3 columns]

# %%
fi.sort_values(by='rate', ascending=False)[:20]
# Out:
#                  feature   imp      rate
# 54                 score  3315  0.055250
# 117        qid_enc_count  3030  0.050500
# 2                   hour  2436  0.040600
# 53               qid_enc  2256  0.037600
# 115              uid_enc  2239  0.037317
# 116        uid_enc_count  1985  0.033083
# 66            u_inv_mean  1619  0.026983
# 65           u_inv_count  1527  0.025450
# 57   u_diff_qa_days_mean  1429  0.023817
# 67             u_inv_std  1367  0.022783
# 113                uf_c4  1357  0.022617
# 125                   wk  1320  0.022000
# 103    u_word_count_mean  1296  0.021600
# 104     u_word_count_sum  1198  0.019967
# 122          uf_c3_count  1194  0.019900
# 123          uf_c4_count  1183  0.019717
# 102     u_word_count_max  1169  0.019483
# 112                uf_c3  1157  0.019283
# 110                uf_c1  1124  0.018733
# 55           u_ans_count  1115  0.018583
